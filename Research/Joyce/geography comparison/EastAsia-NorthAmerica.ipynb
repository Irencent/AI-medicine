# %%
import pingouin as pg

# %%
import numpy as np
from scipy.stats import chi2_contingency
from scipy import stats

# %%
import pandas as pd

# %%
data = pd.read_excel("/Users/huyanshen/Desktop/Book1.xlsx")
data.dropna(how='any')
# Out:
#      Asia   US
# 0     5.0  5.6
# 1    11.0  2.1
# 2     4.0  4.6
# 3    29.0  8.0
# 4     4.0  0.3
# ..    ...  ...
# 126  11.0  5.0
# 127  10.0  3.0
# 128   7.0  7.0
# 129   4.0  3.0
# 130  28.0  2.0
#
# [130 rows x 2 columns]

# %%
US = data['Asia'].dropna()
Asia = data['US'].dropna()
H, p_value = stats.kruskal(Asia, US)
print("P-Value:", p_value)
# Out:
# P-Value: 0.6108695902598118

# %%
F, p_value = stats.f_oneway(Asia, US)
print("F-statistic:", F)
print("P-Value:", p_value)
# Out:
# F-statistic: 0.6964393652556229
# P-Value: 0.40420817253635954

# %%
#Race
observed_values = np.array([[756, 0, 0], [5, 5, 82]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 796.6442324172999
# P-value: 1.0254226605162665e-173
# Cramer's V: 0.969246590565212

# %%
#sex
observed_values = np.array([[493, 263], [86, 45]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 0.0
# P-value: 1.0
# Cramer's V: 0.0

# %%
#Modular Subtypes-all
observed_values = np.array([[113, 214, 429], [9, 35, 87]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
#cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
#print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 7.18940728817911
# P-value: 0.027468822517791622

# %%
#Modular Subtypes-SHH
observed_values = np.array([[136, 57], [11, 2]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 0.6011713762657824
# P-value: 0.4381314416792924
# Cramer's V: 0.054021362920382184

# %%
#Modular Subtypes-non-W/S
observed_values = np.array([[83, 314], [21, 52]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 1.7783072522663779
# P-value: 0.18235732355702652
# Cramer's V: 0.06151123841730543

# %%
#Histology
observed_values = np.array([[506, 149, 26, 34], [21, 5, 8, 0]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 30.879552570028885
# P-value: 9.011621346430132e-07
# Cramer's V: 0.20304607121559046

# %%
#Hydro-before
observed_values = np.array([[626, 130], [57, 74]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))

print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 95.13390401558398
# P-value: 1.7793308497199842e-22
# Cramer's V: 0.32749588672784463

# %%
#Tumor Texture
observed_values = np.array([[123, 154, 464], [3, 2, 5]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))

print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 1.3105761142530734
# P-value: 0.5192924551478761
# Cramer's V: 0.041774489922994026

# %%
#infiltration
observed_values = np.array([[556, 91], [75, 53]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))

print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 51.01176053844406
# P-value: 9.181421708069514e-13
# Cramer's V: 0.25655725774418886

# %%
#Survial status
observed_values = np.array([[608, 148], [100, 31]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))

print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 0.9181936811995365
# P-value: 0.33794969998195823
# Cramer's V: 0.03217402092601097

# %%
#Radiotherapy
observed_values = np.array([[619, 79], [35, 4]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=False)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 0.04165693407920332
# P-value: 0.8382751168047275
# Cramer's V: 0.007518131324666381

# %%
#Chemtherapy
observed_values = np.array([[101, 591], [3, 36]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 0.9314927037268174
# P-value: 0.33447534711598614
# Cramer's V: 0.03569694419027615

# %%
#Tumor resection
observed_values = np.array([[409, 289, 40], [42, 20, 19]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 37.1799130934931
# P-value: 8.442760175875201e-09
# Cramer's V: 0.2130650588056952

# %%
#Lep_diss
observed_values = np.array([[661, 95], [64, 24]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 12.888141173571483
# P-value: 0.00033067068675871286
# Cramer's V: 0.12357309354127045

# %%
#Recurrence_label_raw
observed_values = np.array([[561, 141], [81, 49]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))

print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 18.31023470757198
# P-value: 1.8769606891365307e-05
# Cramer's V: 0.14834922864278274

# %%
#Recurrence_label_impute
observed_values = np.array([[583, 178], [81, 49]])

chi2, p_value, _, _ = chi2_contingency(observed_values, correction=True)
num_rows, num_columns = observed_values.shape
cramers_v = np.sqrt(chi2 / (np.sum(observed_values) * (min(num_rows, num_columns) - 1)))
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Cramer's V:", cramers_v)
# Out:
# Chi-square statistic: 11.220669398240677
# P-value: 0.0008089131221194667
# Cramer's V: 0.11222006897744569

# %%
# Install lifelines using: pip install lifelines
from lifelines import KaplanMeierFitter
import matplotlib.pyplot as plt

# Sample data (time to event, and event status)
time = [5, 10, 15, 20, 25]
event_status = [1, 1, 0, 1, 0]

# Create a Kaplan-Meier estimator
kmf = KaplanMeierFitter()

# Fit the estimator to the data
kmf.fit(time, event_observed=event_status)

# Plot the survival function
kmf.plot_survival_function()
plt.title("Kaplan-Meier Survival Function")
plt.xlabel("Time")
plt.ylabel("Survival Probability")
plt.show()

# %%
# EastAsia follow-up month
import pandas as pd
from lifelines import KaplanMeierFitter
import matplotlib.pyplot as plt

# Load data from CSV file
file_path = '/Users/huyanshen/Desktop/EastAsia_follow_up.csv'
data = pd.read_csv(file_path)
data = data.dropna()

# Assuming your CSV has columns "time" and "event_status"
time_column = 'time'
event_status_column = 'event_status'

# Map 'Alive' to 1 and 'Disease' to 0
data[event_status_column] = data[event_status_column].map({'Alive': 0, 'Decease': 1})

# Create a Kaplan-Meier estimator
kmf = KaplanMeierFitter()

# Fit the estimator to the data
kmf.fit(durations=data[time_column], event_observed=data[event_status_column])

median_followup_time = data[time_column].median()
median_survival_time = kmf.median_survival_time_

ax = kmf.plot_survival_function()
ax.axvline(x=median_survival_time, color='red', linestyle='--',
           label=f'Median Survival Time: {median_survival_time:.2f} months')
ax.axvline(x=median_followup_time, color='green', linestyle='--',
           label=f'Median Follow-up Time: {median_followup_time:.2f} months')

# Plot the survival function
kmf.plot_survival_function()
plt.title("Kaplan-Meier Survival Function")
plt.xlabel("Time")
plt.ylabel("Survival Probability")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/nj/6hcc0q8x30x74w9dhvw1xz2r0000gn/T/ipykernel_56223/2995387919.py in <module>
#       6 # Load data from CSV file
#       7 file_path = '/Users/huyanshen/Desktop/EastAsia_follow_up.csv'
# ----> 8 data = pd.read_csv(file_path)
#       9 data = data.dropna()
#      10
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# EastAsia follow-up month
import pandas as pd
from lifelines import KaplanMeierFitter
import matplotlib.pyplot as plt

# Load data from CSV file
file_path = '/Users/huyanshen/Desktop/Book1.xlsx'
data = pd.read_excel(file_path)
data = data.dropna()

# Assuming your CSV has columns "time" and "event_status"
time_column = 'time'
event_status_column = 'event_status'

# Map 'Alive' to 1 and 'Disease' to 0
data[event_status_column] = data[event_status_column].map({'Alive': 0, 'Decease': 1})

# Create a Kaplan-Meier estimator
kmf = KaplanMeierFitter()

# Fit the estimator to the data
kmf.fit(durations=data[time_column], event_observed=data[event_status_column])

median_followup_time = data[time_column].median()
median_survival_time = kmf.median_survival_time_

ax = kmf.plot_survival_function()
ax.axvline(x=median_survival_time, color='red', linestyle='--',
           label=f'Median Survival Time: {median_survival_time:.2f} months')
ax.axvline(x=median_followup_time, color='green', linestyle='--',
           label=f'Median Follow-up Time: {median_followup_time:.2f} months')

# Plot the survival function
kmf.plot_survival_function()
plt.title("Kaplan-Meier Survival Function")
plt.xlabel("Time")
plt.ylabel("Survival Probability")
plt.legend()
plt.show()

# %%
# East_Asia
file_path = '/Users/huyanshen/Desktop/EastAsia_follow_up.csv'
data = pd.read_csv(file_path)
data = data.dropna()

# Assuming your CSV has columns "time" and "event_status"
time_column = 'time'
event_status_column = 'event_status'
Modular_column='Molecular_Subtypes'

# Map 'Alive' to 1 and 'Disease' to 0
data[event_status_column] = data[event_status_column].map({'Alive': 0, 'Decease': 1})

# Create a Kaplan-Meier estimator
kmf = KaplanMeierFitter()

plt.figure(figsize=(10, 6))
time_sequence = [0, 10, 20, 30, 40 ,50, 60, 70, 80]

# Fit the estimator to the SHH group
kmf.fit(durations=data[data[Modular_column]=='SHH'][time_column], event_observed=data[data[Modular_column]=='SHH'][event_status_column])
kmf.plot_survival_function(ci_show=False,show_censors=True, label='SHH')

# Fit the estimator to the WNT group
kmf.fit(durations=data[data[Modular_column]=='WNT'][time_column], event_observed=data[data[Modular_column]=='WNT'][event_status_column])
kmf.plot_survival_function(ci_show=False, show_censors=True, label='WNT')

# Fit the estimator to the G3 group
kmf.fit(durations=data[data[Modular_column]=='G3'][time_column], event_observed=data[data[Modular_column]=='G3'][event_status_column])
kmf.plot_survival_function(ci_show = False, show_censors=True, label='G3')

# Fit the estimator to the G4 group
kmf.fit(durations=data[data[Modular_column]=='G4'][time_column], event_observed=data[data[Modular_column]=='G4'][event_status_column])
kmf.plot_survival_function(ci_show = False, show_censors=True, label='G4')

results = logrank_test(durations_A=data[data[Modular_column] == 'SHH'][time_column],
                       durations_B=data[data[Modular_column] == 'WNT'][time_column],
                       duraitons_C=data[data[Modular_column] == 'G3'][time_column],
                       durations_D=data[data[Modular_column] == 'G4'][time_column],
                       event_observed_A=data[data[Modular_column] == 'SHH'][event_status_column],
                       event_observed_B=data[data[Modular_column] == 'WNT'][event_status_column],
                       event_observed_C=data[data[Modular_column] == 'G3'][event_status_column], 
                       event_observed_D=data[data[Modular_column] == 'G4'][event_status_column])

plt.text(0.05, 0.1, 'East Asia', fontsize=25, color='blue',
         bbox=dict(boxstyle='round,pad=0.3', edgecolor='black', facecolor='white'),
         transform=plt.gca().transAxes)
plt.text(0.85, 0.7, f'log-rank\np-value:{results.p_value:.4f} ', fontsize=10, color='black',
         transform=plt.gca().transAxes)
plt.subplots_adjust(wspace=0.8)
plt.title('Kaplan-Meier Survival Curve')
plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.legend()
plt.show()

# %%
# East_Asia
file_path = '/Users/huyanshen/Desktop/EastAsia_follow_up.csv'
data = pd.read_csv(file_path)
data = data.dropna()

# Assuming your CSV has columns "time" and "event_status"
time_column = 'time'
event_status_column = 'event_status'
Modular_column='Molecular_Subtypes'

# Map 'Alive' to 1 and 'Disease' to 0
data[event_status_column] = data[event_status_column].map({'Alive': 0, 'Decease': 1})

# Create a Kaplan-Meier estimator
kmf = KaplanMeierFitter()

plt.figure(figsize=(10, 6))

# Fit the estimator to the G3 group
kmf.fit(durations=data[data[Modular_column]=='G3'][time_column], event_observed=data[data[Modular_column]=='G3'][event_status_column])
kmf.plot_survival_function(ci_show = False, show_censors=True, label='G3')

# Fit the estimator to the G4 group
kmf.fit(durations=data[data[Modular_column]=='G4'][time_column], event_observed=data[data[Modular_column]=='G4'][event_status_column])
kmf.plot_survival_function(ci_show = False, show_censors=True, label='G4')

results = logrank_test(data[data[Modular_column] == 'G3'][time_column],
                       data[data[Modular_column] == 'G4'][time_column],
                       data[data[Modular_column] == 'G3'][event_status_column], 
                       data[data[Modular_column] == 'G4'][event_status_column])

plt.text(0.05, 0.1, 'East Asia', fontsize=25, color='blue',
         bbox=dict(boxstyle='round,pad=0.3', edgecolor='black', facecolor='white'),
         transform=plt.gca().transAxes)
plt.text(0.85, 0.7, f'log-rank\np-value:{results.p_value:.4f} ', fontsize=10, color='black',
         transform=plt.gca().transAxes)

plt.subplots_adjust(wspace=0.8)
plt.title('Kaplan-Meier Survival Curve')
plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.legend()
plt.show()

# %%
from lifelines.statistics import logrank_test
# North America
file_path = '/Users/huyanshen/Desktop/NorthAmerica_followup.csv'
data = pd.read_csv(file_path)
data = data.dropna()

# Assuming your CSV has columns "time" and "event_status"
time_column = 'time'
event_status_column = 'event_status'
Modular_column='Molecular_Subtypes'

# Map 'Alive' to 1 and 'Disease' to 0
data[event_status_column] = data[event_status_column].map({'Alive': 0, 'Decease': 1})

# Create a Kaplan-Meier estimator
kmf = KaplanMeierFitter()

plt.figure(figsize=(10, 6))



# Fit the estimator to the SHH group
kmf.fit(durations=data[data[Modular_column]=='SHH'][time_column], event_observed=data[data[Modular_column]=='SHH'][event_status_column])
kmf.plot_survival_function(ci_show=False,show_censors=True, label='SHH')

# Fit the estimator to the WNT group
kmf.fit(durations=data[data[Modular_column]=='WNT'][time_column], event_observed=data[data[Modular_column]=='WNT'][event_status_column])
kmf.plot_survival_function(ci_show=False, show_censors=True, label='WNT')

# Fit the estimator to the G3 group
kmf.fit(durations=data[data[Modular_column]=='G3'][time_column], event_observed=data[data[Modular_column]=='G3'][event_status_column])
kmf.plot_survival_function(ci_show = False, show_censors=True, label='G3')

# Fit the estimator to the G4 group
kmf.fit(durations=data[data[Modular_column]=='G4'][time_column], event_observed=data[data[Modular_column]=='G4'][event_status_column])
kmf.plot_survival_function(ci_show = False, show_censors=True, label='G4')

results = logrank_test(durations_A=data[data[Modular_column] == 'SHH'][time_column],
                       durations_B=data[data[Modular_column] == 'WNT'][time_column],
                       duraitons_C=data[data[Modular_column] == 'G3'][time_column],
                       durations_D=data[data[Modular_column] == 'G4'][time_column],
                       event_observed_A=data[data[Modular_column] == 'SHH'][event_status_column],
                       event_observed_B=data[data[Modular_column] == 'WNT'][event_status_column],
                       event_observed_C=data[data[Modular_column] == 'G3'][event_status_column], 
                       event_observed_D=data[data[Modular_column] == 'G4'][event_status_column])


plt.text(0.05, 0.1, 'North America', fontsize=25, color='blue',
         bbox=dict(boxstyle='round,pad=0.3', edgecolor='black', facecolor='white'),
         transform=plt.gca().transAxes)
plt.text(0.85, 0.7, f'log-rank\np-value:{results.p_value:.4f} ', fontsize=10, color='black',
         transform=plt.gca().transAxes)
plt.subplots_adjust(wspace=0.8)
plt.title('Kaplan-Meier Survival Curve')
plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.legend()
plt.show()

# %%
# North America
file_path = '/Users/huyanshen/Desktop/NorthAmerica_followup.csv'
data = pd.read_csv(file_path)
data = data.dropna()

# Assuming your CSV has columns "time" and "event_status"
time_column = 'time'
event_status_column = 'event_status'
Modular_column='Molecular_Subtypes'

# Map 'Alive' to 1 and 'Disease' to 0
data[event_status_column] = data[event_status_column].map({'Alive': 0, 'Decease': 1})

# Create a Kaplan-Meier estimator
kmf = KaplanMeierFitter()

plt.figure(figsize=(10, 6))

# Fit the estimator to the G3 group
kmf.fit(durations=data[data[Modular_column]=='G3'][time_column], event_observed=data[data[Modular_column]=='G3'][event_status_column])
kmf.plot_survival_function(ci_show = False, show_censors=True, label='G3')

# Fit the estimator to the G4 group
kmf.fit(durations=data[data[Modular_column]=='G4'][time_column], event_observed=data[data[Modular_column]=='G4'][event_status_column])
kmf.plot_survival_function(ci_show = False, show_censors=True, label='G4')

results = logrank_test(data[data[Modular_column] == 'G3'][time_column],
                       data[data[Modular_column] == 'G4'][time_column],
                       data[data[Modular_column] == 'G3'][event_status_column], 
                       data[data[Modular_column] == 'G4'][event_status_column])

plt.text(0.05, 0.1, 'North America', fontsize=25, color='blue',
         bbox=dict(boxstyle='round,pad=0.3', edgecolor='black', facecolor='white'),
         transform=plt.gca().transAxes)
plt.text(0.85, 0.7, f'log-rank\np-value:{results.p_value:.4f} ', fontsize=10, color='black',
         transform=plt.gca().transAxes)
plt.subplots_adjust(wspace=0.8)
plt.title('Kaplan-Meier Survival Curve')
plt.xlabel('Time')
plt.ylabel('Survival Probability')
plt.legend()
plt.show()

# %%
help(logrank_test)
# Out:
# Help on function logrank_test in module lifelines.statistics:
#
# logrank_test(durations_A, durations_B, event_observed_A=None, event_observed_B=None, t_0=-1, weights_A=None, weights_B=None, weightings=None, **kwargs) -> lifelines.statistics.StatisticalResult
#     Measures and reports on whether two intensity processes are different. That is, given two
#     event series, determines whether the data generating processes are statistically different.
#     The test-statistic is chi-squared under the null hypothesis. Let :math:`h_i(t)` be the hazard ratio of
#     group :math:`i` at time :math:`t`, then:
#
#     .. math::
#         \begin{align}
#          & H_0: h_1(t) = h_2(t) \\
#          & H_A: h_1(t) = c h_2(t), \;\; c \ne 1
#         \end{align}
#
#     This implicitly uses the log-rank weights.
#
#     Note
#     -----
#     - *lifelines* logrank implementation only handles right-censored data.
#
# ...
