# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from tqdm import tqdm

from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline
from lifelines import CoxPHFitter
import shap
import xgboost
import matplotlib.pyplot as plt
import statistics as st
from bayes_opt import BayesianOptimization
from bayes_opt.util import UtilityFunction
from pyirr import intraclass_correlation
from lightgbm import LGBMClassifier
from sklearn.svm import SVC
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
from feature_utils.feature_classfication import data_normalization, data_normalization_apply_cohort1_to_all, lgb_evaluate_lgbm, lgb_evaluate_svm

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from functools import partial
from sklearn.preprocessing import label_binarize

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, roc_auc_score, roc_curve, auc
import sys
import argparse

import csv
import os
# Out:
# /var/folders/nj/6hcc0q8x30x74w9dhvw1xz2r0000gn/T/ipykernel_1917/110702860.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def write_experiment_results_to_csv(file_path, data_dict):
    file_exists = os.path.isfile(file_path)

    with open(file_path, 'a', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=data_dict.keys())

        if not file_exists:
            writer.writeheader()

        writer.writerow(data_dict)

def f1_scores(label_f1, pred_f1, pos_index):
    """
    Calculate f1 score（for bootstrap）
    :param data: data[:, 0] = pred, data[:, 1] = label, data[:, 2] = index
    :return: f1 score
    """
    conf_mat = confusion_matrix(y_true=label_f1, y_pred=pred_f1)

    tp = conf_mat[pos_index][pos_index]
    fp = np.sum(conf_mat[:, pos_index]) - tp
    fn = np.sum(conf_mat[pos_index]) - tp
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1_cls = 2 * precision * recall / (precision + recall)
    return f1_cls

def update_value_ep(x):
    if x < 0.1:
        return 0
    elif 0.1 <= x <= 0.5:
        return 0.5
    else:
        return 1
    
def update_value_age(x):
    """
    年龄的encoding：0-3，3-6，6-9，9-12，12-15，15-18，18+, [0, 0.15, 0.3, 0.45, 0.6, 0.75, 1]
    """
    if x < 3:
        return 0
    elif 3 <= x < 6:
        return 0.15
    elif 6 <= x < 9:
        return 0.3
    elif 9 <= x < 12:
        return 0.45
    elif 12 <= x < 15:
        return 0.6
    elif 15 <= x < 18:
        return 0.75
    else:
        return 1
    
def update_value_dsmn(x):
    """
    转移pattern：C-D-（0）；C-D+（0.25）；C+D-（0.5）；C+NA（0.75）；C+D+（1）
    """
    if x ==0:
        return 0
    elif x==0.25:
        return 1.0
    elif x==0.375:
        return 0.75
    elif x==0.5:
        return 0.5
    elif x==0.75:
        return 0.25
    else:
        return 0
    
class DummyFile(object):
    def write(self, x): pass

# %%
three_cls_path =  '/Users/huyanshen/Desktop/AI-Medicine/Research/PengCheng/Shap_Value_yanshen/ModelComparison/new_3cls_radiomics_new.txt'#args.radiomics_file
three_cls_path_c4 = '/Users/huyanshen/Desktop/AI-Medicine/Research/PengCheng/Shap_Value_yanshen/ModelComparison/new_3cls_radiomics_cohort4_new.txt'#args.radiomics_file_c4
data = pd.read_csv(three_cls_path, sep='\t')
data_c4 = pd.read_csv(three_cls_path_c4, sep='\t')

# %%
wnt_shh_g34_feature_names = ['T1E_log-sigma-3-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis_x',
     'T1E_log-sigma-3-mm-3D_glcm_Autocorrelation_x',
     'T1E_log-sigma-1-mm-3D_glcm_ClusterShade_x',
     'T1E_wavelet-LHL_firstorder_Mean_x',
     'T2_wavelet-LLH_glcm_ClusterShade_y',
     'T1E_log-sigma-5-mm-3D_glrlm_LowGrayLevelRunEmphasis_x',
     'T1E_wavelet-HLL_firstorder_Median_x',
     'T1E_wavelet-LHL_firstorder_Median_x',
     'T2_wavelet-HHL_firstorder_Skewness_x',
     'T1E_log-sigma-3-mm-3D_glrlm_LongRunLowGrayLevelEmphasis_x',
     'T1E_lbp-2D_glrlm_RunLengthNonUniformity_x',
     'T2_log-sigma-1-mm-3D_gldm_LowGrayLevelEmphasis_x',
     'T1E_log-sigma-5-mm-3D_firstorder_90Percentile_x',
     'T1E_log-sigma-3-mm-3D_glszm_LowGrayLevelZoneEmphasis_x',
     'T2_wavelet-HHL_glcm_SumSquares_x',
     'T2_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized_x',
     'T2_wavelet-LLH_gldm_DependenceNonUniformity_x',
     'T2_original_shape_Maximum3DDiameter_y',
     'T2_original_glszm_LargeAreaEmphasis_y']

clinical_feature_names = ''
    
id_val = data[data['Cohort']!=1]['id'].tolist()
id_new = data_c4['id'].tolist()
print('Val id: ', len(id_val))
print('New id: ', len(id_new))
    #['Location','FourthIn','Enhance','Enhance_Percent','Margin','Water','Cyst','Hydro','EpendymalDissemination','3rdVIRDissemination','SuperLMD','InfraLMD','LMDPattern','Ependymal3Dissemination','LMDDissemination','AllDissemination']
clnc_all =['Location','FourthIn','Enhance','Enhance_Percent','Margin','Water','Cyst','Hydro','EpendymalDissemination','3rdVIRDissemination','SuperLMD','InfraLMD','LMDPattern','Ependymal3Dissemination','LMDDissemination','AllDissemination']
# Out:
# Val id:  135
# New id:  44

# %%
sel_columns_basic = ['Cohort','Subtypes_three','fold','Age']
sel_columns = sel_columns_basic + wnt_shh_g34_feature_names

x = data[sel_columns]
x.iloc[:, 4:] = x.iloc[:, 4:].astype(float)
print('total features and labels shape: ', x.shape)
x_new = data_c4[sel_columns]
print(sel_columns, x_new.shape)
x_new.iloc[:, 3:] = x_new.iloc[:, 3:].astype(float)
print('total features and labels shape: ', x.shape)
# Out:
# total features and labels shape:  (649, 23)
# ['Cohort', 'Subtypes_three', 'fold', 'Age', 'T1E_log-sigma-3-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis_x', 'T1E_log-sigma-3-mm-3D_glcm_Autocorrelation_x', 'T1E_log-sigma-1-mm-3D_glcm_ClusterShade_x', 'T1E_wavelet-LHL_firstorder_Mean_x', 'T2_wavelet-LLH_glcm_ClusterShade_y', 'T1E_log-sigma-5-mm-3D_glrlm_LowGrayLevelRunEmphasis_x', 'T1E_wavelet-HLL_firstorder_Median_x', 'T1E_wavelet-LHL_firstorder_Median_x', 'T2_wavelet-HHL_firstorder_Skewness_x', 'T1E_log-sigma-3-mm-3D_glrlm_LongRunLowGrayLevelEmphasis_x', 'T1E_lbp-2D_glrlm_RunLengthNonUniformity_x', 'T2_log-sigma-1-mm-3D_gldm_LowGrayLevelEmphasis_x', 'T1E_log-sigma-5-mm-3D_firstorder_90Percentile_x', 'T1E_log-sigma-3-mm-3D_glszm_LowGrayLevelZoneEmphasis_x', 'T2_wavelet-HHL_glcm_SumSquares_x', 'T2_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized_x', 'T2_wavelet-LLH_gldm_DependenceNonUniformity_x', 'T2_original_shape_Maximum3DDiameter_y', 'T2_original_glszm_LargeAreaEmphasis_y'] (44, 23)
# total features and labels shape:  (649, 23)

# %%
# split base dataset and external validation dataset
df_val = x[(x['Cohort'] == 2) | (x['Cohort'] == 3)]
df_val.reset_index(inplace=True)
X_val = df_val.iloc[:, 4:]

feature_names = X_val.columns.tolist()
X_val = np.array(X_val)
y_val = df_val['Subtypes_three']
y_val = np.array(y_val)
    
df_new = x_new
X_new = df_new.iloc[:, 3:]

feature_names = X_new.columns.tolist()
print(feature_names)
X_new = np.array(X_new)
y_new = df_new['Subtypes_three']
y_new = np.array(y_new)

print('X-val: ', X_val.shape)
print('X-new: ', X_new.shape)

df_X = x[x['Cohort'] == 1]
df_X.reset_index(inplace=True)
folds_indices = {}
# Out:
# ['Age', 'T1E_log-sigma-3-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis_x', 'T1E_log-sigma-3-mm-3D_glcm_Autocorrelation_x', 'T1E_log-sigma-1-mm-3D_glcm_ClusterShade_x', 'T1E_wavelet-LHL_firstorder_Mean_x', 'T2_wavelet-LLH_glcm_ClusterShade_y', 'T1E_log-sigma-5-mm-3D_glrlm_LowGrayLevelRunEmphasis_x', 'T1E_wavelet-HLL_firstorder_Median_x', 'T1E_wavelet-LHL_firstorder_Median_x', 'T2_wavelet-HHL_firstorder_Skewness_x', 'T1E_log-sigma-3-mm-3D_glrlm_LongRunLowGrayLevelEmphasis_x', 'T1E_lbp-2D_glrlm_RunLengthNonUniformity_x', 'T2_log-sigma-1-mm-3D_gldm_LowGrayLevelEmphasis_x', 'T1E_log-sigma-5-mm-3D_firstorder_90Percentile_x', 'T1E_log-sigma-3-mm-3D_glszm_LowGrayLevelZoneEmphasis_x', 'T2_wavelet-HHL_glcm_SumSquares_x', 'T2_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized_x', 'T2_wavelet-LLH_gldm_DependenceNonUniformity_x', 'T2_original_shape_Maximum3DDiameter_y', 'T2_original_glszm_LargeAreaEmphasis_y']
# X-val:  (135, 20)
# X-new:  (44, 20)

# %%
for fold in df_X['fold'].unique():
    test_index = df_X[df_X['fold'] == fold].index
    train_index = df_X[df_X['fold'] != fold].index
    print(len(test_index), len(train_index))
    folds_indices[fold] = {'train_index': train_index, 'test_index': test_index}

X = df_X.iloc[:, 4:]
y = df_X['Subtypes_three']
print('X: ', X.shape)
print('Fold index has been determined!')
    
params_best = []
for i, values in enumerate(folds_indices.values()):
    train_index, test_index = values['train_index'], values['test_index']
    X_test, y_test = X.iloc[test_index], y.iloc[test_index]
    X_train, y_train = X.iloc[train_index], y.iloc[train_index]

    X_train = np.array(X_train)
    X_test = np.array(X_test)

    y_train = np.array(y_train).astype(int)
    y_test = np.array(y_test).astype(int)

    nm = SMOTE(random_state=42)
    X_res, y_res = nm.fit_resample(X_train, y_train)

    print('size of data partitions')
    print('...............INPUT..............OUTPUT..........')
    print('Train      : ', X_train.shape, '         ', y_train.shape, np.sum(y_train))
    print('Test       : ', X_test.shape, '         ', y_test.shape, np.sum(y_test))
    print('Validation : ', X_val.shape, '         ', y_val.shape, np.sum(y_val))
    # bayesian optimization of hyperparameters for lg_boost
    seed = 1
    # use partial to pass train, val and test data
    partial_lgb_evaluate_svm = partial(lgb_evaluate_svm, X_train=X_res, y_train=y_res, X_val=X_val, y_val=y_val,
                                                X_test=X_test, y_test=y_test, multi_cls=True)
    lgb_bo = BayesianOptimization(partial_lgb_evaluate_svm, pbounds={'C' : (0.01, 100)})

    # Optimally needs quite a few more initiation points and number of iterations
    gp_params = {'alpha': 1e-4}
    lgb_bo.set_gp_params(**gp_params)
    acq_f = UtilityFunction(kind="ei", kappa=2.576, xi=0.0)
    lgb_bo.maximize(init_points=200, n_iter=50, acquisition_function=acq_f)

    fold_max = lgb_bo.max['params']
    params_best.append(fold_max)
# Out:
# 172 342
# 170 344
# 172 342
# X:  (514, 20)
# Fold index has been determined!
# size of data partitions
# ...............INPUT..............OUTPUT..........
# Train      :  (342, 20)           (342,) 391
# Test       :  (172, 20)           (172,) 200
# Validation :  (135, 20)           (135,) 156
# |   iter    |  target   |     C     |
# -------------------------------------
# ************************************
# Train AUC       :  0.9945
# Test AUC       :  0.7532
# Validation AUC :  0.7361
# {'C': 92.48184647563461, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 1         | 0.7532    | 92.48     |
# ************************************
# Train AUC       :  0.9771
# Test AUC       :  0.7578
# Validation AUC :  0.7713
# {'C': 19.419810890856056, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 2         | 0.7578    | 19.42     |
# ************************************
# Train AUC       :  0.9903
# Test AUC       :  0.7548
# Validation AUC :  0.7566
# {'C': 53.192341825648214, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 3         | 0.7548    | 53.19     |
# ************************************
# Train AUC       :  0.9792
# Test AUC       :  0.7556
# Validation AUC :  0.7665
# {'C': 21.89943080575407, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 4         | 0.7556    | 21.9      |
# ************************************
# Train AUC       :  0.9533
# Test AUC       :  0.7709
# Validation AUC :  0.784
# {'C': 5.672169528375725, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 5         | 0.7709    | 5.672     |
# ************************************
# Train AUC       :  0.9882
# Test AUC       :  0.7554
# Validation AUC :  0.7644
# {'C': 43.96187169338257, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 6         | 0.7554    | 43.96     |
# ************************************
# Train AUC       :  0.9938
# Test AUC       :  0.7531
# Validation AUC :  0.7362
# {'C': 83.44582705797123, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 7         | 0.7531    | 83.45     |
# ************************************
# Train AUC       :  0.9912
# Test AUC       :  0.7537
# Validation AUC :  0.7518
# {'C': 58.73335287071456, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 8         | 0.7537    | 58.73     |
# ************************************
# Train AUC       :  0.9941
# Test AUC       :  0.7528
# Validation AUC :  0.7378
# {'C': 86.46707842941369, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 9         | 0.7528    | 86.47     |
# ************************************
# Train AUC       :  0.9899
# Test AUC       :  0.7545
# Validation AUC :  0.7559
# {'C': 50.66938382297369, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 10        | 0.7545    | 50.67     |
# ************************************
# Train AUC       :  0.9774
# Test AUC       :  0.7548
# Validation AUC :  0.768
# {'C': 20.222930915322713, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 11        | 0.7548    | 20.22     |
# ************************************
# Train AUC       :  0.9935
# Test AUC       :  0.7536
# Validation AUC :  0.7416
# {'C': 79.56412579144951, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 12        | 0.7536    | 79.56     |
# ************************************
# Train AUC       :  0.9727
# Test AUC       :  0.7602
# Validation AUC :  0.779
# {'C': 14.799798862009379, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 13        | 0.7602    | 14.8      |
# ************************************
# Train AUC       :  0.9935
# Test AUC       :  0.7553
# Validation AUC :  0.7431
# {'C': 79.479944171955, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 14        | 0.7553    | 79.48     |
# ************************************
# Train AUC       :  0.9823
# Test AUC       :  0.7562
# Validation AUC :  0.7625
# {'C': 28.313627046759787, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 15        | 0.7562    | 28.31     |
# ************************************
# Train AUC       :  0.9917
# Test AUC       :  0.7552
# Validation AUC :  0.7511
# {'C': 63.2724454271758, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 16        | 0.7552    | 63.27     |
# ************************************
# Train AUC       :  0.994
# Test AUC       :  0.7544
# Validation AUC :  0.7364
# {'C': 86.16920467090011, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 17        | 0.7544    | 86.17     |
# ************************************
# Train AUC       :  0.982
# Test AUC       :  0.7555
# Validation AUC :  0.7614
# {'C': 27.40027430754297, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 18        | 0.7555    | 27.4      |
# ************************************
# Train AUC       :  0.9926
# Test AUC       :  0.7545
# Validation AUC :  0.7444
# {'C': 70.81932627968737, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 19        | 0.7545    | 70.82     |
# ************************************
# Train AUC       :  0.9546
# Test AUC       :  0.7682
# Validation AUC :  0.7867
# {'C': 6.133268173383144, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 20        | 0.7682    | 6.133     |
# ************************************
# Train AUC       :  0.9947
# Test AUC       :  0.7525
# Validation AUC :  0.7407
# {'C': 96.55268952083861, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 21        | 0.7525    | 96.55     |
# ************************************
# Train AUC       :  0.9934
# Test AUC       :  0.7539
# Validation AUC :  0.7434
# {'C': 80.19712761511221, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 22        | 0.7539    | 80.2      |
# ************************************
# Train AUC       :  0.9911
# Test AUC       :  0.7536
# Validation AUC :  0.7527
# {'C': 58.24793648761383, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 23        | 0.7536    | 58.25     |
# ************************************
# Train AUC       :  0.9949
# Test AUC       :  0.7517
# Validation AUC :  0.7389
# {'C': 98.14797202932914, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 24        | 0.7517    | 98.15     |
# ************************************
# Train AUC       :  0.9679
# Test AUC       :  0.7624
# Validation AUC :  0.785
# {'C': 11.548684295809906, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 25        | 0.7624    | 11.55     |
# ************************************
# Train AUC       :  0.9945
# Test AUC       :  0.7527
# Validation AUC :  0.7349
# {'C': 92.8624207871916, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 26        | 0.7527    | 92.86     |
# ************************************
# Train AUC       :  0.992
# Test AUC       :  0.7536
# Validation AUC :  0.7476
# {'C': 66.10019983447924, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 27        | 0.7536    | 66.1      |
# ************************************
# Train AUC       :  0.991
# Test AUC       :  0.7551
# Validation AUC :  0.7551
# {'C': 57.37622982229722, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 28        | 0.7551    | 57.38     |
# ************************************
# Train AUC       :  0.9895
# Test AUC       :  0.7554
# Validation AUC :  0.7566
# {'C': 48.93260175271975, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 29        | 0.7554    | 48.93     |
# ************************************
# Train AUC       :  0.9932
# Test AUC       :  0.7523
# Validation AUC :  0.7422
# {'C': 76.62412577902352, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 30        | 0.7523    | 76.62     |
# ************************************
# Train AUC       :  0.9908
# Test AUC       :  0.7541
# Validation AUC :  0.7551
# {'C': 56.22240620940301, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 31        | 0.7541    | 56.22     |
# ************************************
# Train AUC       :  0.9912
# Test AUC       :  0.7516
# Validation AUC :  0.7524
# {'C': 61.62206281939559, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 32        | 0.7516    | 61.62     |
# ************************************
# Train AUC       :  0.9859
# Test AUC       :  0.7567
# Validation AUC :  0.7586
# {'C': 38.32454254933127, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 33        | 0.7567    | 38.32     |
# ************************************
# Train AUC       :  0.9942
# Test AUC       :  0.7531
# Validation AUC :  0.7361
# {'C': 88.54063716260912, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 34        | 0.7531    | 88.54     |
# ************************************
# Train AUC       :  0.9326
# Test AUC       :  0.7786
# Validation AUC :  0.7774
# {'C': 1.855807695696554, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 35        | 0.7786    | 1.856     |
# ************************************
# Train AUC       :  0.9928
# Test AUC       :  0.7547
# Validation AUC :  0.7447
# {'C': 72.3174604399116, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 36        | 0.7547    | 72.32     |
# ************************************
# Train AUC       :  0.9618
# Test AUC       :  0.764
# Validation AUC :  0.7891
# {'C': 8.686136113708613, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 37        | 0.764     | 8.686     |
# ************************************
# Train AUC       :  0.9944
# Test AUC       :  0.7518
# Validation AUC :  0.7371
# {'C': 90.95312891999694, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 38        | 0.7518    | 90.95     |
# ************************************
# Train AUC       :  0.9754
# Test AUC       :  0.7588
# Validation AUC :  0.7718
# {'C': 17.848424772104995, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 39        | 0.7588    | 17.85     |
# ************************************
# Train AUC       :  0.991
# Test AUC       :  0.7545
# Validation AUC :  0.7533
# {'C': 57.21989547954205, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 40        | 0.7545    | 57.22     |
# ************************************
# Train AUC       :  0.9905
# Test AUC       :  0.755
# Validation AUC :  0.7594
# {'C': 54.21247175265952, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 41        | 0.755     | 54.21     |
# ************************************
# Train AUC       :  0.9816
# Test AUC       :  0.7569
# Validation AUC :  0.7604
# {'C': 26.5427339895161, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 42        | 0.7569    | 26.54     |
# ************************************
# Train AUC       :  0.99
# Test AUC       :  0.7538
# Validation AUC :  0.7562
# {'C': 51.05778581258046, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 43        | 0.7538    | 51.06     |
# ************************************
# Train AUC       :  0.972
# Test AUC       :  0.7602
# Validation AUC :  0.777
# {'C': 14.817914246702019, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 44        | 0.7602    | 14.82     |
# ************************************
# Train AUC       :  0.9909
# Test AUC       :  0.7546
# Validation AUC :  0.7525
# {'C': 55.497383983333435, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 45        | 0.7546    | 55.5      |
# ************************************
# Train AUC       :  0.973
# Test AUC       :  0.761
# Validation AUC :  0.7776
# {'C': 15.20925871695918, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 46        | 0.761     | 15.21     |
# ************************************
# Train AUC       :  0.9948
# Test AUC       :  0.7535
# Validation AUC :  0.7364
# {'C': 97.53244760567382, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 47        | 0.7535    | 97.53     |
# ************************************
# Train AUC       :  0.9871
# Test AUC       :  0.7563
# Validation AUC :  0.7585
# {'C': 41.390628358333224, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 48        | 0.7563    | 41.39     |
# ************************************
# Train AUC       :  0.9937
# Test AUC       :  0.7531
# Validation AUC :  0.7379
# {'C': 82.19442418190984, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 49        | 0.7531    | 82.19     |
# ************************************
# Train AUC       :  0.9911
# Test AUC       :  0.7531
# Validation AUC :  0.7512
# {'C': 59.46188663341054, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 50        | 0.7531    | 59.46     |
# ************************************
# Train AUC       :  0.9949
# Test AUC       :  0.7519
# Validation AUC :  0.7378
# {'C': 98.67426518797036, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 51        | 0.7519    | 98.67     |
# ************************************
# Train AUC       :  0.9913
# Test AUC       :  0.753
# Validation AUC :  0.7547
# {'C': 61.58072558736208, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 52        | 0.753     | 61.58     |
# ************************************
# Train AUC       :  0.9922
# Test AUC       :  0.7545
# Validation AUC :  0.7451
# {'C': 67.91670199329873, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 53        | 0.7545    | 67.92     |
# ************************************
# Train AUC       :  0.9626
# Test AUC       :  0.7645
# Validation AUC :  0.7892
# {'C': 9.112425890576755, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 54        | 0.7645    | 9.112     |
# ************************************
# Train AUC       :  0.995
# Test AUC       :  0.752
# Validation AUC :  0.7358
# {'C': 99.43625883618236, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 55        | 0.752     | 99.44     |
# ************************************
# Train AUC       :  0.9728
# Test AUC       :  0.7599
# Validation AUC :  0.7769
# {'C': 15.630471224723998, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 56        | 0.7599    | 15.63     |
# ************************************
# Train AUC       :  0.9854
# Test AUC       :  0.7551
# Validation AUC :  0.7628
# {'C': 38.131476605850615, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 57        | 0.7551    | 38.13     |
# ************************************
# Train AUC       :  0.995
# Test AUC       :  0.7516
# Validation AUC :  0.7353
# {'C': 98.25883310505327, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 58        | 0.7516    | 98.26     |
# ************************************
# Train AUC       :  0.9917
# Test AUC       :  0.7535
# Validation AUC :  0.7488
# {'C': 62.85108372835251, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 59        | 0.7535    | 62.85     |
# ************************************
# Train AUC       :  0.9944
# Test AUC       :  0.7521
# Validation AUC :  0.7395
# {'C': 90.85920549202271, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 60        | 0.7521    | 90.86     |
# ************************************
# Train AUC       :  0.9911
# Test AUC       :  0.7539
# Validation AUC :  0.7572
# {'C': 56.78453635473787, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 61        | 0.7539    | 56.78     |
# ************************************
# Train AUC       :  0.9604
# Test AUC       :  0.7637
# Validation AUC :  0.789
# {'C': 8.120708379886466, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 62        | 0.7637    | 8.121     |
# ************************************
# Train AUC       :  0.9912
# Test AUC       :  0.7553
# Validation AUC :  0.7586
# {'C': 56.73047036951552, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 63        | 0.7553    | 56.73     |
# ************************************
# Train AUC       :  0.9819
# Test AUC       :  0.7535
# Validation AUC :  0.7595
# {'C': 27.85703694826443, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 64        | 0.7535    | 27.86     |
# ************************************
# Train AUC       :  0.9827
# Test AUC       :  0.7558
# Validation AUC :  0.7604
# {'C': 29.293064408180644, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 65        | 0.7558    | 29.29     |
# ************************************
# Train AUC       :  0.9913
# Test AUC       :  0.7532
# Validation AUC :  0.7528
# {'C': 60.443004860933904, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 66        | 0.7532    | 60.44     |
# ************************************
# Train AUC       :  0.9854
# Test AUC       :  0.7576
# Validation AUC :  0.7595
# {'C': 36.32201256582708, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 67        | 0.7576    | 36.32     |
# ************************************
# Train AUC       :  0.9774
# Test AUC       :  0.7563
# Validation AUC :  0.771
# {'C': 19.65129484980472, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 68        | 0.7563    | 19.65     |
# ************************************
# Train AUC       :  0.938
# Test AUC       :  0.7825
# Validation AUC :  0.7768
# {'C': 2.4703338324075346, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 69        | 0.7825    | 2.47      |
# ************************************
# Train AUC       :  0.9894
# Test AUC       :  0.7554
# Validation AUC :  0.76
# {'C': 49.06568571122866, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 70        | 0.7554    | 49.07     |
# ************************************
# Train AUC       :  0.9741
# Test AUC       :  0.7606
# Validation AUC :  0.7744
# {'C': 16.315019483459388, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 71        | 0.7606    | 16.32     |
# ************************************
# Train AUC       :  0.9896
# Test AUC       :  0.7557
# Validation AUC :  0.7628
# {'C': 48.243842210181796, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 72        | 0.7557    | 48.24     |
# ************************************
# Train AUC       :  0.9801
# Test AUC       :  0.7549
# Validation AUC :  0.7639
# {'C': 23.85921254934316, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 73        | 0.7549    | 23.86     |
# ************************************
# Train AUC       :  0.9798
# Test AUC       :  0.7538
# Validation AUC :  0.766
# {'C': 23.476101780433748, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 74        | 0.7538    | 23.48     |
# ************************************
# Train AUC       :  0.993
# Test AUC       :  0.7543
# Validation AUC :  0.7441
# {'C': 74.9349381334752, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 75        | 0.7543    | 74.93     |
# ************************************
# Train AUC       :  0.9652
# Test AUC       :  0.7651
# Validation AUC :  0.7899
# {'C': 9.871307976651467, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 76        | 0.7651    | 9.871     |
# ************************************
# Train AUC       :  0.9903
# Test AUC       :  0.7551
# Validation AUC :  0.7536
# {'C': 51.15010523170407, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 77        | 0.7551    | 51.15     |
# ************************************
# Train AUC       :  0.9946
# Test AUC       :  0.7529
# Validation AUC :  0.7364
# {'C': 94.05345497262317, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 78        | 0.7529    | 94.05     |
# ************************************
# Train AUC       :  0.9948
# Test AUC       :  0.752
# Validation AUC :  0.7359
# {'C': 95.81753678712835, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 79        | 0.752     | 95.82     |
# ************************************
# Train AUC       :  0.96
# Test AUC       :  0.7647
# Validation AUC :  0.7898
# {'C': 7.9468498058610555, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 80        | 0.7647    | 7.947     |
# ************************************
# Train AUC       :  0.993
# Test AUC       :  0.7527
# Validation AUC :  0.7436
# {'C': 74.53372576357012, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 81        | 0.7527    | 74.53     |
# ************************************
# Train AUC       :  0.9795
# Test AUC       :  0.7556
# Validation AUC :  0.7652
# {'C': 22.935306044533665, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 82        | 0.7556    | 22.94     |
# ************************************
# Train AUC       :  0.9907
# Test AUC       :  0.754
# Validation AUC :  0.7525
# {'C': 54.004835347191445, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 83        | 0.754     | 54.0      |
# ************************************
# Train AUC       :  0.995
# Test AUC       :  0.7535
# Validation AUC :  0.7333
# {'C': 99.6274099984213, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 84        | 0.7535    | 99.63     |
# ************************************
# Train AUC       :  0.9902
# Test AUC       :  0.7547
# Validation AUC :  0.7561
# {'C': 51.84211736054818, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 85        | 0.7547    | 51.84     |
# ************************************
# Train AUC       :  0.994
# Test AUC       :  0.7527
# Validation AUC :  0.7363
# {'C': 85.86667037417963, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 86        | 0.7527    | 85.87     |
# ************************************
# Train AUC       :  0.994
# Test AUC       :  0.7539
# Validation AUC :  0.7387
# {'C': 86.0041370261443, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 87        | 0.7539    | 86.0      |
# ************************************
# Train AUC       :  0.9875
# Test AUC       :  0.7564
# Validation AUC :  0.7599
# {'C': 41.91377504703386, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 88        | 0.7564    | 41.91     |
# ************************************
# Train AUC       :  0.9949
# Test AUC       :  0.7511
# Validation AUC :  0.7337
# {'C': 97.75998563301994, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 89        | 0.7511    | 97.76     |
# ************************************
# Train AUC       :  0.9797
# Test AUC       :  0.7543
# Validation AUC :  0.7661
# {'C': 23.611392564101013, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 90        | 0.7543    | 23.61     |
# ************************************
# Train AUC       :  0.9862
# Test AUC       :  0.7576
# Validation AUC :  0.7598
# {'C': 38.63837563186992, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 91        | 0.7576    | 38.64     |
# ************************************
# Train AUC       :  0.9911
# Test AUC       :  0.7531
# Validation AUC :  0.7512
# {'C': 59.21604559180682, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 92        | 0.7531    | 59.22     |
# ************************************
# Train AUC       :  0.9916
# Test AUC       :  0.7526
# Validation AUC :  0.754
# {'C': 62.79216484196566, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 93        | 0.7526    | 62.79     |
# ************************************
# Train AUC       :  0.9836
# Test AUC       :  0.7566
# Validation AUC :  0.7627
# {'C': 31.673283369249653, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 94        | 0.7566    | 31.67     |
# ************************************
# Train AUC       :  0.9624
# Test AUC       :  0.7633
# Validation AUC :  0.7888
# {'C': 8.936637223275602, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 95        | 0.7633    | 8.937     |
# ************************************
# Train AUC       :  0.9346
# Test AUC       :  0.7791
# Validation AUC :  0.7767
# {'C': 1.9922188557382412, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 96        | 0.7791    | 1.992     |
# ************************************
# Train AUC       :  0.9925
# Test AUC       :  0.7553
# Validation AUC :  0.748
# {'C': 70.31648741883166, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 97        | 0.7553    | 70.32     |
# ************************************
# Train AUC       :  0.9947
# Test AUC       :  0.7535
# Validation AUC :  0.7347
# {'C': 96.57623311547385, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 98        | 0.7535    | 96.58     |
# ************************************
# Train AUC       :  0.9944
# Test AUC       :  0.7537
# Validation AUC :  0.7367
# {'C': 90.62187014375753, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 99        | 0.7537    | 90.62     |
# ************************************
# Train AUC       :  0.9904
# Test AUC       :  0.7555
# Validation AUC :  0.754
# {'C': 52.16441240148184, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 100       | 0.7555    | 52.16     |
# ************************************
# Train AUC       :  0.9877
# Test AUC       :  0.7565
# Validation AUC :  0.7598
# {'C': 42.24168833540342, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 101       | 0.7565    | 42.24     |
# ************************************
# Train AUC       :  0.9655
# Test AUC       :  0.7638
# Validation AUC :  0.7883
# {'C': 10.32752884760325, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 102       | 0.7638    | 10.33     |
# ************************************
# Train AUC       :  0.9925
# Test AUC       :  0.7517
# Validation AUC :  0.7458
# {'C': 72.17282583253484, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 103       | 0.7517    | 72.17     |
# ************************************
# Train AUC       :  0.9686
# Test AUC       :  0.7621
# Validation AUC :  0.785
# {'C': 11.877162530084, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 104       | 0.7621    | 11.88     |
# ************************************
# Train AUC       :  0.952
# Test AUC       :  0.772
# Validation AUC :  0.7818
# {'C': 5.305814283203333, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 105       | 0.772     | 5.306     |
# ************************************
# Train AUC       :  0.9913
# Test AUC       :  0.7527
# Validation AUC :  0.7506
# {'C': 59.41149547946553, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# ...
# | 215       | 0.8223    | 6.55      |
# ************************************
# Train AUC       :  0.939
# Test AUC       :  0.8352
# Validation AUC :  0.7657
# {'C': 4.276695810348869, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 216       | 0.8352    | 4.277     |
# ************************************
# Train AUC       :  0.9423
# Test AUC       :  0.8316
# Validation AUC :  0.7633
# {'C': 4.875348739403902, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 217       | 0.8316    | 4.875     |
# ************************************
# Train AUC       :  0.9458
# Test AUC       :  0.8279
# Validation AUC :  0.7629
# {'C': 5.468322891609975, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 218       | 0.8279    | 5.468     |
# ************************************
# Train AUC       :  0.9091
# Test AUC       :  0.8559
# Validation AUC :  0.7776
# {'C': 1.1243992668707241, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 219       | 0.8559    | 1.124     |
# ************************************
# Train AUC       :  0.9594
# Test AUC       :  0.8145
# Validation AUC :  0.7628
# {'C': 10.002922291186287, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 220       | 0.8145    | 10.0      |
# ************************************
# Train AUC       :  0.9581
# Test AUC       :  0.8152
# Validation AUC :  0.7637
# {'C': 9.413143380717363, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 221       | 0.8152    | 9.413     |
# ************************************
# Train AUC       :  0.9102
# Test AUC       :  0.856
# Validation AUC :  0.7779
# {'C': 1.1969927519180321, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 222       | 0.856     | 1.197     |
# ************************************
# Train AUC       :  0.9084
# Test AUC       :  0.8564
# Validation AUC :  0.7782
# {'C': 1.080672722078291, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 223       | 0.8564    | 1.081     |
# ************************************
# Train AUC       :  0.9082
# Test AUC       :  0.857
# Validation AUC :  0.7791
# {'C': 1.0684258931800605, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 224       | 0.857     | 1.068     |
# ************************************
# Train AUC       :  0.9783
# Test AUC       :  0.7953
# Validation AUC :  0.737
# {'C': 21.72257493944752, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 225       | 0.7953    | 21.72     |
# ************************************
# Train AUC       :  0.9693
# Test AUC       :  0.8055
# Validation AUC :  0.7524
# {'C': 14.33346503684825, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 226       | 0.8055    | 14.33     |
# ************************************
# Train AUC       :  0.9955
# Test AUC       :  0.7659
# Validation AUC :  0.7054
# {'C': 98.61802017023079, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 227       | 0.7659    | 98.62     |
# ************************************
# Train AUC       :  0.9887
# Test AUC       :  0.7828
# Validation AUC :  0.7149
# {'C': 45.101553662373895, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 228       | 0.7828    | 45.1      |
# ************************************
# Train AUC       :  0.9954
# Test AUC       :  0.7665
# Validation AUC :  0.7083
# {'C': 96.48698284410148, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 229       | 0.7665    | 96.49     |
# ************************************
# Train AUC       :  0.9943
# Test AUC       :  0.7676
# Validation AUC :  0.709
# {'C': 78.53679580310752, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 230       | 0.7676    | 78.54     |
# ************************************
# Train AUC       :  0.9813
# Test AUC       :  0.7914
# Validation AUC :  0.7333
# {'C': 25.42610442617368, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 231       | 0.7914    | 25.43     |
# ************************************
# Train AUC       :  0.9951
# Test AUC       :  0.7601
# Validation AUC :  0.7079
# {'C': 90.96969272443162, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 232       | 0.7601    | 90.97     |
# ************************************
# Train AUC       :  0.9609
# Test AUC       :  0.8149
# Validation AUC :  0.7613
# {'C': 10.43695338977964, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 233       | 0.8149    | 10.44     |
# ************************************
# Train AUC       :  0.908
# Test AUC       :  0.856
# Validation AUC :  0.7795
# {'C': 1.0487088147556793, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 234       | 0.856     | 1.049     |
# ************************************
# Train AUC       :  0.9947
# Test AUC       :  0.7651
# Validation AUC :  0.7058
# {'C': 85.79146849980984, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 235       | 0.7651    | 85.79     |
# ************************************
# Train AUC       :  0.9257
# Test AUC       :  0.8452
# Validation AUC :  0.7694
# {'C': 2.4714475668451064, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 236       | 0.8452    | 2.471     |
# ************************************
# Train AUC       :  0.9878
# Test AUC       :  0.7759
# Validation AUC :  0.7169
# {'C': 41.63409622460177, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 237       | 0.7759    | 41.63     |
# ************************************
# Train AUC       :  0.9872
# Test AUC       :  0.7804
# Validation AUC :  0.7224
# {'C': 37.970572898888484, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 238       | 0.7804    | 37.97     |
# ************************************
# Train AUC       :  0.9407
# Test AUC       :  0.8323
# Validation AUC :  0.7633
# {'C': 4.573308252426177, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 239       | 0.8323    | 4.573     |
# ************************************
# Train AUC       :  0.9471
# Test AUC       :  0.8266
# Validation AUC :  0.7639
# {'C': 5.7802205186621745, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 240       | 0.8266    | 5.78      |
# ************************************
# Train AUC       :  0.9913
# Test AUC       :  0.7749
# Validation AUC :  0.7136
# {'C': 56.01017031094839, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 241       | 0.7749    | 56.01     |
# ************************************
# Train AUC       :  0.9018
# Test AUC       :  0.8539
# Validation AUC :  0.7784
# {'C': 0.7469446179319171, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 242       | 0.8539    | 0.7469    |
# ************************************
# Train AUC       :  0.9939
# Test AUC       :  0.7637
# Validation AUC :  0.7118
# {'C': 74.25285686523254, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 243       | 0.7637    | 74.25     |
# ************************************
# Train AUC       :  0.9745
# Test AUC       :  0.7985
# Validation AUC :  0.7422
# {'C': 18.425671586222037, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 244       | 0.7985    | 18.43     |
# ************************************
# Train AUC       :  0.9295
# Test AUC       :  0.8428
# Validation AUC :  0.767
# {'C': 2.950372212564419, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 245       | 0.8428    | 2.95      |
# ************************************
# Train AUC       :  0.9867
# Test AUC       :  0.7817
# Validation AUC :  0.7231
# {'C': 35.93386569579629, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 246       | 0.7817    | 35.93     |
# ************************************
# Train AUC       :  0.909
# Test AUC       :  0.8569
# Validation AUC :  0.7788
# {'C': 1.109949288643262, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 247       | 0.8569    | 1.11      |
# ************************************
# Train AUC       :  0.909
# Test AUC       :  0.8565
# Validation AUC :  0.7784
# {'C': 1.1143431571790474, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 248       | 0.8565    | 1.114     |
# ************************************
# Train AUC       :  0.909
# Test AUC       :  0.8565
# Validation AUC :  0.7782
# {'C': 1.1186480177730431, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 249       | 0.8565    | 1.119     |
# ************************************
# Train AUC       :  0.9129
# Test AUC       :  0.8556
# Validation AUC :  0.7748
# {'C': 1.360041374242364, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 250       | 0.8556    | 1.36      |
# =====================================

# %%
def bootstrap(true, pred, B, c, func, **args):
    """
    计算 bootstrap 置信区间
    :param data: array 保存样本数据
    :param B: 抽样次数 通常 B>=1000
    :param c: 置信水平
    :param func: 样本估计量
    :return: bootstrap置信区间上下限
    """
    array = np.array(true)
    n = len(array)
    sample_result_arr = []
    for i in range(B):
        index_arr = np.random.randint(0, n, size=n)
        data_sample_real = true[index_arr]
        data_sample_pred = pred[index_arr]
        sample_result = func(data_sample_real, data_sample_pred, **args)
        sample_result_arr.append(sample_result)
    a = 1 - c
    k1 = int(B * a / 2)
    k2 = int(B * (1 - a / 2))
    auc_sample_arr_sorted = sorted(sample_result_arr)
    lower = auc_sample_arr_sorted[k1]
    higher = auc_sample_arr_sorted[k2]
    return (lower, higher)

#print("f1 score(95%CI):{}{}".format(f1_score(y_test, l_lg_test, average='weighted'),np.round(bootstrap(y_test, l_lg_test, 1000, 0.95, f1_score, average='weighted'), decimals=4)))
#print("AUC CI(95%CI):{}{}".format(roc_auc_score(y_test, p_lg_test, multi_class='ovr'), bootstrap(y_test, p_lg_test, 1000, 0.95, roc_auc_score, multi_class='ovr')))

# %%
test_folds = []
test_gt_folds = []
val_folds = []
true_folds = []
pred_folds = []
cm_folds = []
f1_test_folds = []
auc_test_folds = []
accuracy_test_folds = []
new_folds = []
f1_test_CI_folds = []
auc_test_CI_folds = []
accuracy_test_CI_folds = []

for i, values in enumerate(folds_indices.values()):
    train_index, test_index = values['train_index'], values['test_index']
    X_train, y_train = X.iloc[train_index], y.iloc[train_index]
    X_test, y_test = X.iloc[test_index], y.iloc[test_index]

    X_train = np.array(X_train)
    X_test = np.array(X_test)

    y_train = np.array(y_train).astype(int)
    y_test = np.array(y_test).astype(int)

    X_train, y_train = X.iloc[train_index], y.iloc[train_index]
    X_test, y_test = X.iloc[test_index], y.iloc[test_index]

    X_train = np.array(X_train)
    X_test = np.array(X_test)

    y_train = np.array(y_train).astype(int)
    y_test = np.array(y_test).astype(int)

    nm = SMOTE(random_state=42)
    X_res, y_res = nm.fit_resample(X_train, y_train)

    params_cur = params_best[i]
    modelsvc = SVC(probability=True)
    modelsvc.set_params(**params_cur)
    clf_lg = modelsvc.fit(X_res, y_res)
    p_lg_train = clf_lg.predict_proba(X_res)  # [:,1]
    p_lg_test = clf_lg.predict_proba(X_test)  # [:,1]
    p_lg_val = clf_lg.predict_proba(X_val)  # [:,1]
    p_lg_new = clf_lg.predict_proba(X_new)  # [:,1]

    val_folds.append(p_lg_val)
    test_folds.append(p_lg_test)
    test_gt_folds.append(y_test)
    new_folds.append(p_lg_new)

    l_lg_train = clf_lg.predict(X_res)
    l_lg_test = clf_lg.predict(X_test)
    l_lg_val = clf_lg.predict(X_val)
    l_lg_new = clf_lg.predict(X_new)

    accuracy_train = accuracy_score(y_res, l_lg_train)
    accuracy_test = accuracy_score(y_test, l_lg_test)
    accuracy_val = accuracy_score(y_val, l_lg_val)
    accuracy_new = accuracy_score(y_new, l_lg_new)
    accuracy_test_folds.append(accuracy_test)
    accuracy_test_CI_folds.append(bootstrap(y_test, l_lg_test, 3000, 0.95, accuracy_score))

    f1_train = f1_score(y_res, l_lg_train, average='weighted')
    f1_test = f1_score(y_test, l_lg_test, average='weighted')
    f1_val = f1_score(y_val, l_lg_val, average='weighted')
    f1_new = f1_score(y_new, l_lg_new, average='weighted')
    f1_test_folds.append(f1_test)
    f1_test_CI_folds.append(bootstrap(y_test, l_lg_test, 3000, 0.95,f1_score, average='weighted'))

    true_folds.append(y_test)
    pred_folds.append(l_lg_test)

    lg_auc_train = roc_auc_score(y_res, p_lg_train, multi_class='ovr')
    lg_auc_test = roc_auc_score(y_test, p_lg_test, multi_class='ovr')
    lg_auc_val = roc_auc_score(y_val, p_lg_val, multi_class='ovr')
    lg_auc_new = roc_auc_score(y_new, p_lg_new, multi_class='ovr')
    auc_test_folds.append(lg_auc_test)
    auc_test_CI_folds.append(bootstrap(y_test, p_lg_test, 3000, 0.95,roc_auc_score, multi_class='ovr'))

    cm_test = confusion_matrix(y_test, l_lg_test)
    cm_folds.append(cm_test)

# %%
(len(pred_folds[0]),len(pred_folds[1]),len(pred_folds[2])),(len(test_folds[0]),len(test_folds[1]),len(test_folds[2]))
# Out:
# ((172, 170, 172), (172, 170, 172))

# %%
all_val_folds = np.stack(val_folds)
all_new_folds = np.stack(new_folds)

mean_folds = np.mean(all_val_folds, axis=0)
mean_new_folds = np.mean(all_new_folds, axis=0)

experiment_name = 'Age_Radio'

# %%
from datetime import datetime

# 获取当前时间
now = datetime.now()

# 格式化时间为 MMDDHHMM 格式
timestamp = now.strftime("%m%d%H%M")
csv_result = '/Users/huyanshen/Desktop/AI-Medicine/Research/PengCheng/Shap_Value_yanshen/ModelComparison/SVM_result/results.csv'
original_stdout = sys.stdout

with open(csv_result.replace('results.csv', experiment_name + '_' + timestamp + '.txt'), 'w') as f:
    sys.stdout = f
    print('-------------Features---------------')
    print(sel_columns)

    print('-------------Testing----------------')
    all_test_folds = np.vstack(test_folds)
    gt_test = np.concatenate(test_gt_folds)
    print('All_test_folds: ', all_test_folds.shape)

    all_l_test_folds = np.concatenate(pred_folds)
    lg_accuracy_test = accuracy_score(gt_test, all_l_test_folds)
    lg_accuracy_CI_test = bootstrap(gt_test, all_l_test_folds, 3000, 0.95, accuracy_score)
    print(f'Test Accuracy: {np.round(lg_accuracy_test, decimals=4)} {tuple(np.round(lg_accuracy_CI_test, decimals=4))}')


    lg_auc_test = roc_auc_score(gt_test, all_test_folds, multi_class='ovr')
    lg_auc_CI_test = bootstrap(gt_test, all_test_folds, 3000, 0.95, roc_auc_score, multi_class='ovr')
    print('Test AUC : {} {}'.format(np.round(lg_auc_test, decimals=4), tuple(np.round(lg_auc_CI_test, decimals=4))))
    AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(auc_test_folds, decimals=4), np.round(auc_test_CI_folds, decimals=4))]
    print('Test AUC: ', AUC_format, '(per fold)')

    # Binarize the true labels to use with roc_auc_score
    y_test_binarized = label_binarize(gt_test, classes=[0, 1, 2])
    aucs_test = []
    aucs_CI_test = []
    for i in range(3):
        auc_test = roc_auc_score(y_test_binarized[:, i], np.array(all_test_folds)[:, i])
        auc_CI_test = bootstrap(y_test_binarized[:, i], np.array(all_test_folds)[:, i], 3000, 0.95, roc_auc_score, multi_class='ovr')
        aucs_test.append(auc_test)
        aucs_CI_test.append(auc_CI_test)
    AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(aucs_test, decimals=4), np.round(aucs_CI_test, decimals=4))]
    print('Test AUC : ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')

    f1_test = f1_score(gt_test, np.argmax(all_test_folds, axis=1), average='weighted')
    f1_CI_test = bootstrap(gt_test, np.argmax(all_test_folds, axis=1), 3000, 0.95, f1_score, average='weighted')
    print('Test F1 score: {} {}'.format(np.round(f1_test, decimals=4), tuple(np.round(f1_CI_test, decimals=4))))
    AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(f1_test_folds, decimals=4), np.round(f1_test_CI_folds, decimals=4))]
    print('Test F1 score: ', AUC_format, '(per fold)')
    test_f1_per_subtype = [np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=0), decimals=4),
                            np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=1), decimals=4),
                            np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=2), decimals=4)]
    test_f1_CI_per_subtype = [np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=0), decimals=4),
                            np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=1), decimals=4),
                            np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=2), decimals=4)]
    AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(test_f1_per_subtype, decimals=4), np.round(test_f1_CI_per_subtype, decimals=4))]
    print('Test F1 score: ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')

    cm_test = confusion_matrix(gt_test, np.argmax(all_test_folds, axis=1))
    print('Test Confusion Matrix: ')
    print(cm_test)
    #disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_val)
    #disp1.plot()

    print('-----------Validation--------------')
    all_val_folds = np.stack(val_folds)
    mean_folds = np.mean(all_val_folds, axis=0)
    print('All_val_folds: ', all_val_folds.shape)
    print('All_mean_val_folds:', mean_folds.shape)

    lg_auc_val = roc_auc_score(y_val, mean_folds, multi_class='ovr')
    print('Validation AUC : ', np.round(lg_auc_val, decimals=4))

    # Binarize the true labels to use with roc_auc_score
    y_val_binarized = label_binarize(y_val, classes=[0, 1, 2])
    aucs_val = []
    for i in range(3):
        auc_val = roc_auc_score(y_val_binarized[:, i], np.array(mean_folds)[:, i])
        aucs_val.append(auc_val)
    print('Validation AUC : ', np.round(aucs_val, decimals=4), '(per subtype, [WNT, G3/G4, SHH])')

    f1_mean_val = f1_score(y_val, np.argmax(mean_folds, axis=1), average='weighted')
    print('Validation f1 score: ', np.round(f1_mean_val, decimals=4))
    val_f1_per_subtype = [np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=0), decimals=4),
                            np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=1), decimals=4),
                            np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=2), decimals=4)]
    print('Validation f1 score: ', val_f1_per_subtype, '(per subtype, [WNT, G3/G4, SHH])')

    cm_val = confusion_matrix(y_val, np.argmax(mean_folds, axis=1))
    print('Validation Confusion Matrix: ')
    print(cm_val)
    #disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_val)
    #disp1.plot()
        
    print('-----------Golden--------------')
    all_new_folds = np.stack(new_folds)
    mean_new_folds = np.mean(all_new_folds, axis=0)
    print('All_new_folds: ', all_new_folds.shape)
    print('All_mean_new_folds:', mean_new_folds.shape)

    lg_auc_new = roc_auc_score(y_new, mean_new_folds, multi_class='ovr')
    print('Golden AUC : ', np.round(lg_auc_new, decimals=4))
    # Binarize the true labels to use with roc_auc_score
    y_new_binarized = label_binarize(y_new, classes=[0, 1, 2])
    aucs_new = []
    for i in range(3):
        auc_new = roc_auc_score(y_new_binarized[:, i], np.array(mean_new_folds)[:, i])
        aucs_new.append(auc_new)
    print('Golden AUC : ', np.round(aucs_new, decimals=4), '(per subtype, [WNT, G3/G4, SHH])')

    f1_mean_new = f1_score(y_new, np.argmax(mean_new_folds, axis=1), average='weighted')
    print('Golden f1 score: ', np.round(f1_mean_new, decimals=4))
    new_f1_per_subtype = [np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=0), decimals=4),
                            np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=1), decimals=4),
                            np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=2), decimals=4)]
    print('Golden f1 score: ', new_f1_per_subtype, '(per subtype, [WNT, G3/G4, SHH])')

    cm_new = confusion_matrix(y_new, np.argmax(mean_new_folds, axis=1))
    print('Golden Confusion Matrix: ')
    print(cm_new)

    print('-------------Params-----------------')
    for i in range(3):
        print(params_best[i])
        
    experiment_data = {
            'Experiment': experiment_name,
            'Test AUC Overall': np.round(lg_auc_test, decimals=4),
            'Test AUC Per Fold': np.round(auc_test_folds, decimals=4).tolist(),
            'Test AUC Per Subtype': np.round(aucs_test, decimals=4),
            'Test F1 Overall': np.round(f1_test, decimals=4),
            'Test F1 Per Fold': np.round(f1_test_folds, decimals=4).tolist(),
            'Test F1 Per Subtype': test_f1_per_subtype,
            'Validation AUC Overall': np.round(lg_auc_val, decimals=4),
            'Validation AUC Per Subtype': np.round(aucs_val, decimals=4).tolist(),
            'Validation F1 Overall': np.round(f1_mean_val, decimals=4),
            'Validation F1 Per Subtype': val_f1_per_subtype,
            'Golden AUC Overall': np.round(lg_auc_new, decimals=4),
            'Golden AUC Per Subtype': np.round(aucs_new, decimals=4).tolist(),
            'Golden F1 Overall': np.round(f1_mean_new, decimals=4),
            'Golden F1 Per Subtype': new_f1_per_subtype,
            'details file': experiment_name + '_' + timestamp + '.txt'
    }

    # 写入数据
    write_experiment_results_to_csv(csv_result, experiment_data)
    sys.stdout = original_stdout

# %%
all_l_test_folds = np.vstack(test_folds)
len(test_folds[0]), len(test_folds[1])
# Out:
# (172, 170)

# %%
from datetime import datetime

# 获取当前时间
now = datetime.now()

# 格式化时间为 MMDDHHMM 格式
timestamp = now.strftime("%m%d%H%M")
csv_result = '/Users/huyanshen/Desktop/AI-Medicine/Research/PengCheng/Shap_Value_yanshen/ModelComparison/SVM_result/results.csv'


print('-------------Features---------------')
print(sel_columns)

print('-------------Testing----------------')
all_test_folds = np.vstack(test_folds)
gt_test = np.concatenate(test_gt_folds)
print('All_test_folds: ', all_test_folds.shape)

all_l_test_folds = np.concatenate(pred_folds)
lg_accuracy_test = accuracy_score(gt_test, all_l_test_folds)
lg_accuracy_CI_test = bootstrap(gt_test, all_l_test_folds, 3000, 0.95, accuracy_score)
print(f'Test Accuracy: {np.round(lg_accuracy_test, decimals=4)} {tuple(np.round(lg_accuracy_CI_test, decimals=4))}')


lg_auc_test = roc_auc_score(gt_test, all_test_folds, multi_class='ovr')
lg_auc_CI_test = bootstrap(gt_test, all_test_folds, 3000, 0.95, roc_auc_score, multi_class='ovr')
print('Test AUC : {} {}'.format(np.round(lg_auc_test, decimals=4), tuple(np.round(lg_auc_CI_test, decimals=4))))
AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(auc_test_folds, decimals=4), np.round(auc_test_CI_folds, decimals=4))]
print('Test AUC: ', AUC_format, '(per fold)')

# Binarize the true labels to use with roc_auc_score
y_test_binarized = label_binarize(gt_test, classes=[0, 1, 2])
aucs_test = []
aucs_CI_test = []
for i in range(3):
    auc_test = roc_auc_score(y_test_binarized[:, i], np.array(all_test_folds)[:, i])
    auc_CI_test = bootstrap(y_test_binarized[:, i], np.array(all_test_folds)[:, i], 3000, 0.95, roc_auc_score, multi_class='ovr')
    aucs_test.append(auc_test)
    aucs_CI_test.append(auc_CI_test)
AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(aucs_test, decimals=4), np.round(aucs_CI_test, decimals=4))]
print('Test AUC : ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')

f1_test = f1_score(gt_test, np.argmax(all_test_folds, axis=1), average='weighted')
f1_CI_test = bootstrap(gt_test, np.argmax(all_test_folds, axis=1), 3000, 0.95, f1_score, average='weighted')
print('Test F1 score: {} {}'.format(np.round(f1_test, decimals=4), tuple(np.round(f1_CI_test, decimals=4))))
AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(f1_test_folds, decimals=4), np.round(f1_test_CI_folds, decimals=4))]
print('Test F1 score: ', AUC_format, '(per fold)')
test_f1_per_subtype = [np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=0), decimals=4),
                        np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=1), decimals=4),
                        np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=2), decimals=4)]
test_f1_CI_per_subtype = [np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=0), decimals=4),
                        np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=1), decimals=4),
                        np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=2), decimals=4)]
AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(test_f1_per_subtype, decimals=4), np.round(test_f1_CI_per_subtype, decimals=4))]
print('Test F1 score: ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')

cm_test = confusion_matrix(gt_test, np.argmax(all_test_folds, axis=1))
print('Test Confusion Matrix: ')
print(cm_test)
#disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_val)
#disp1.plot()

print('-----------Validation--------------')
all_val_folds = np.stack(val_folds)
mean_folds = np.mean(all_val_folds, axis=0)
print('All_val_folds: ', all_val_folds.shape)
print('All_mean_val_folds:', mean_folds.shape)

lg_auc_val = roc_auc_score(y_val, mean_folds, multi_class='ovr')
print('Validation AUC : ', np.round(lg_auc_val, decimals=4))

# Binarize the true labels to use with roc_auc_score
y_val_binarized = label_binarize(y_val, classes=[0, 1, 2])
aucs_val = []
for i in range(3):
    auc_val = roc_auc_score(y_val_binarized[:, i], np.array(mean_folds)[:, i])
    aucs_val.append(auc_val)
print('Validation AUC : ', np.round(aucs_val, decimals=4), '(per subtype, [WNT, G3/G4, SHH])')

f1_mean_val = f1_score(y_val, np.argmax(mean_folds, axis=1), average='weighted')
print('Validation f1 score: ', np.round(f1_mean_val, decimals=4))
val_f1_per_subtype = [np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=0), decimals=4),
                        np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=1), decimals=4),
                        np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=2), decimals=4)]
print('Validation f1 score: ', val_f1_per_subtype, '(per subtype, [WNT, G3/G4, SHH])')

cm_val = confusion_matrix(y_val, np.argmax(mean_folds, axis=1))
print('Validation Confusion Matrix: ')
print(cm_val)
#disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_val)
#disp1.plot()
    
print('-----------Golden--------------')
all_new_folds = np.stack(new_folds)
mean_new_folds = np.mean(all_new_folds, axis=0)
print('All_new_folds: ', all_new_folds.shape)
print('All_mean_new_folds:', mean_new_folds.shape)

lg_auc_new = roc_auc_score(y_new, mean_new_folds, multi_class='ovr')
print('Golden AUC : ', np.round(lg_auc_new, decimals=4))
# Binarize the true labels to use with roc_auc_score
y_new_binarized = label_binarize(y_new, classes=[0, 1, 2])
aucs_new = []
for i in range(3):
    auc_new = roc_auc_score(y_new_binarized[:, i], np.array(mean_new_folds)[:, i])
    aucs_new.append(auc_new)
print('Golden AUC : ', np.round(aucs_new, decimals=4), '(per subtype, [WNT, G3/G4, SHH])')

f1_mean_new = f1_score(y_new, np.argmax(mean_new_folds, axis=1), average='weighted')
print('Golden f1 score: ', np.round(f1_mean_new, decimals=4))
new_f1_per_subtype = [np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=0), decimals=4),
                        np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=1), decimals=4),
                        np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=2), decimals=4)]
print('Golden f1 score: ', new_f1_per_subtype, '(per subtype, [WNT, G3/G4, SHH])')

cm_new = confusion_matrix(y_new, np.argmax(mean_new_folds, axis=1))
print('Golden Confusion Matrix: ')
print(cm_new)

print('-------------Params-----------------')
for i in range(3):
    print(params_best[i])
    
experiment_data = {
        'Experiment': experiment_name,
        'Test AUC Overall': np.round(lg_auc_test, decimals=4),
        'Test AUC Per Fold': np.round(auc_test_folds, decimals=4).tolist(),
        'Test AUC Per Subtype': np.round(aucs_test, decimals=4),
        'Test F1 Overall': np.round(f1_test, decimals=4),
        'Test F1 Per Fold': np.round(f1_test_folds, decimals=4).tolist(),
        'Test F1 Per Subtype': test_f1_per_subtype,
        'Validation AUC Overall': np.round(lg_auc_val, decimals=4),
        'Validation AUC Per Subtype': np.round(aucs_val, decimals=4).tolist(),
        'Validation F1 Overall': np.round(f1_mean_val, decimals=4),
        'Validation F1 Per Subtype': val_f1_per_subtype,
        'Golden AUC Overall': np.round(lg_auc_new, decimals=4),
        'Golden AUC Per Subtype': np.round(aucs_new, decimals=4).tolist(),
        'Golden F1 Overall': np.round(f1_mean_new, decimals=4),
        'Golden F1 Per Subtype': new_f1_per_subtype,
        'details file': experiment_name + '_' + timestamp + '.txt'
}

# 写入数据
write_experiment_results_to_csv(csv_result, experiment_data)
# Out:
# -------------Features---------------
# ['Cohort', 'Subtypes_three', 'fold', 'Age', 'T1E_log-sigma-3-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis_x', 'T1E_log-sigma-3-mm-3D_glcm_Autocorrelation_x', 'T1E_log-sigma-1-mm-3D_glcm_ClusterShade_x', 'T1E_wavelet-LHL_firstorder_Mean_x', 'T2_wavelet-LLH_glcm_ClusterShade_y', 'T1E_log-sigma-5-mm-3D_glrlm_LowGrayLevelRunEmphasis_x', 'T1E_wavelet-HLL_firstorder_Median_x', 'T1E_wavelet-LHL_firstorder_Median_x', 'T2_wavelet-HHL_firstorder_Skewness_x', 'T1E_log-sigma-3-mm-3D_glrlm_LongRunLowGrayLevelEmphasis_x', 'T1E_lbp-2D_glrlm_RunLengthNonUniformity_x', 'T2_log-sigma-1-mm-3D_gldm_LowGrayLevelEmphasis_x', 'T1E_log-sigma-5-mm-3D_firstorder_90Percentile_x', 'T1E_log-sigma-3-mm-3D_glszm_LowGrayLevelZoneEmphasis_x', 'T2_wavelet-HHL_glcm_SumSquares_x', 'T2_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized_x', 'T2_wavelet-LLH_gldm_DependenceNonUniformity_x', 'T2_original_shape_Maximum3DDiameter_y', 'T2_original_glszm_LargeAreaEmphasis_y']
# -------------Testing----------------
# All_test_folds:  (514, 3)
# Test Accuracy: 0.6615 (0.6206, 0.7043)
# Test AUC : 0.8062 (0.7712, 0.8385)
# Test AUC:  ['0.7815 (0.7154, 0.8397)', '0.7875 (0.7282, 0.8432)', '0.8562 (0.8032, 0.9015)'] (per fold)
# Test AUC :  ['0.8697 (0.8192, 0.9142)', '0.7701 (0.7279, 0.8096)', '0.7788 (0.7316, 0.8238)'] (per subtype, [WNT, G3/G4, SHH])
# Test F1 score: 0.6496 (0.6093, 0.6899)
# Test F1 score:  ['0.6408 (0.5681, 0.7112)', '0.6337 (0.561, 0.7051)', '0.7239 (0.6527, 0.7886)'] (per fold)
# Test F1 score:  ['0.557 (0.4586, 0.6463)', '0.7158 (0.6727, 0.7568)', '0.5533 (0.4825, 0.6169)'] (per subtype, [WNT, G3/G4, SHH])
# Test Confusion Matrix:
# [[ 44  14   9]
#  [ 35 204  64]
#  [ 12  49  83]]
# -----------Validation--------------
# All_val_folds:  (3, 135, 3)
# All_mean_val_folds: (135, 3)
# Validation AUC :  0.79
# Validation AUC :  [0.832  0.7839 0.7542] (per subtype, [WNT, G3/G4, SHH])
# Validation f1 score:  0.6769
# Validation f1 score:  [0.5143, 0.7564, 0.5823] (per subtype, [WNT, G3/G4, SHH])
# Validation Confusion Matrix:
# [[ 9  5  3]
#  [ 6 59 15]
#  [ 3 12 23]]
# -----------Golden--------------
# All_new_folds:  (3, 44, 3)
# All_mean_new_folds: (44, 3)
# Golden AUC :  0.8542
# Golden AUC :  [0.7954 0.8485 0.9188] (per subtype, [WNT, G3/G4, SHH])
# Golden f1 score:  0.6701
# Golden f1 score:  [0.1667, 0.807, 0.4211] (per subtype, [WNT, G3/G4, SHH])
# Golden Confusion Matrix:
# [[ 1  1  5]
#  [ 4 23  6]
#  [ 0  0  4]]
# -------------Params-----------------
# {'C': 2.7245893870569944}
# {'C': 2.1594615881240777}
# {'C': 1.0684258931800605}

# %%
all_test_folds
# Out:
# array([[3.44147455e-05, 6.58738628e-01, 3.41226957e-01],
#        [3.10552495e-04, 5.06398410e-01, 4.93291038e-01],
#        [1.31348063e-03, 6.33496698e-01, 3.65189821e-01],
#        ...,
#        [6.41433946e-03, 6.23657536e-01, 3.69928124e-01],
#        [7.77019191e-01, 1.96724918e-01, 2.62558909e-02],
#        [1.94510367e-02, 3.34591625e-01, 6.45957338e-01]])
