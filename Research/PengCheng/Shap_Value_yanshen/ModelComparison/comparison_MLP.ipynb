# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score

from tqdm import tqdm

from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline
from lifelines import CoxPHFitter
import shap
import xgboost
import matplotlib.pyplot as plt
import statistics as st
from bayes_opt import BayesianOptimization
from bayes_opt.util import UtilityFunction
from pyirr import intraclass_correlation
from lightgbm import LGBMClassifier
from sklearn.neural_network import MLPClassifier
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
from feature_utils.feature_classfication import data_normalization, data_normalization_apply_cohort1_to_all, lgb_evaluate_mlp

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from functools import partial
from sklearn.preprocessing import label_binarize

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, roc_auc_score, roc_curve, auc
import sys
import argparse

import csv
import os

# %%
def write_experiment_results_to_csv(file_path, data_dict):
    file_exists = os.path.isfile(file_path)

    with open(file_path, 'a', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=data_dict.keys())

        if not file_exists:
            writer.writeheader()

        writer.writerow(data_dict)

def f1_scores(label_f1, pred_f1, pos_index):
    """
    Calculate f1 score（for bootstrap）
    :param data: data[:, 0] = pred, data[:, 1] = label, data[:, 2] = index
    :return: f1 score
    """
    conf_mat = confusion_matrix(y_true=label_f1, y_pred=pred_f1)

    tp = conf_mat[pos_index][pos_index]
    fp = np.sum(conf_mat[:, pos_index]) - tp
    fn = np.sum(conf_mat[pos_index]) - tp
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1_cls = 2 * precision * recall / (precision + recall)
    return f1_cls

def update_value_ep(x):
    if x < 0.1:
        return 0
    elif 0.1 <= x <= 0.5:
        return 0.5
    else:
        return 1
    
def update_value_age(x):
    """
    年龄的encoding：0-3，3-6，6-9，9-12，12-15，15-18，18+, [0, 0.15, 0.3, 0.45, 0.6, 0.75, 1]
    """
    if x < 3:
        return 0
    elif 3 <= x < 6:
        return 0.15
    elif 6 <= x < 9:
        return 0.3
    elif 9 <= x < 12:
        return 0.45
    elif 12 <= x < 15:
        return 0.6
    elif 15 <= x < 18:
        return 0.75
    else:
        return 1
    
def update_value_dsmn(x):
    """
    转移pattern：C-D-（0）；C-D+（0.25）；C+D-（0.5）；C+NA（0.75）；C+D+（1）
    """
    if x ==0:
        return 0
    elif x==0.25:
        return 1.0
    elif x==0.375:
        return 0.75
    elif x==0.5:
        return 0.5
    elif x==0.75:
        return 0.25
    else:
        return 0
    
class DummyFile(object):
    def write(self, x): pass

# %%
three_cls_path =  '/Users/huyanshen/Desktop/AI-Medicine/Research/PengCheng/Shap_Value_yanshen/ModelComparison/new_3cls_radiomics_new.txt'#args.radiomics_file
three_cls_path_c4 = '/Users/huyanshen/Desktop/AI-Medicine/Research/PengCheng/Shap_Value_yanshen/ModelComparison/new_3cls_radiomics_cohort4_new.txt'#args.radiomics_file_c4
data = pd.read_csv(three_cls_path, sep='\t')
data_c4 = pd.read_csv(three_cls_path_c4, sep='\t')

# %%
wnt_shh_g34_feature_names = ['T1E_log-sigma-3-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis_x',
     'T1E_log-sigma-3-mm-3D_glcm_Autocorrelation_x',
     'T1E_log-sigma-1-mm-3D_glcm_ClusterShade_x',
     'T1E_wavelet-LHL_firstorder_Mean_x',
     'T2_wavelet-LLH_glcm_ClusterShade_y',
     'T1E_log-sigma-5-mm-3D_glrlm_LowGrayLevelRunEmphasis_x',
     'T1E_wavelet-HLL_firstorder_Median_x',
     'T1E_wavelet-LHL_firstorder_Median_x',
     'T2_wavelet-HHL_firstorder_Skewness_x',
     'T1E_log-sigma-3-mm-3D_glrlm_LongRunLowGrayLevelEmphasis_x',
     'T1E_lbp-2D_glrlm_RunLengthNonUniformity_x',
     'T2_log-sigma-1-mm-3D_gldm_LowGrayLevelEmphasis_x',
     'T1E_log-sigma-5-mm-3D_firstorder_90Percentile_x',
     'T1E_log-sigma-3-mm-3D_glszm_LowGrayLevelZoneEmphasis_x',
     'T2_wavelet-HHL_glcm_SumSquares_x',
     'T2_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized_x',
     'T2_wavelet-LLH_gldm_DependenceNonUniformity_x',
     'T2_original_shape_Maximum3DDiameter_y',
     'T2_original_glszm_LargeAreaEmphasis_y']

clinical_feature_names = ''
    
id_val = data[data['Cohort']!=1]['id'].tolist()
id_new = data_c4['id'].tolist()
print('Val id: ', len(id_val))
print('New id: ', len(id_new))
    #['Location','FourthIn','Enhance','Enhance_Percent','Margin','Water','Cyst','Hydro','EpendymalDissemination','3rdVIRDissemination','SuperLMD','InfraLMD','LMDPattern','Ependymal3Dissemination','LMDDissemination','AllDissemination']
clnc_all =['Location','FourthIn','Enhance','Enhance_Percent','Margin','Water','Cyst','Hydro','EpendymalDissemination','3rdVIRDissemination','SuperLMD','InfraLMD','LMDPattern','Ependymal3Dissemination','LMDDissemination','AllDissemination']
# Out:
# Val id:  135
# New id:  44

# %%
sel_columns_basic = ['Cohort','Subtypes_three','fold','Age']
sel_columns = sel_columns_basic + wnt_shh_g34_feature_names

x = data[sel_columns]
x.iloc[:, 4:] = x.iloc[:, 4:].astype(float)
print('total features and labels shape: ', x.shape)
x_new = data_c4[sel_columns]
print(sel_columns, x_new.shape)
x_new.iloc[:, 3:] = x_new.iloc[:, 3:].astype(float)
print('total features and labels shape: ', x.shape)
# Out:
# total features and labels shape:  (649, 23)
# ['Cohort', 'Subtypes_three', 'fold', 'Age', 'T1E_log-sigma-3-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis_x', 'T1E_log-sigma-3-mm-3D_glcm_Autocorrelation_x', 'T1E_log-sigma-1-mm-3D_glcm_ClusterShade_x', 'T1E_wavelet-LHL_firstorder_Mean_x', 'T2_wavelet-LLH_glcm_ClusterShade_y', 'T1E_log-sigma-5-mm-3D_glrlm_LowGrayLevelRunEmphasis_x', 'T1E_wavelet-HLL_firstorder_Median_x', 'T1E_wavelet-LHL_firstorder_Median_x', 'T2_wavelet-HHL_firstorder_Skewness_x', 'T1E_log-sigma-3-mm-3D_glrlm_LongRunLowGrayLevelEmphasis_x', 'T1E_lbp-2D_glrlm_RunLengthNonUniformity_x', 'T2_log-sigma-1-mm-3D_gldm_LowGrayLevelEmphasis_x', 'T1E_log-sigma-5-mm-3D_firstorder_90Percentile_x', 'T1E_log-sigma-3-mm-3D_glszm_LowGrayLevelZoneEmphasis_x', 'T2_wavelet-HHL_glcm_SumSquares_x', 'T2_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized_x', 'T2_wavelet-LLH_gldm_DependenceNonUniformity_x', 'T2_original_shape_Maximum3DDiameter_y', 'T2_original_glszm_LargeAreaEmphasis_y'] (44, 23)
# total features and labels shape:  (649, 23)

# %%
# split base dataset and external validation dataset
df_val = x[(x['Cohort'] == 2) | (x['Cohort'] == 3)]
df_val.reset_index(inplace=True)
X_val = df_val.iloc[:, 4:]

feature_names = X_val.columns.tolist()
X_val = np.array(X_val)
y_val = df_val['Subtypes_three']
y_val = np.array(y_val)
    
df_new = x_new
X_new = df_new.iloc[:, 3:]

feature_names = X_new.columns.tolist()
print(feature_names)
X_new = np.array(X_new)
y_new = df_new['Subtypes_three']
y_new = np.array(y_new)

print('X-val: ', X_val.shape)
print('X-new: ', X_new.shape)

df_X = x[x['Cohort'] == 1]
df_X.reset_index(inplace=True)
folds_indices = {}
# Out:
# ['Age', 'T1E_log-sigma-3-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis_x', 'T1E_log-sigma-3-mm-3D_glcm_Autocorrelation_x', 'T1E_log-sigma-1-mm-3D_glcm_ClusterShade_x', 'T1E_wavelet-LHL_firstorder_Mean_x', 'T2_wavelet-LLH_glcm_ClusterShade_y', 'T1E_log-sigma-5-mm-3D_glrlm_LowGrayLevelRunEmphasis_x', 'T1E_wavelet-HLL_firstorder_Median_x', 'T1E_wavelet-LHL_firstorder_Median_x', 'T2_wavelet-HHL_firstorder_Skewness_x', 'T1E_log-sigma-3-mm-3D_glrlm_LongRunLowGrayLevelEmphasis_x', 'T1E_lbp-2D_glrlm_RunLengthNonUniformity_x', 'T2_log-sigma-1-mm-3D_gldm_LowGrayLevelEmphasis_x', 'T1E_log-sigma-5-mm-3D_firstorder_90Percentile_x', 'T1E_log-sigma-3-mm-3D_glszm_LowGrayLevelZoneEmphasis_x', 'T2_wavelet-HHL_glcm_SumSquares_x', 'T2_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized_x', 'T2_wavelet-LLH_gldm_DependenceNonUniformity_x', 'T2_original_shape_Maximum3DDiameter_y', 'T2_original_glszm_LargeAreaEmphasis_y']
# X-val:  (135, 20)
# X-new:  (44, 20)

# %%
for fold in df_X['fold'].unique():
    test_index = df_X[df_X['fold'] == fold].index
    train_index = df_X[df_X['fold'] != fold].index
    print(len(test_index), len(train_index))
    folds_indices[fold] = {'train_index': train_index, 'test_index': test_index}

X = df_X.iloc[:, 4:]
y = df_X['Subtypes_three']
print('X: ', X.shape)
print('Fold index has been determined!')
    
params_best = []
for i, values in enumerate(folds_indices.values()):
    train_index, test_index = values['train_index'], values['test_index']
    X_test, y_test = X.iloc[test_index], y.iloc[test_index]
    X_train, y_train = X.iloc[train_index], y.iloc[train_index]

    X_train = np.array(X_train)
    X_test = np.array(X_test)

    y_train = np.array(y_train).astype(int)
    y_test = np.array(y_test).astype(int)

    nm = SMOTE(random_state=42)
    X_res, y_res = nm.fit_resample(X_train, y_train)

    print('size of data partitions')
    print('...............INPUT..............OUTPUT..........')
    print('Train      : ', X_train.shape, '         ', y_train.shape, np.sum(y_train))
    print('Test       : ', X_test.shape, '         ', y_test.shape, np.sum(y_test))
    print('Validation : ', X_val.shape, '         ', y_val.shape, np.sum(y_val))
    # bayesian optimization of hyperparameters for lg_boost
    seed = 1
    # use partial to pass train, val and test data
    partial_lgb_evaluate_mlp = partial(lgb_evaluate_mlp, X_train=X_res, y_train=y_res, X_val=X_val, y_val=y_val,
                                                X_test=X_test, y_test=y_test,  multi_cls=True)
    lgb_bo = BayesianOptimization(partial_lgb_evaluate_mlp, {'alpha': (0.00005, 0.001),
              'batch_size': (100, 800),
              'learning_rate_init': (0.0005, 0.01),
              'power_t': (0.5, 2),
              'max_iter': (100, 800),
              'random_state': (1, 10),
              'tol': (1e-4, 1e-3),
              'momentum': (0, 1),
              'validation_fraction': (0, 1),
              'beta_1': (0, 1),
              'beta_2': (0, 1),
              'epsilon': (1e-8, 1e-7),
              'n_iter_no_change': (5, 100),
              'max_fun': (10000, 50000)})

    # Optimally needs quite a few more initiation points and number of iterations
    gp_params = {'alpha': 1e-4}
    lgb_bo.set_gp_params(**gp_params)
    acq_f = UtilityFunction(kind="ei", kappa=2.576, xi=0.0)
    lgb_bo.maximize(init_points=200, n_iter=50, acquisition_function=acq_f)

    fold_max = lgb_bo.max['params']
    fold_params = {'alpha': fold_max['alpha'],
              'batch_size': int(fold_max['batch_size']),
              'learning_rate_init': fold_max['learning_rate_init'],
              'power_t': fold_max['power_t'],
              'max_iter': int(fold_max['max_iter']),
              'random_state': int(fold_max['random_state']),
              'tol': fold_max['tol'],
              'momentum': fold_max['momentum'],
              'validation_fraction': fold_max['validation_fraction'],
              'beta_1': fold_max['beta_1'],
              'beta_2': fold_max['beta_2'],
              'epsilon': fold_max['epsilon'],
              'n_iter_no_change': int(fold_max['n_iter_no_change']),
              'max_fun': int(fold_max['max_fun'])
                    }
    params_best.append(fold_params)
# Out:
# 172 342
# 170 344
# 172 342
# X:  (514, 20)
# Fold index has been determined!
# size of data partitions
# ...............INPUT..............OUTPUT..........
# Train      :  (342, 20)           (342,) 391
# Test       :  (172, 20)           (172,) 200
# Validation :  (135, 20)           (135,) 156
# |   iter    |  target   |   alpha   | batch_... |  beta_1   |  beta_2   |  epsilon  | learni... |  max_fun  | max_iter  | momentum  | n_iter... |  power_t  | random... |    tol    | valida... |
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ************************************
# Train AUC       :  0.9261
# Test AUC       :  0.7599
# Validation AUC :  0.7468
# {'activation': 'relu', 'alpha': 0.0001100569738818689, 'batch_size': 379, 'beta_1': 0.6984109031783292, 'beta_2': 0.38647637801684265, 'early_stopping': False, 'epsilon': 8.601270498966229e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.006364358316027148, 'max_fun': 25728, 'max_iter': 262, 'momentum': 0.32570168444381653, 'n_iter_no_change': 39, 'nesterovs_momentum': True, 'power_t': 0.9161474042739415, 'random_state': 6, 'shuffle': True, 'solver': 'adam', 'tol': 0.0007623729766544439, 'validation_fraction': 0.04827500683883312, 'verbose': False, 'warm_start': False}
# | 1         | 0.7599    | 0.0001101 | 379.8     | 0.6984    | 0.3865    | 8.601e-08 | 0.006364  | 2.573e+04 | 262.5     | 0.3257    | 39.23     | 0.9161    | 6.734     | 0.0007624 | 0.04828   |
# ************************************
# Train AUC       :  0.9521
# Test AUC       :  0.7671
# Validation AUC :  0.7607
# {'activation': 'relu', 'alpha': 0.000861871721643258, 'batch_size': 714, 'beta_1': 0.5408160827371257, 'beta_2': 0.9534766827208534, 'early_stopping': False, 'epsilon': 3.388971287701138e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.007960557926357338, 'max_fun': 14007, 'max_iter': 570, 'momentum': 0.4467358302655252, 'n_iter_no_change': 92, 'nesterovs_momentum': True, 'power_t': 0.7947031542577688, 'random_state': 7, 'shuffle': True, 'solver': 'adam', 'tol': 0.0006437680100877729, 'validation_fraction': 0.96388360511469, 'verbose': False, 'warm_start': False}
# | 2         | 0.7671    | 0.0008619 | 714.7     | 0.5408    | 0.9535    | 3.389e-08 | 0.007961  | 1.401e+04 | 570.6     | 0.4467    | 92.73     | 0.7947    | 7.431     | 0.0006438 | 0.9639    |
# ************************************
# Train AUC       :  0.8806
# Test AUC       :  0.7314
# Validation AUC :  0.7081
# {'activation': 'relu', 'alpha': 0.0005232311808616491, 'batch_size': 741, 'beta_1': 0.7542773598095798, 'beta_2': 0.36882948345845235, 'early_stopping': False, 'epsilon': 3.539862079406603e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.004238572557308199, 'max_fun': 32458, 'max_iter': 145, 'momentum': 0.4199177500461345, 'n_iter_no_change': 24, 'nesterovs_momentum': True, 'power_t': 1.9909787959088776, 'random_state': 7, 'shuffle': True, 'solver': 'adam', 'tol': 0.0006171053787650552, 'validation_fraction': 0.8934019582161251, 'verbose': False, 'warm_start': False}
# | 3         | 0.7314    | 0.0005232 | 741.4     | 0.7543    | 0.3688    | 3.54e-08  | 0.004239  | 3.246e+04 | 145.1     | 0.4199    | 24.84     | 1.991     | 7.615     | 0.0006171 | 0.8934    |
# ************************************
# Train AUC       :  0.9147
# Test AUC       :  0.7695
# Validation AUC :  0.7578
# {'activation': 'relu', 'alpha': 0.0005389003322222469, 'batch_size': 443, 'beta_1': 0.135354980800371, 'beta_2': 0.2196292511956276, 'early_stopping': False, 'epsilon': 1.8600631334252463e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0074909910959508035, 'max_fun': 41683, 'max_iter': 201, 'momentum': 0.5080184727639712, 'n_iter_no_change': 75, 'nesterovs_momentum': True, 'power_t': 1.328252416941636, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.00011934247066960111, 'validation_fraction': 0.2651738649417056, 'verbose': False, 'warm_start': False}
# | 4         | 0.7695    | 0.0005389 | 443.6     | 0.1354    | 0.2196    | 1.86e-08  | 0.007491  | 4.168e+04 | 201.9     | 0.508     | 75.78     | 1.328     | 8.18      | 0.0001193 | 0.2652    |
# ************************************
# Train AUC       :  0.9604
# Test AUC       :  0.7944
# Validation AUC :  0.7714
# {'activation': 'relu', 'alpha': 0.0009116559910022976, 'batch_size': 351, 'beta_1': 0.30711748832047925, 'beta_2': 0.956201164347775, 'early_stopping': False, 'epsilon': 9.756230118861469e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.004103803950231291, 'max_fun': 21351, 'max_iter': 730, 'momentum': 0.1917031657785251, 'n_iter_no_change': 61, 'nesterovs_momentum': True, 'power_t': 1.4480076076669235, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.000741068239425068, 'validation_fraction': 0.7546826499972126, 'verbose': False, 'warm_start': False}
# | 5         | 0.7944    | 0.0009117 | 352.0     | 0.3071    | 0.9562    | 9.756e-08 | 0.004104  | 2.135e+04 | 730.9     | 0.1917    | 61.08     | 1.448     | 4.38      | 0.0007411 | 0.7547    |
# ************************************
# Train AUC       :  0.903
# Test AUC       :  0.752
# Validation AUC :  0.7296
# {'activation': 'relu', 'alpha': 0.00020035745309711177, 'batch_size': 608, 'beta_1': 0.38381446545994347, 'beta_2': 0.5376421195902145, 'early_stopping': False, 'epsilon': 5.713750852585463e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.003939929741431468, 'max_fun': 25767, 'max_iter': 210, 'momentum': 0.5017698491319889, 'n_iter_no_change': 60, 'nesterovs_momentum': True, 'power_t': 0.6694872998915407, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.000720901781445931, 'validation_fraction': 0.6127355211025899, 'verbose': False, 'warm_start': False}
# | 6         | 0.752     | 0.0002004 | 608.6     | 0.3838    | 0.5376    | 5.714e-08 | 0.00394   | 2.577e+04 | 210.2     | 0.5018    | 60.67     | 0.6695    | 8.796     | 0.0007209 | 0.6127    |
# ************************************
# Train AUC       :  0.9322
# Test AUC       :  0.7703
# Validation AUC :  0.7544
# {'activation': 'relu', 'alpha': 0.0009769815546581944, 'batch_size': 614, 'beta_1': 0.542664693894115, 'beta_2': 0.8835962126288974, 'early_stopping': False, 'epsilon': 3.324559423774321e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00816533912840331, 'max_fun': 48017, 'max_iter': 348, 'momentum': 0.5534548125480917, 'n_iter_no_change': 37, 'nesterovs_momentum': True, 'power_t': 1.2739169795833676, 'random_state': 5, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001342789715907291, 'validation_fraction': 0.2042357731674712, 'verbose': False, 'warm_start': False}
# | 7         | 0.7703    | 0.000977  | 614.9     | 0.5427    | 0.8836    | 3.325e-08 | 0.008165  | 4.802e+04 | 348.1     | 0.5535    | 37.16     | 1.274     | 5.669     | 0.0001343 | 0.2042    |
# ************************************
# Train AUC       :  0.9488
# Test AUC       :  0.774
# Validation AUC :  0.776
# {'activation': 'relu', 'alpha': 0.0008798040185249646, 'batch_size': 423, 'beta_1': 0.45936934583224764, 'beta_2': 0.6727554913359265, 'early_stopping': False, 'epsilon': 8.202538975028704e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0060195831995809145, 'max_fun': 29356, 'max_iter': 415, 'momentum': 0.9911653998076425, 'n_iter_no_change': 66, 'nesterovs_momentum': True, 'power_t': 0.6605571893272653, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0007673147862950791, 'validation_fraction': 0.05910956638573084, 'verbose': False, 'warm_start': False}
# | 8         | 0.774     | 0.0008798 | 423.0     | 0.4594    | 0.6728    | 8.203e-08 | 0.00602   | 2.936e+04 | 415.4     | 0.9912    | 66.36     | 0.6606    | 1.085     | 0.0007673 | 0.05911   |
# ************************************
# Train AUC       :  0.9692
# Test AUC       :  0.7802
# Validation AUC :  0.7483
# {'activation': 'relu', 'alpha': 0.0005874071318100346, 'batch_size': 458, 'beta_1': 0.7762129520635677, 'beta_2': 0.5277214867758053, 'early_stopping': False, 'epsilon': 3.623194119663514e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.008856910046268832, 'max_fun': 39885, 'max_iter': 497, 'momentum': 0.0243204904057851, 'n_iter_no_change': 60, 'nesterovs_momentum': True, 'power_t': 0.7165581688816174, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.00017004974264992514, 'validation_fraction': 0.3462601141081736, 'verbose': False, 'warm_start': False}
# | 9         | 0.7802    | 0.0005874 | 458.2     | 0.7762    | 0.5277    | 3.623e-08 | 0.008857  | 3.989e+04 | 498.0     | 0.02432   | 60.9      | 0.7166    | 4.271     | 0.00017   | 0.3463    |
# ************************************
# Train AUC       :  0.9455
# Test AUC       :  0.7757
# Validation AUC :  0.7436
# {'activation': 'relu', 'alpha': 0.000526478679279866, 'batch_size': 261, 'beta_1': 0.7905454740335678, 'beta_2': 0.03390098397865515, 'early_stopping': False, 'epsilon': 7.43471990578579e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0018818749021955845, 'max_fun': 16061, 'max_iter': 788, 'momentum': 0.2862557333047937, 'n_iter_no_change': 78, 'nesterovs_momentum': True, 'power_t': 1.802633430932922, 'random_state': 9, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001416945959219124, 'validation_fraction': 0.2115566776959188, 'verbose': False, 'warm_start': False}
# | 10        | 0.7757    | 0.0005265 | 261.3     | 0.7905    | 0.0339    | 7.435e-08 | 0.001882  | 1.606e+04 | 788.7     | 0.2863    | 78.65     | 1.803     | 9.791     | 0.0001417 | 0.2116    |
# ************************************
# Train AUC       :  0.8811
# Test AUC       :  0.7322
# Validation AUC :  0.7123
# {'activation': 'relu', 'alpha': 8.446933073799428e-05, 'batch_size': 667, 'beta_1': 0.025330494254996117, 'beta_2': 0.5177684851007125, 'early_stopping': False, 'epsilon': 1.4340931801008547e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.005221594352379507, 'max_fun': 14780, 'max_iter': 672, 'momentum': 0.44697971829672334, 'n_iter_no_change': 5, 'nesterovs_momentum': True, 'power_t': 0.9049104186876983, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.00040460560018380255, 'validation_fraction': 0.35585066355142003, 'verbose': False, 'warm_start': False}
# | 11        | 0.7322    | 8.447e-05 | 667.7     | 0.02533   | 0.5178    | 1.434e-08 | 0.005222  | 1.478e+04 | 672.0     | 0.447     | 5.812     | 0.9049    | 8.793     | 0.0004046 | 0.3559    |
# ************************************
# Train AUC       :  0.9365
# Test AUC       :  0.7732
# Validation AUC :  0.7487
# {'activation': 'relu', 'alpha': 0.0005751205218045944, 'batch_size': 678, 'beta_1': 0.14329548543505288, 'beta_2': 0.29036738265704487, 'early_stopping': False, 'epsilon': 2.3346369105501717e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00984808053033994, 'max_fun': 42253, 'max_iter': 740, 'momentum': 0.6628446767142279, 'n_iter_no_change': 19, 'nesterovs_momentum': True, 'power_t': 1.915660625249391, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.0003807152128503705, 'validation_fraction': 0.6160633714913661, 'verbose': False, 'warm_start': False}
# | 12        | 0.7732    | 0.0005751 | 678.5     | 0.1433    | 0.2904    | 2.335e-08 | 0.009848  | 4.225e+04 | 740.3     | 0.6628    | 19.95     | 1.916     | 4.369     | 0.0003807 | 0.6161    |
# ************************************
# Train AUC       :  0.8872
# Test AUC       :  0.7374
# Validation AUC :  0.7143
# {'activation': 'relu', 'alpha': 0.0003495932442512085, 'batch_size': 174, 'beta_1': 0.16276034399778694, 'beta_2': 0.9304862393773539, 'early_stopping': False, 'epsilon': 7.197609937475623e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0008428491278638529, 'max_fun': 33193, 'max_iter': 290, 'momentum': 0.7827287646401386, 'n_iter_no_change': 49, 'nesterovs_momentum': True, 'power_t': 1.5754160471908212, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.0009917391857348543, 'validation_fraction': 0.7006609066829343, 'verbose': False, 'warm_start': False}
# | 13        | 0.7374    | 0.0003496 | 174.3     | 0.1628    | 0.9305    | 7.198e-08 | 0.0008428 | 3.319e+04 | 290.4     | 0.7827    | 49.16     | 1.575     | 8.734     | 0.0009917 | 0.7007    |
# ************************************
# Train AUC       :  0.8941
# Test AUC       :  0.7486
# Validation AUC :  0.7264
# {'activation': 'relu', 'alpha': 0.00016195943973799362, 'batch_size': 523, 'beta_1': 0.036659218552077655, 'beta_2': 0.03744209094198159, 'early_stopping': False, 'epsilon': 5.380717187405012e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0010696468898175474, 'max_fun': 30837, 'max_iter': 442, 'momentum': 0.13299397174343996, 'n_iter_no_change': 20, 'nesterovs_momentum': True, 'power_t': 1.644317887824625, 'random_state': 2, 'shuffle': True, 'solver': 'adam', 'tol': 0.0003186590453195721, 'validation_fraction': 0.9272045601330193, 'verbose': False, 'warm_start': False}
# | 14        | 0.7486    | 0.000162  | 523.0     | 0.03666   | 0.03744   | 5.381e-08 | 0.00107   | 3.084e+04 | 442.6     | 0.133     | 20.63     | 1.644     | 2.215     | 0.0003187 | 0.9272    |
# ************************************
# Train AUC       :  0.8652
# Test AUC       :  0.7379
# Validation AUC :  0.7058
# {'activation': 'relu', 'alpha': 0.0009410148705745099, 'batch_size': 604, 'beta_1': 0.21577206544441474, 'beta_2': 0.3900641920720652, 'early_stopping': False, 'epsilon': 1.416237075437347e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001435457365358224, 'max_fun': 45454, 'max_iter': 188, 'momentum': 0.475475411967097, 'n_iter_no_change': 69, 'nesterovs_momentum': True, 'power_t': 1.968534457687696, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.0009588956162914008, 'validation_fraction': 0.2908871602869164, 'verbose': False, 'warm_start': False}
# | 15        | 0.7379    | 0.000941  | 604.8     | 0.2158    | 0.3901    | 1.416e-08 | 0.001435  | 4.545e+04 | 188.4     | 0.4755    | 69.52     | 1.969     | 8.977     | 0.0009589 | 0.2909    |
# ************************************
# Train AUC       :  0.9519
# Test AUC       :  0.7803
# Validation AUC :  0.7592
# {'activation': 'relu', 'alpha': 0.00034237554038790387, 'batch_size': 420, 'beta_1': 0.6786390238209229, 'beta_2': 0.6491388591726635, 'early_stopping': False, 'epsilon': 7.248227018847773e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00901897504283666, 'max_fun': 44542, 'max_iter': 337, 'momentum': 0.020056994667192796, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.71566465520907, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.00027001098264970894, 'validation_fraction': 0.2737373210485282, 'verbose': False, 'warm_start': False}
# | 16        | 0.7803    | 0.0003424 | 420.8     | 0.6786    | 0.6491    | 7.248e-08 | 0.009019  | 4.454e+04 | 337.2     | 0.02006   | 10.04     | 0.7157    | 4.872     | 0.00027   | 0.2737    |
# ************************************
# Train AUC       :  0.9265
# Test AUC       :  0.7631
# Validation AUC :  0.7599
# {'activation': 'relu', 'alpha': 0.000575439632585874, 'batch_size': 320, 'beta_1': 0.2939101946340127, 'beta_2': 0.49670899852531625, 'early_stopping': False, 'epsilon': 7.01325015898871e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00795587440421098, 'max_fun': 46197, 'max_iter': 278, 'momentum': 0.6015596505469801, 'n_iter_no_change': 50, 'nesterovs_momentum': True, 'power_t': 1.982561692339215, 'random_state': 9, 'shuffle': True, 'solver': 'adam', 'tol': 0.0003022380456526476, 'validation_fraction': 0.1472248953919758, 'verbose': False, 'warm_start': False}
# | 17        | 0.7631    | 0.0005754 | 320.0     | 0.2939    | 0.4967    | 7.013e-08 | 0.007956  | 4.62e+04  | 278.8     | 0.6016    | 50.44     | 1.983     | 9.355     | 0.0003022 | 0.1472    |
# ************************************
# Train AUC       :  0.9036
# Test AUC       :  0.7514
# Validation AUC :  0.7383
# {'activation': 'relu', 'alpha': 0.0008052605361379073, 'batch_size': 356, 'beta_1': 0.7420132949797266, 'beta_2': 0.4801850993229836, 'early_stopping': False, 'epsilon': 1.2777705536149031e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0069714914925391135, 'max_fun': 47893, 'max_iter': 107, 'momentum': 0.07703632423745854, 'n_iter_no_change': 90, 'nesterovs_momentum': True, 'power_t': 1.4737489640450112, 'random_state': 5, 'shuffle': True, 'solver': 'adam', 'tol': 0.0003599649437336186, 'validation_fraction': 0.7449160346727624, 'verbose': False, 'warm_start': False}
# | 18        | 0.7514    | 0.0008053 | 356.2     | 0.742     | 0.4802    | 1.278e-08 | 0.006971  | 4.789e+04 | 107.9     | 0.07704   | 90.83     | 1.474     | 5.959     | 0.00036   | 0.7449    |
# ************************************
# Train AUC       :  0.9172
# Test AUC       :  0.7668
# Validation AUC :  0.7338
# {'activation': 'relu', 'alpha': 0.00024375631079502608, 'batch_size': 380, 'beta_1': 0.7839308999179138, 'beta_2': 0.02982132019024686, 'early_stopping': False, 'epsilon': 8.012488871329126e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0006952474709483385, 'max_fun': 28360, 'max_iter': 798, 'momentum': 0.3980007657732135, 'n_iter_no_change': 61, 'nesterovs_momentum': True, 'power_t': 1.0627601878372253, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.00036900607318353666, 'validation_fraction': 0.9737990800705951, 'verbose': False, 'warm_start': False}
# | 19        | 0.7668    | 0.0002438 | 380.0     | 0.7839    | 0.02982   | 8.012e-08 | 0.0006952 | 2.836e+04 | 798.7     | 0.398     | 61.88     | 1.063     | 4.342     | 0.000369  | 0.9738    |
# ************************************
# Train AUC       :  0.8602
# Test AUC       :  0.7356
# Validation AUC :  0.6943
# {'activation': 'relu', 'alpha': 0.0006666815874069241, 'batch_size': 328, 'beta_1': 0.9922343293374399, 'beta_2': 0.8910189469145703, 'early_stopping': False, 'epsilon': 3.22334364878193e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.003408248820602218, 'max_fun': 25932, 'max_iter': 107, 'momentum': 0.5546279972934204, 'n_iter_no_change': 89, 'nesterovs_momentum': True, 'power_t': 1.553080858310806, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.00035932994361983475, 'validation_fraction': 0.22472623089347954, 'verbose': False, 'warm_start': False}
# | 20        | 0.7356    | 0.0006667 | 328.5     | 0.9922    | 0.891     | 3.223e-08 | 0.003408  | 2.593e+04 | 107.4     | 0.5546    | 89.64     | 1.553     | 8.437     | 0.0003593 | 0.2247    |
# ************************************
# Train AUC       :  0.8988
# Test AUC       :  0.7476
# Validation AUC :  0.7344
# {'activation': 'relu', 'alpha': 0.0003315837184161336, 'batch_size': 145, 'beta_1': 0.3280087729694159, 'beta_2': 0.7604547546797147, 'early_stopping': False, 'epsilon': 9.642490658831407e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00055956740871916, 'max_fun': 40012, 'max_iter': 630, 'momentum': 0.2168699955104888, 'n_iter_no_change': 34, 'nesterovs_momentum': True, 'power_t': 1.3058529635107337, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.0008131819648141144, 'validation_fraction': 0.3695312284243709, 'verbose': False, 'warm_start': False}
# | 21        | 0.7476    | 0.0003316 | 145.7     | 0.328     | 0.7605    | 9.642e-08 | 0.0005596 | 4.001e+04 | 630.2     | 0.2169    | 34.76     | 1.306     | 8.869     | 0.0008132 | 0.3695    |
# ************************************
# Train AUC       :  0.8362
# Test AUC       :  0.7097
# Validation AUC :  0.6728
# {'activation': 'relu', 'alpha': 0.0007328046336680091, 'batch_size': 430, 'beta_1': 0.5792659542887701, 'beta_2': 0.20269397086619378, 'early_stopping': False, 'epsilon': 8.722252184661799e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0007683511254869715, 'max_fun': 33058, 'max_iter': 108, 'momentum': 0.3288190628411506, 'n_iter_no_change': 56, 'nesterovs_momentum': True, 'power_t': 1.7880462670317032, 'random_state': 2, 'shuffle': True, 'solver': 'adam', 'tol': 0.00019580464949011924, 'validation_fraction': 0.8544288121408438, 'verbose': False, 'warm_start': False}
# | 22        | 0.7097    | 0.0007328 | 430.9     | 0.5793    | 0.2027    | 8.722e-08 | 0.0007684 | 3.306e+04 | 108.7     | 0.3288    | 56.1      | 1.788     | 2.832     | 0.0001958 | 0.8544    |
# ************************************
# Train AUC       :  0.9236
# Test AUC       :  0.7537
# Validation AUC :  0.7454
# {'activation': 'relu', 'alpha': 0.0004999241089781984, 'batch_size': 718, 'beta_1': 0.8143015600206345, 'beta_2': 0.37049265756865524, 'early_stopping': False, 'epsilon': 1.3124787984681227e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.009269713733422526, 'max_fun': 38343, 'max_iter': 267, 'momentum': 0.30362237843559103, 'n_iter_no_change': 12, 'nesterovs_momentum': True, 'power_t': 1.2655101047508701, 'random_state': 6, 'shuffle': True, 'solver': 'adam', 'tol': 0.0004398041480748955, 'validation_fraction': 0.2647230624934085, 'verbose': False, 'warm_start': False}
# | 23        | 0.7537    | 0.0004999 | 718.1     | 0.8143    | 0.3705    | 1.312e-08 | 0.00927   | 3.834e+04 | 267.5     | 0.3036    | 12.95     | 1.266     | 6.291     | 0.0004398 | 0.2647    |
# ************************************
# Train AUC       :  0.9133
# Test AUC       :  0.7567
# Validation AUC :  0.7262
# {'activation': 'relu', 'alpha': 0.00034081355414781767, 'batch_size': 422, 'beta_1': 0.24450540299108625, 'beta_2': 0.528985452939483, 'early_stopping': False, 'epsilon': 9.504604693464447e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.003698250840216931, 'max_fun': 24817, 'max_iter': 310, 'momentum': 0.3775628880897933, 'n_iter_no_change': 66, 'nesterovs_momentum': True, 'power_t': 1.4585774890683094, 'random_state': 3, 'shuffle': True, 'solver': 'adam', 'tol': 0.0005162619273623336, 'validation_fraction': 0.10019136103982118, 'verbose': False, 'warm_start': False}
# | 24        | 0.7567    | 0.0003408 | 422.1     | 0.2445    | 0.529     | 9.505e-08 | 0.003698  | 2.482e+04 | 310.4     | 0.3776    | 66.33     | 1.459     | 3.523     | 0.0005163 | 0.1002    |
# ************************************
# Train AUC       :  0.9627
# Test AUC       :  0.7561
# Validation AUC :  0.7533
# {'activation': 'relu', 'alpha': 0.0009228288460484459, 'batch_size': 458, 'beta_1': 0.3649315114307272, 'beta_2': 0.09930431917417704, 'early_stopping': False, 'epsilon': 2.5202911271995133e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.007611292706675311, 'max_fun': 17409, 'max_iter': 610, 'momentum': 0.6778872076692966, 'n_iter_no_change': 74, 'nesterovs_momentum': True, 'power_t': 1.2743122715486093, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0004453163629086896, 'validation_fraction': 0.9483283904373351, 'verbose': False, 'warm_start': False}
# | 25        | 0.7561    | 0.0009228 | 458.4     | 0.3649    | 0.0993    | 2.52e-08  | 0.007611  | 1.741e+04 | 610.6     | 0.6779    | 74.35     | 1.274     | 1.049     | 0.0004453 | 0.9483    |
# ************************************
# Train AUC       :  0.9347
# Test AUC       :  0.7726
# Validation AUC :  0.7552
# {'activation': 'relu', 'alpha': 0.00013225131324605933, 'batch_size': 522, 'beta_1': 0.26794248133856535, 'beta_2': 0.5597033562555195, 'early_stopping': False, 'epsilon': 9.259945689797524e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.002437830299297646, 'max_fun': 19771, 'max_iter': 793, 'momentum': 0.5960196386415024, 'n_iter_no_change': 15, 'nesterovs_momentum': True, 'power_t': 1.5119186106113596, 'random_state': 2, 'shuffle': True, 'solver': 'adam', 'tol': 0.00013709725985710367, 'validation_fraction': 0.01772890665470872, 'verbose': False, 'warm_start': False}
# | 26        | 0.7726    | 0.0001323 | 522.9     | 0.2679    | 0.5597    | 9.26e-08  | 0.002438  | 1.977e+04 | 793.3     | 0.596     | 15.58     | 1.512     | 2.941     | 0.0001371 | 0.01773   |
# ************************************
# Train AUC       :  0.9362
# Test AUC       :  0.7752
# Validation AUC :  0.7603
# {'activation': 'relu', 'alpha': 0.0007692033485486209, 'batch_size': 665, 'beta_1': 0.5142021959006857, 'beta_2': 0.5274399493252224, 'early_stopping': False, 'epsilon': 6.311482223374922e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.009352493351989365, 'max_fun': 32395, 'max_iter': 372, 'momentum': 0.5586870075739714, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 1.2249989348521342, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.00011210058992493663, 'validation_fraction': 0.32356211716384176, 'verbose': False, 'warm_start': False}
# | 27        | 0.7752    | 0.0007692 | 665.7     | 0.5142    | 0.5274    | 6.311e-08 | 0.009352  | 3.24e+04  | 372.5     | 0.5587    | 10.16     | 1.225     | 1.776     | 0.0001121 | 0.3236    |
# ************************************
# Train AUC       :  0.8176
# Test AUC       :  0.6759
# Validation AUC :  0.628
# {'activation': 'relu', 'alpha': 0.0008003146024761995, 'batch_size': 406, 'beta_1': 0.9931542990554448, 'beta_2': 0.730100129968266, 'early_stopping': False, 'epsilon': 7.805490982722087e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0006744717255190151, 'max_fun': 27141, 'max_iter': 786, 'momentum': 0.3363580226269902, 'n_iter_no_change': 24, 'nesterovs_momentum': True, 'power_t': 0.7065731814330638, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.00034658327935442346, 'validation_fraction': 0.9139928680204455, 'verbose': False, 'warm_start': False}
# | 28        | 0.6759    | 0.0008003 | 407.0     | 0.9932    | 0.7301    | 7.805e-08 | 0.0006745 | 2.714e+04 | 786.1     | 0.3364    | 24.03     | 0.7066    | 4.776     | 0.0003466 | 0.914     |
# ************************************
# Train AUC       :  0.9402
# Test AUC       :  0.7759
# Validation AUC :  0.7666
# {'activation': 'relu', 'alpha': 0.0007082799810480228, 'batch_size': 523, 'beta_1': 0.4447959152998633, 'beta_2': 0.15131474732517147, 'early_stopping': False, 'epsilon': 6.557729391065665e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.004208833364187944, 'max_fun': 11601, 'max_iter': 593, 'momentum': 0.6051248406497559, 'n_iter_no_change': 16, 'nesterovs_momentum': True, 'power_t': 1.0714523138212342, 'random_state': 7, 'shuffle': True, 'solver': 'adam', 'tol': 0.0004709107201506837, 'validation_fraction': 0.24302093214029108, 'verbose': False, 'warm_start': False}
# | 29        | 0.7759    | 0.0007083 | 523.8     | 0.4448    | 0.1513    | 6.558e-08 | 0.004209  | 1.16e+04  | 593.8     | 0.6051    | 16.18     | 1.071     | 7.3       | 0.0004709 | 0.243     |
# ************************************
# Train AUC       :  0.9205
# Test AUC       :  0.7526
# Validation AUC :  0.7645
# {'activation': 'relu', 'alpha': 0.0007955321288174208, 'batch_size': 727, 'beta_1': 0.9522653262726793, 'beta_2': 0.5367472093662322, 'early_stopping': False, 'epsilon': 3.6991432689960305e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0030159903679338007, 'max_fun': 43062, 'max_iter': 711, 'momentum': 0.6320976025310612, 'n_iter_no_change': 46, 'nesterovs_momentum': True, 'power_t': 1.5182079364218564, 'random_state': 2, 'shuffle': True, 'solver': 'adam', 'tol': 0.0009296757211693676, 'validation_fraction': 0.03994797883949097, 'verbose': False, 'warm_start': False}
# | 30        | 0.7526    | 0.0007955 | 727.5     | 0.9523    | 0.5367    | 3.699e-08 | 0.003016  | 4.306e+04 | 711.3     | 0.6321    | 46.73     | 1.518     | 2.637     | 0.0009297 | 0.03995   |
# ************************************
# Train AUC       :  0.8691
# Test AUC       :  0.7251
# Validation AUC :  0.7028
# {'activation': 'relu', 'alpha': 0.00016177054636898092, 'batch_size': 715, 'beta_1': 0.09997398187883744, 'beta_2': 0.8494205702829337, 'early_stopping': False, 'epsilon': 4.0277562179516005e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0071024957367607534, 'max_fun': 18294, 'max_iter': 363, 'momentum': 0.6660460809732314, 'n_iter_no_change': 8, 'nesterovs_momentum': True, 'power_t': 1.780606199814393, 'random_state': 7, 'shuffle': True, 'solver': 'adam', 'tol': 0.0006223323018914264, 'validation_fraction': 0.618067448855136, 'verbose': False, 'warm_start': False}
# | 31        | 0.7251    | 0.0001618 | 715.1     | 0.09997   | 0.8494    | 4.028e-08 | 0.007102  | 1.829e+04 | 363.5     | 0.666     | 8.407     | 1.781     | 7.495     | 0.0006223 | 0.6181    |
# ************************************
# Train AUC       :  0.9029
# Test AUC       :  0.7454
# Validation AUC :  0.7247
# {'activation': 'relu', 'alpha': 0.0006222498908501562, 'batch_size': 401, 'beta_1': 0.12215470672065387, 'beta_2': 0.011550591162354129, 'early_stopping': False, 'epsilon': 4.439163223105315e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00980638981463833, 'max_fun': 12159, 'max_iter': 677, 'momentum': 0.7835523643737493, 'n_iter_no_change': 10, 'nesterovs_momentum': True, 'power_t': 0.7725577983775522, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.000489232969782371, 'validation_fraction': 0.8475186591996753, 'verbose': False, 'warm_start': False}
# | 32        | 0.7454    | 0.0006222 | 401.7     | 0.1222    | 0.01155   | 4.439e-08 | 0.009806  | 1.216e+04 | 677.5     | 0.7836    | 10.27     | 0.7726    | 4.436     | 0.0004892 | 0.8475    |
# ************************************
# Train AUC       :  0.9282
# Test AUC       :  0.7707
# Validation AUC :  0.7516
# {'activation': 'relu', 'alpha': 0.00017186898020240827, 'batch_size': 612, 'beta_1': 0.5764407334461495, 'beta_2': 0.9428149528152049, 'early_stopping': False, 'epsilon': 1.1636817468643954e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.009868910014168696, 'max_fun': 34726, 'max_iter': 245, 'momentum': 0.24152753793671, 'n_iter_no_change': 70, 'nesterovs_momentum': True, 'power_t': 1.7403254074143175, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0009388773052583909, 'validation_fraction': 0.44620125215724915, 'verbose': False, 'warm_start': False}
# | 33        | 0.7707    | 0.0001719 | 612.2     | 0.5764    | 0.9428    | 1.164e-08 | 0.009869  | 3.473e+04 | 245.2     | 0.2415    | 70.02     | 1.74      | 1.496     | 0.0009389 | 0.4462    |
# ************************************
# Train AUC       :  0.862
# Test AUC       :  0.7183
# Validation AUC :  0.6963
# {'activation': 'relu', 'alpha': 0.0003582874342755082, 'batch_size': 778, 'beta_1': 0.7747043800783066, 'beta_2': 0.13706902126728115, 'early_stopping': False, 'epsilon': 9.168999622094792e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0007610219405039737, 'max_fun': 25039, 'max_iter': 390, 'momentum': 0.6463046855365264, 'n_iter_no_change': 92, 'nesterovs_momentum': True, 'power_t': 0.5360854044020393, 'random_state': 7, 'shuffle': True, 'solver': 'adam', 'tol': 0.0006602325625578137, 'validation_fraction': 0.48062678441172146, 'verbose': False, 'warm_start': False}
# | 34        | 0.7183    | 0.0003583 | 778.9     | 0.7747    | 0.1371    | 9.169e-08 | 0.000761  | 2.504e+04 | 390.8     | 0.6463    | 92.79     | 0.5361    | 7.191     | 0.0006602 | 0.4806    |
# ************************************
# Train AUC       :  0.9131
# Test AUC       :  0.7559
# Validation AUC :  0.7399
# {'activation': 'relu', 'alpha': 0.0003069247943528595, 'batch_size': 539, 'beta_1': 0.8020802233774122, 'beta_2': 0.7772779132566143, 'early_stopping': False, 'epsilon': 5.886443042770516e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.006368476393698025, 'max_fun': 42324, 'max_iter': 283, 'momentum': 0.6119190979077512, 'n_iter_no_change': 49, 'nesterovs_momentum': True, 'power_t': 0.563462135088445, 'random_state': 6, 'shuffle': True, 'solver': 'adam', 'tol': 0.0004178828278172572, 'validation_fraction': 0.2486438920682762, 'verbose': False, 'warm_start': False}
# | 35        | 0.7559    | 0.0003069 | 539.8     | 0.8021    | 0.7773    | 5.886e-08 | 0.006368  | 4.232e+04 | 283.4     | 0.6119    | 49.71     | 0.5635    | 6.084     | 0.0004179 | 0.2486    |
# ************************************
# Train AUC       :  0.9142
# Test AUC       :  0.7279
# Validation AUC :  0.7247
# {'activation': 'relu', 'alpha': 0.00014645787632010463, 'batch_size': 153, 'beta_1': 0.8934926687769119, 'beta_2': 0.08979379495503115, 'early_stopping': False, 'epsilon': 8.224418118880826e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00874186299467771, 'max_fun': 13833, 'max_iter': 775, 'momentum': 0.1365134470414161, 'n_iter_no_change': 47, 'nesterovs_momentum': True, 'power_t': 1.8830275343448788, 'random_state': 5, 'shuffle': True, 'solver': 'adam', 'tol': 0.000904469451405861, 'validation_fraction': 0.07476789119671368, 'verbose': False, 'warm_start': False}
# | 36        | 0.7279    | 0.0001465 | 153.5     | 0.8935    | 0.08979   | 8.224e-08 | 0.008742  | 1.383e+04 | 775.1     | 0.1365    | 47.23     | 1.883     | 5.553     | 0.0009045 | 0.07477   |
# ************************************
# Train AUC       :  0.8806
# Test AUC       :  0.7329
# Validation AUC :  0.709
# {'activation': 'relu', 'alpha': 0.000776086712950668, 'batch_size': 125, 'beta_1': 0.2914438000302344, 'beta_2': 0.5900974440287674, 'early_stopping': False, 'epsilon': 5.859717838175287e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.001571695095771006, 'max_fun': 49755, 'max_iter': 119, 'momentum': 0.0673340728592714, 'n_iter_no_change': 15, 'nesterovs_momentum': True, 'power_t': 1.1655194249735632, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.0003716143420551979, 'validation_fraction': 0.6613815146808034, 'verbose': False, 'warm_start': False}
# | 37        | 0.7329    | 0.0007761 | 125.7     | 0.2914    | 0.5901    | 5.86e-08  | 0.001572  | 4.976e+04 | 119.7     | 0.06733   | 15.02     | 1.166     | 8.583     | 0.0003716 | 0.6614    |
# ************************************
# Train AUC       :  0.8782
# Test AUC       :  0.7344
# Validation AUC :  0.6961
# {'activation': 'relu', 'alpha': 0.0006013534370508356, 'batch_size': 523, 'beta_1': 0.7705748633075792, 'beta_2': 0.510225170431234, 'early_stopping': False, 'epsilon': 9.294064128474534e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.002153120387641914, 'max_fun': 20729, 'max_iter': 213, 'momentum': 0.6767780271256619, 'n_iter_no_change': 40, 'nesterovs_momentum': True, 'power_t': 1.9426506254094487, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.0009236887731908465, 'validation_fraction': 0.33748124368606636, 'verbose': False, 'warm_start': False}
# | 38        | 0.7344    | 0.0006014 | 523.0     | 0.7706    | 0.5102    | 9.294e-08 | 0.002153  | 2.073e+04 | 213.2     | 0.6768    | 40.19     | 1.943     | 4.281     | 0.0009237 | 0.3375    |
# ************************************
# Train AUC       :  0.9641
# Test AUC       :  0.7834
# Validation AUC :  0.7653
# {'activation': 'relu', 'alpha': 0.000868415436438587, 'batch_size': 409, 'beta_1': 0.5780030973536489, 'beta_2': 0.8093566329178912, 'early_stopping': False, 'epsilon': 3.032212975325663e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.007840651810482723, 'max_fun': 44071, 'max_iter': 579, 'momentum': 0.1405214326127452, 'n_iter_no_change': 29, 'nesterovs_momentum': True, 'power_t': 1.2031069055414467, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.0004520670166544025, 'validation_fraction': 0.29296458729229247, 'verbose': False, 'warm_start': False}
# | 39        | 0.7834    | 0.0008684 | 409.3     | 0.578     | 0.8094    | 3.032e-08 | 0.007841  | 4.407e+04 | 579.7     | 0.1405    | 29.92     | 1.203     | 8.106     | 0.0004521 | 0.293     |
# ************************************
# Train AUC       :  0.8488
# Test AUC       :  0.695
# Validation AUC :  0.6642
# {'activation': 'relu', 'alpha': 0.000666958672589882, 'batch_size': 564, 'beta_1': 0.977723861647091, 'beta_2': 0.323036980797446, 'early_stopping': False, 'epsilon': 2.6830432705272568e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00729007467705611, 'max_fun': 10537, 'max_iter': 590, 'momentum': 0.577596220089516, 'n_iter_no_change': 54, 'nesterovs_momentum': True, 'power_t': 1.3746453075716014, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.0005082716078789881, 'validation_fraction': 0.7988322996187892, 'verbose': False, 'warm_start': False}
# | 40        | 0.695     | 0.000667  | 564.0     | 0.9777    | 0.323     | 2.683e-08 | 0.00729   | 1.054e+04 | 590.5     | 0.5776    | 54.95     | 1.375     | 8.224     | 0.0005083 | 0.7988    |
# ************************************
# Train AUC       :  0.9361
# Test AUC       :  0.7687
# Validation AUC :  0.761
# {'activation': 'relu', 'alpha': 0.0008285161710928196, 'batch_size': 275, 'beta_1': 0.9622079593113609, 'beta_2': 0.2601904110605592, 'early_stopping': False, 'epsilon': 5.40926713980237e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0015780242290388134, 'max_fun': 25210, 'max_iter': 673, 'momentum': 0.5847244672631897, 'n_iter_no_change': 37, 'nesterovs_momentum': True, 'power_t': 0.7902935731012473, 'random_state': 6, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001064154207197548, 'validation_fraction': 0.10541738344936513, 'verbose': False, 'warm_start': False}
# | 41        | 0.7687    | 0.0008285 | 275.2     | 0.9622    | 0.2602    | 5.409e-08 | 0.001578  | 2.521e+04 | 673.8     | 0.5847    | 37.81     | 0.7903    | 6.361     | 0.0001064 | 0.1054    |
# ************************************
# Train AUC       :  0.9661
# Test AUC       :  0.7776
# Validation AUC :  0.7693
# {'activation': 'relu', 'alpha': 0.0003203110826334463, 'batch_size': 535, 'beta_1': 0.32523133414969374, 'beta_2': 0.45650003782841264, 'early_stopping': False, 'epsilon': 6.803951968022163e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.006977365686348245, 'max_fun': 15011, 'max_iter': 778, 'momentum': 0.6286983608306603, 'n_iter_no_change': 59, 'nesterovs_momentum': True, 'power_t': 1.0027158209048492, 'random_state': 2, 'shuffle': True, 'solver': 'adam', 'tol': 0.00041132107448055245, 'validation_fraction': 0.5879257096191717, 'verbose': False, 'warm_start': False}
# | 42        | 0.7776    | 0.0003203 | 535.6     | 0.3252    | 0.4565    | 6.804e-08 | 0.006977  | 1.501e+04 | 778.8     | 0.6287    | 59.43     | 1.003     | 2.782     | 0.0004113 | 0.5879    |
# ************************************
# Train AUC       :  0.9227
# Test AUC       :  0.7684
# Validation AUC :  0.7471
# {'activation': 'relu', 'alpha': 0.0003103703258373645, 'batch_size': 231, 'beta_1': 0.013496341738961748, 'beta_2': 0.7735239628621468, 'early_stopping': False, 'epsilon': 6.125968656485954e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0027642912369050528, 'max_fun': 31353, 'max_iter': 306, 'momentum': 0.06480487050271355, 'n_iter_no_change': 83, 'nesterovs_momentum': True, 'power_t': 1.565309567091135, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.0008541675486004066, 'validation_fraction': 0.06457702950380273, 'verbose': False, 'warm_start': False}
# | 43        | 0.7684    | 0.0003104 | 231.4     | 0.0135    | 0.7735    | 6.126e-08 | 0.002764  | 3.135e+04 | 306.1     | 0.0648    | 83.87     | 1.565     | 4.168     | 0.0008542 | 0.06458   |
# ************************************
# Train AUC       :  0.9385
# Test AUC       :  0.7832
# Validation AUC :  0.7451
# {'activation': 'relu', 'alpha': 0.0004334761987961463, 'batch_size': 612, 'beta_1': 0.5730930721621036, 'beta_2': 0.3936395562775893, 'early_stopping': False, 'epsilon': 4.410400566793e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.004879150684354334, 'max_fun': 23007, 'max_iter': 601, 'momentum': 0.00853212375091239, 'n_iter_no_change': 99, 'nesterovs_momentum': True, 'power_t': 0.7840252795974727, 'random_state': 6, 'shuffle': True, 'solver': 'adam', 'tol': 0.00016843735851457172, 'validation_fraction': 0.9939111883095141, 'verbose': False, 'warm_start': False}
# | 44        | 0.7832    | 0.0004335 | 612.9     | 0.5731    | 0.3936    | 4.41e-08  | 0.004879  | 2.301e+04 | 601.1     | 0.008532  | 99.15     | 0.784     | 6.742     | 0.0001684 | 0.9939    |
# ************************************
# Train AUC       :  0.958
# Test AUC       :  0.7998
# Validation AUC :  0.7674
# {'activation': 'relu', 'alpha': 0.0005656938640490419, 'batch_size': 343, 'beta_1': 0.4446492621456912, 'beta_2': 0.46646448266480445, 'early_stopping': False, 'epsilon': 6.009229424373674e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0032034174061037046, 'max_fun': 44032, 'max_iter': 789, 'momentum': 0.13775034461799884, 'n_iter_no_change': 77, 'nesterovs_momentum': True, 'power_t': 1.642605596631681, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.00010244376257628324, 'validation_fraction': 0.9682502535343684, 'verbose': False, 'warm_start': False}
# | 45        | 0.7998    | 0.0005657 | 344.0     | 0.4446    | 0.4665    | 6.009e-08 | 0.003203  | 4.403e+04 | 789.7     | 0.1378    | 77.82     | 1.643     | 4.895     | 0.0001024 | 0.9683    |
# ************************************
# Train AUC       :  0.8898
# Test AUC       :  0.7521
# Validation AUC :  0.7028
# {'activation': 'relu', 'alpha': 0.0009575094490673427, 'batch_size': 707, 'beta_1': 0.770191728573237, 'beta_2': 0.9274195601963472, 'early_stopping': False, 'epsilon': 7.502750580078249e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0028344466481917967, 'max_fun': 39927, 'max_iter': 188, 'momentum': 0.055346610307766, 'n_iter_no_change': 54, 'nesterovs_momentum': True, 'power_t': 1.3695949657797233, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.0005465725858567093, 'validation_fraction': 0.7612076401898097, 'verbose': False, 'warm_start': False}
# | 46        | 0.7521    | 0.0009575 | 707.5     | 0.7702    | 0.9274    | 7.503e-08 | 0.002834  | 3.993e+04 | 188.1     | 0.05535   | 55.0      | 1.37      | 4.13      | 0.0005466 | 0.7612    |
# ************************************
# Train AUC       :  0.932
# Test AUC       :  0.7639
# Validation AUC :  0.7634
# {'activation': 'relu', 'alpha': 0.0009011444389218513, 'batch_size': 648, 'beta_1': 0.35513797226429333, 'beta_2': 0.06478082645166705, 'early_stopping': False, 'epsilon': 9.352870550779374e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.008475831151047724, 'max_fun': 12304, 'max_iter': 769, 'momentum': 0.79165532096415, 'n_iter_no_change': 17, 'nesterovs_momentum': True, 'power_t': 1.1883688758917024, 'random_state': 5, 'shuffle': True, 'solver': 'adam', 'tol': 0.00041004207486711864, 'validation_fraction': 0.522350137861748, 'verbose': False, 'warm_start': False}
# | 47        | 0.7639    | 0.0009011 | 648.3     | 0.3551    | 0.06478   | 9.353e-08 | 0.008476  | 1.23e+04  | 769.7     | 0.7917    | 17.73     | 1.188     | 5.917     | 0.00041   | 0.5224    |
# ************************************
# Train AUC       :  0.918
# Test AUC       :  0.7673
# Validation AUC :  0.764
# {'activation': 'relu', 'alpha': 0.0007256941676458083, 'batch_size': 156, 'beta_1': 0.44480538620267296, 'beta_2': 0.6245297572992754, 'early_stopping': False, 'epsilon': 1.53685196663927e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00872097897693789, 'max_fun': 33128, 'max_iter': 104, 'momentum': 0.7046609188097012, 'n_iter_no_change': 93, 'nesterovs_momentum': True, 'power_t': 0.9044113597654753, 'random_state': 5, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001990731459606835, 'validation_fraction': 0.3373628438999191, 'verbose': False, 'warm_start': False}
# | 48        | 0.7673    | 0.0007257 | 156.1     | 0.4448    | 0.6245    | 1.537e-08 | 0.008721  | 3.313e+04 | 105.0     | 0.7047    | 93.51     | 0.9044    | 5.956     | 0.0001991 | 0.3374    |
# ************************************
# Train AUC       :  0.9087
# Test AUC       :  0.7678
# Validation AUC :  0.7116
# {'activation': 'relu', 'alpha': 0.00029040557768879414, 'batch_size': 799, 'beta_1': 0.7217366226987423, 'beta_2': 0.6621572445952265, 'early_stopping': False, 'epsilon': 5.711378721697301e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.002078339295602091, 'max_fun': 45634, 'max_iter': 444, 'momentum': 0.5350546633080973, 'n_iter_no_change': 75, 'nesterovs_momentum': True, 'power_t': 0.8418999686792326, 'random_state': 6, 'shuffle': True, 'solver': 'adam', 'tol': 0.00012712600424533174, 'validation_fraction': 0.7479967145749918, 'verbose': False, 'warm_start': False}
# | 49        | 0.7678    | 0.0002904 | 799.2     | 0.7217    | 0.6622    | 5.711e-08 | 0.002078  | 4.563e+04 | 444.6     | 0.5351    | 75.48     | 0.8419    | 6.269     | 0.0001271 | 0.748     |
# ************************************
# Train AUC       :  0.9425
# Test AUC       :  0.7685
# Validation AUC :  0.756
# {'activation': 'relu', 'alpha': 0.00038408241189326423, 'batch_size': 138, 'beta_1': 0.2664556047169404, 'beta_2': 0.25645950556259767, 'early_stopping': False, 'epsilon': 1.0236207020806095e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.009714728335327473, 'max_fun': 23854, 'max_iter': 174, 'momentum': 0.5693303027845669, 'n_iter_no_change': 31, 'nesterovs_momentum': True, 'power_t': 0.5960355670128581, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.000634626483826684, 'validation_fraction': 0.37640009499563987, 'verbose': False, 'warm_start': False}
# | 50        | 0.7685    | 0.0003841 | 138.4     | 0.2665    | 0.2565    | 1.024e-08 | 0.009715  | 2.385e+04 | 174.9     | 0.5693    | 31.97     | 0.596     | 4.554     | 0.0006346 | 0.3764    |
# ************************************
# Train AUC       :  0.8673
# Test AUC       :  0.7195
# Validation AUC :  0.6892
# {'activation': 'relu', 'alpha': 0.0009149990033133677, 'batch_size': 489, 'beta_1': 0.8472944520929533, 'beta_2': 0.10256633133250748, 'early_stopping': False, 'epsilon': 5.808248309252647e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0025987758601259967, 'max_fun': 13199, 'max_iter': 170, 'momentum': 0.7190042654269785, 'n_iter_no_change': 12, 'nesterovs_momentum': True, 'power_t': 0.8566782753407018, 'random_state': 5, 'shuffle': True, 'solver': 'adam', 'tol': 0.0005388637990775653, 'validation_fraction': 0.5512822258956692, 'verbose': False, 'warm_start': False}
# | 51        | 0.7195    | 0.000915  | 489.6     | 0.8473    | 0.1026    | 5.808e-08 | 0.002599  | 1.32e+04  | 170.2     | 0.719     | 12.73     | 0.8567    | 5.674     | 0.0005389 | 0.5513    |
# ************************************
# Train AUC       :  0.9423
# Test AUC       :  0.7816
# Validation AUC :  0.7463
# ...
# ************************************
# Train AUC       :  0.9279
# Test AUC       :  0.8347
# Validation AUC :  0.7741
# {'activation': 'relu', 'alpha': 0.0003821991179243919, 'batch_size': 360, 'beta_1': 0.0562534792203192, 'beta_2': 0.8376573772342707, 'early_stopping': False, 'epsilon': 4.6285531096624993e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00784245838415251, 'max_fun': 34811, 'max_iter': 447, 'momentum': 0.5498811055763361, 'n_iter_no_change': 84, 'nesterovs_momentum': True, 'power_t': 0.9977138486691939, 'random_state': 6, 'shuffle': True, 'solver': 'adam', 'tol': 0.00048123090977810905, 'validation_fraction': 0.6431676851362529, 'verbose': False, 'warm_start': False}
# | 234       | 0.8347    | 0.0003822 | 360.3     | 0.05625   | 0.8377    | 4.629e-08 | 0.007842  | 3.481e+04 | 447.4     | 0.5499    | 84.61     | 0.9977    | 6.362     | 0.0004812 | 0.6432    |
# ************************************
# Train AUC       :  0.9531
# Test AUC       :  0.8132
# Validation AUC :  0.7561
# {'activation': 'relu', 'alpha': 0.00021164227436617028, 'batch_size': 200, 'beta_1': 0.27737281802571134, 'beta_2': 0.036211081577806614, 'early_stopping': False, 'epsilon': 8.934448843636684e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.008647134314984673, 'max_fun': 14216, 'max_iter': 577, 'momentum': 0.27484490160246067, 'n_iter_no_change': 34, 'nesterovs_momentum': True, 'power_t': 1.249182824756781, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.0004402921760685036, 'validation_fraction': 0.1051158870067247, 'verbose': False, 'warm_start': False}
# | 235       | 0.8132    | 0.0002116 | 200.1     | 0.2774    | 0.03621   | 8.934e-08 | 0.008647  | 1.422e+04 | 577.6     | 0.2748    | 34.37     | 1.249     | 4.969     | 0.0004403 | 0.1051    |
# ************************************
# Train AUC       :  0.913
# Test AUC       :  0.8495
# Validation AUC :  0.7639
# {'activation': 'relu', 'alpha': 0.0004583817924338338, 'batch_size': 671, 'beta_1': 0.25340862909306705, 'beta_2': 0.12404790903659213, 'early_stopping': False, 'epsilon': 9.586187121885842e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.003652098951078811, 'max_fun': 25212, 'max_iter': 487, 'momentum': 0.0003790131246094175, 'n_iter_no_change': 9, 'nesterovs_momentum': True, 'power_t': 0.625876458790905, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.000435492034028065, 'validation_fraction': 0.9238627304042211, 'verbose': False, 'warm_start': False}
# | 236       | 0.8495    | 0.0004584 | 671.8     | 0.2534    | 0.124     | 9.586e-08 | 0.003652  | 2.521e+04 | 488.0     | 0.000379  | 9.867     | 0.6259    | 1.1       | 0.0004355 | 0.9239    |
# ************************************
# Train AUC       :  0.8473
# Test AUC       :  0.8464
# Validation AUC :  0.7295
# {'activation': 'relu', 'alpha': 0.0009232103931825365, 'batch_size': 760, 'beta_1': 0.15216195328939386, 'beta_2': 0.8707022665967433, 'early_stopping': False, 'epsilon': 1.0468273678378598e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0012267731720223486, 'max_fun': 35289, 'max_iter': 279, 'momentum': 0.10630026757596334, 'n_iter_no_change': 89, 'nesterovs_momentum': True, 'power_t': 0.5648663150360089, 'random_state': 2, 'shuffle': True, 'solver': 'adam', 'tol': 0.0003933936433508422, 'validation_fraction': 0.33442988934687934, 'verbose': False, 'warm_start': False}
# | 237       | 0.8464    | 0.0009232 | 760.4     | 0.1522    | 0.8707    | 1.047e-08 | 0.001227  | 3.529e+04 | 279.4     | 0.1063    | 89.4      | 0.5649    | 2.464     | 0.0003934 | 0.3344    |
# ************************************
# Train AUC       :  0.8946
# Test AUC       :  0.8359
# Validation AUC :  0.7334
# {'activation': 'relu', 'alpha': 0.0006494636483373956, 'batch_size': 703, 'beta_1': 0.7710312906681456, 'beta_2': 0.487526135420015, 'early_stopping': False, 'epsilon': 2.2278320111769484e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0015759098180842335, 'max_fun': 39722, 'max_iter': 456, 'momentum': 0.35351811806570255, 'n_iter_no_change': 48, 'nesterovs_momentum': True, 'power_t': 0.6349400101954337, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.00034803578184088, 'validation_fraction': 0.2725778143921621, 'verbose': False, 'warm_start': False}
# | 238       | 0.8359    | 0.0006495 | 703.8     | 0.771     | 0.4875    | 2.228e-08 | 0.001576  | 3.972e+04 | 456.2     | 0.3535    | 48.56     | 0.6349    | 1.66      | 0.000348  | 0.2726    |
# ************************************
# Train AUC       :  0.916
# Test AUC       :  0.8378
# Validation AUC :  0.7748
# {'activation': 'relu', 'alpha': 0.0004175745745508893, 'batch_size': 295, 'beta_1': 0.5631386236928301, 'beta_2': 0.2335540165482437, 'early_stopping': False, 'epsilon': 5.6877208579899733e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.009486966559522145, 'max_fun': 13383, 'max_iter': 197, 'momentum': 0.6996664855830451, 'n_iter_no_change': 27, 'nesterovs_momentum': True, 'power_t': 1.2670991003624312, 'random_state': 2, 'shuffle': True, 'solver': 'adam', 'tol': 0.0002730184544848855, 'validation_fraction': 0.061424630192259966, 'verbose': False, 'warm_start': False}
# | 239       | 0.8378    | 0.0004176 | 295.1     | 0.5631    | 0.2336    | 5.688e-08 | 0.009487  | 1.338e+04 | 197.7     | 0.6997    | 27.84     | 1.267     | 2.028     | 0.000273  | 0.06142   |
# ************************************
# Train AUC       :  0.9533
# Test AUC       :  0.832
# Validation AUC :  0.7836
# {'activation': 'relu', 'alpha': 0.0003127464131392894, 'batch_size': 543, 'beta_1': 0.7784565849294376, 'beta_2': 0.709218631251089, 'early_stopping': False, 'epsilon': 6.395522223196903e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.008004829215849855, 'max_fun': 41242, 'max_iter': 662, 'momentum': 0.3793757495752351, 'n_iter_no_change': 92, 'nesterovs_momentum': True, 'power_t': 1.1241775274887058, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.00035947206734339405, 'validation_fraction': 0.761646558534222, 'verbose': False, 'warm_start': False}
# | 240       | 0.832     | 0.0003127 | 543.9     | 0.7785    | 0.7092    | 6.396e-08 | 0.008005  | 4.124e+04 | 662.6     | 0.3794    | 92.32     | 1.124     | 1.842     | 0.0003595 | 0.7616    |
# ************************************
# Train AUC       :  0.8065
# Test AUC       :  0.842
# Validation AUC :  0.724
# {'activation': 'relu', 'alpha': 0.00017020235658185453, 'batch_size': 671, 'beta_1': 0.5006264834884375, 'beta_2': 0.8092583560248824, 'early_stopping': False, 'epsilon': 9.767539695531e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0005588230014966036, 'max_fun': 13530, 'max_iter': 316, 'momentum': 0.05535299083438361, 'n_iter_no_change': 37, 'nesterovs_momentum': True, 'power_t': 0.6567152087778334, 'random_state': 3, 'shuffle': True, 'solver': 'adam', 'tol': 0.0006624185268113968, 'validation_fraction': 0.6706427783024302, 'verbose': False, 'warm_start': False}
# | 241       | 0.842     | 0.0001702 | 671.5     | 0.5006    | 0.8093    | 9.768e-08 | 0.0005588 | 1.353e+04 | 317.0     | 0.05535   | 37.44     | 0.6567    | 3.321     | 0.0006624 | 0.6706    |
# ************************************
# Train AUC       :  0.8719
# Test AUC       :  0.8498
# Validation AUC :  0.7635
# {'activation': 'relu', 'alpha': 0.000912019346219836, 'batch_size': 762, 'beta_1': 0.08484931690322672, 'beta_2': 0.6624484364840949, 'early_stopping': False, 'epsilon': 2.8464067728764964e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.009564259479050709, 'max_fun': 28165, 'max_iter': 206, 'momentum': 0.19111757996838374, 'n_iter_no_change': 39, 'nesterovs_momentum': True, 'power_t': 1.6959380423516603, 'random_state': 7, 'shuffle': True, 'solver': 'adam', 'tol': 0.0007338101840120103, 'validation_fraction': 0.45777449794534075, 'verbose': False, 'warm_start': False}
# | 242       | 0.8498    | 0.000912  | 762.8     | 0.08485   | 0.6624    | 2.846e-08 | 0.009564  | 2.817e+04 | 206.4     | 0.1911    | 39.46     | 1.696     | 7.535     | 0.0007338 | 0.4578    |
# ************************************
# Train AUC       :  0.8984
# Test AUC       :  0.853
# Validation AUC :  0.7665
# {'activation': 'relu', 'alpha': 0.00027569046239479323, 'batch_size': 753, 'beta_1': 0.031089070492654525, 'beta_2': 0.425038908987896, 'early_stopping': False, 'epsilon': 3.09707118507714e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00706101901443798, 'max_fun': 19036, 'max_iter': 439, 'momentum': 0.7085082726202869, 'n_iter_no_change': 86, 'nesterovs_momentum': True, 'power_t': 1.6139411445048324, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.0004492599345676083, 'validation_fraction': 0.5338850511593851, 'verbose': False, 'warm_start': False}
# | 243       | 0.853     | 0.0002757 | 753.1     | 0.03109   | 0.425     | 3.097e-08 | 0.007061  | 1.904e+04 | 439.2     | 0.7085    | 86.37     | 1.614     | 8.456     | 0.0004493 | 0.5339    |
# ************************************
# Train AUC       :  0.9044
# Test AUC       :  0.8411
# Validation AUC :  0.7662
# {'activation': 'relu', 'alpha': 0.0003234912024866308, 'batch_size': 551, 'beta_1': 0.8332555317961685, 'beta_2': 0.7310662082254652, 'early_stopping': False, 'epsilon': 1.466043737572616e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.002972057471013309, 'max_fun': 19407, 'max_iter': 656, 'momentum': 0.34471157967288213, 'n_iter_no_change': 29, 'nesterovs_momentum': True, 'power_t': 0.9821453050442959, 'random_state': 6, 'shuffle': True, 'solver': 'adam', 'tol': 0.0005796543420275193, 'validation_fraction': 0.7193207794810157, 'verbose': False, 'warm_start': False}
# | 244       | 0.8411    | 0.0003235 | 551.6     | 0.8333    | 0.7311    | 1.466e-08 | 0.002972  | 1.941e+04 | 656.7     | 0.3447    | 29.85     | 0.9821    | 6.609     | 0.0005797 | 0.7193    |
# ************************************
# Train AUC       :  0.9067
# Test AUC       :  0.8343
# Validation AUC :  0.7696
# {'activation': 'relu', 'alpha': 0.0006984075963502108, 'batch_size': 599, 'beta_1': 0.544998498537955, 'beta_2': 0.21624553564183113, 'early_stopping': False, 'epsilon': 9.338545280958654e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.005528811010156082, 'max_fun': 38089, 'max_iter': 463, 'momentum': 0.9490284367051643, 'n_iter_no_change': 58, 'nesterovs_momentum': True, 'power_t': 1.2181428135579027, 'random_state': 5, 'shuffle': True, 'solver': 'adam', 'tol': 0.00039323582179185714, 'validation_fraction': 0.4434850606872125, 'verbose': False, 'warm_start': False}
# | 245       | 0.8343    | 0.0006984 | 599.7     | 0.545     | 0.2162    | 9.339e-08 | 0.005529  | 3.809e+04 | 463.9     | 0.949     | 58.42     | 1.218     | 5.979     | 0.0003932 | 0.4435    |
# ************************************
# Train AUC       :  0.9512
# Test AUC       :  0.8285
# Validation AUC :  0.7543
# {'activation': 'relu', 'alpha': 9.434310550397821e-05, 'batch_size': 572, 'beta_1': 0.5705104734141415, 'beta_2': 0.15536419071668484, 'early_stopping': False, 'epsilon': 8.636873105674524e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.007041688834329521, 'max_fun': 27659, 'max_iter': 728, 'momentum': 0.7581023695126857, 'n_iter_no_change': 83, 'nesterovs_momentum': True, 'power_t': 1.3528594237723723, 'random_state': 8, 'shuffle': True, 'solver': 'adam', 'tol': 0.000527879366276973, 'validation_fraction': 0.3138695302224145, 'verbose': False, 'warm_start': False}
# | 246       | 0.8285    | 9.434e-05 | 572.9     | 0.5705    | 0.1554    | 8.637e-08 | 0.007042  | 2.766e+04 | 728.9     | 0.7581    | 83.12     | 1.353     | 8.992     | 0.0005279 | 0.3139    |
# ************************************
# Train AUC       :  0.931
# Test AUC       :  0.8342
# Validation AUC :  0.7677
# {'activation': 'relu', 'alpha': 0.00010725197967645809, 'batch_size': 725, 'beta_1': 0.7445740186400417, 'beta_2': 0.3433939578948737, 'early_stopping': False, 'epsilon': 1.2638072034778629e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.00925863278797917, 'max_fun': 19020, 'max_iter': 427, 'momentum': 0.5483640876395348, 'n_iter_no_change': 99, 'nesterovs_momentum': True, 'power_t': 1.8071602128618443, 'random_state': 4, 'shuffle': True, 'solver': 'adam', 'tol': 0.0003402082387618489, 'validation_fraction': 0.9201663072391497, 'verbose': False, 'warm_start': False}
# | 247       | 0.8342    | 0.0001073 | 725.0     | 0.7446    | 0.3434    | 1.264e-08 | 0.009259  | 1.902e+04 | 427.8     | 0.5484    | 99.79     | 1.807     | 4.124     | 0.0003402 | 0.9202    |
# ************************************
# Train AUC       :  0.9131
# Test AUC       :  0.8431
# Validation AUC :  0.7618
# {'activation': 'relu', 'alpha': 0.00045892920470789973, 'batch_size': 629, 'beta_1': 0.41803700219674544, 'beta_2': 0.4170344414900178, 'early_stopping': False, 'epsilon': 6.879369752129437e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.007312131445191506, 'max_fun': 49322, 'max_iter': 358, 'momentum': 0.675943735173972, 'n_iter_no_change': 80, 'nesterovs_momentum': True, 'power_t': 1.7356341254976961, 'random_state': 3, 'shuffle': True, 'solver': 'adam', 'tol': 0.0006361500141138292, 'validation_fraction': 0.8874161918149902, 'verbose': False, 'warm_start': False}
# | 248       | 0.8431    | 0.0004589 | 630.0     | 0.418     | 0.417     | 6.879e-08 | 0.007312  | 4.932e+04 | 358.3     | 0.6759    | 80.32     | 1.736     | 3.963     | 0.0006362 | 0.8874    |
# ************************************
# Train AUC       :  0.8048
# Test AUC       :  0.8415
# Validation AUC :  0.7321
# {'activation': 'relu', 'alpha': 0.0006243955302074332, 'batch_size': 596, 'beta_1': 0.93141042942165, 'beta_2': 0.6867887242481612, 'early_stopping': False, 'epsilon': 3.199523611031746e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.0010221772334593137, 'max_fun': 16053, 'max_iter': 309, 'momentum': 0.08346694042017144, 'n_iter_no_change': 16, 'nesterovs_momentum': True, 'power_t': 0.8556343736003645, 'random_state': 1, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001125145552959159, 'validation_fraction': 0.040178170568679894, 'verbose': False, 'warm_start': False}
# | 249       | 0.8415    | 0.0006244 | 596.2     | 0.9314    | 0.6868    | 3.2e-08   | 0.001022  | 1.605e+04 | 310.0     | 0.08347   | 16.06     | 0.8556    | 1.426     | 0.0001125 | 0.04018   |
# ************************************
# Train AUC       :  0.8634
# Test AUC       :  0.851
# Validation AUC :  0.774
# {'activation': 'relu', 'alpha': 0.0007496019074216221, 'batch_size': 519, 'beta_1': 0.8982182873948064, 'beta_2': 0.015321423244189836, 'early_stopping': False, 'epsilon': 1.700488904618451e-08, 'hidden_layer_sizes': (100,), 'learning_rate': 'constant', 'learning_rate_init': 0.007146318201971697, 'max_fun': 29839, 'max_iter': 533, 'momentum': 0.012451173189971465, 'n_iter_no_change': 65, 'nesterovs_momentum': True, 'power_t': 1.056919283953227, 'random_state': 3, 'shuffle': True, 'solver': 'adam', 'tol': 0.00036564546077574406, 'validation_fraction': 0.24242703358355777, 'verbose': False, 'warm_start': False}
# | 250       | 0.851     | 0.0007496 | 519.2     | 0.8982    | 0.01532   | 1.7e-08   | 0.007146  | 2.984e+04 | 533.2     | 0.01245   | 65.97     | 1.057     | 3.433     | 0.0003656 | 0.2424    |
# =================================================================================================================================================================================================

# %%
def bootstrap(true, pred, B, c, func, **args):
    """
    计算 bootstrap 置信区间
    :param data: array 保存样本数据
    :param B: 抽样次数 通常 B>=1000
    :param c: 置信水平
    :param func: 样本估计量
    :return: bootstrap置信区间上下限
    """
    array = np.array(true)
    n = len(array)
    sample_result_arr = []
    for i in range(B):
        index_arr = np.random.randint(0, n, size=n)
        data_sample_real = true[index_arr]
        data_sample_pred = pred[index_arr]
        sample_result = func(data_sample_real, data_sample_pred, **args)
        sample_result_arr.append(sample_result)
    a = 1 - c
    k1 = int(B * a / 2)
    k2 = int(B * (1 - a / 2))
    auc_sample_arr_sorted = sorted(sample_result_arr)
    lower = auc_sample_arr_sorted[k1]
    higher = auc_sample_arr_sorted[k2]
    return (lower, higher)

#print("f1 score(95%CI):{}{}".format(f1_score(y_test, l_lg_test, average='weighted'),np.round(bootstrap(y_test, l_lg_test, 1000, 0.95, f1_score, average='weighted'), decimals=4)))
#print("AUC CI(95%CI):{}{}".format(roc_auc_score(y_test, p_lg_test, multi_class='ovr'), bootstrap(y_test, p_lg_test, 1000, 0.95, roc_auc_score, multi_class='ovr')))

# %%
test_folds = []
test_gt_folds = []
val_folds = []
true_folds = []
pred_folds = []
cm_folds = []
f1_test_folds = []
auc_test_folds = []
new_folds = []
f1_test_CI_folds = []
auc_test_CI_folds = []

for i, values in enumerate(folds_indices.values()):
    train_index, test_index = values['train_index'], values['test_index']
    X_train, y_train = X.iloc[train_index], y.iloc[train_index]
    X_test, y_test = X.iloc[test_index], y.iloc[test_index]

    X_train = np.array(X_train)
    X_test = np.array(X_test)

    y_train = np.array(y_train).astype(int)
    y_test = np.array(y_test).astype(int)

    X_train, y_train = X.iloc[train_index], y.iloc[train_index]
    X_test, y_test = X.iloc[test_index], y.iloc[test_index]

    X_train = np.array(X_train)
    X_test = np.array(X_test)

    y_train = np.array(y_train).astype(int)
    y_test = np.array(y_test).astype(int)

    nm = SMOTE(random_state=42)
    X_res, y_res = nm.fit_resample(X_train, y_train)

    params_cur = params_best[i]
    model = MLPClassifier()
    model.set_params(**params_cur)
    clf_lg = model.fit(X_res, y_res)
    p_lg_train = clf_lg.predict_proba(X_res)  # [:,1]
    p_lg_test = clf_lg.predict_proba(X_test)  # [:,1]
    p_lg_val = clf_lg.predict_proba(X_val)  # [:,1]
    p_lg_new = clf_lg.predict_proba(X_new)  # [:,1]

    val_folds.append(p_lg_val)
    test_folds.append(p_lg_test)
    test_gt_folds.append(y_test)
    new_folds.append(p_lg_new)

    l_lg_train = clf_lg.predict(X_res)
    l_lg_test = clf_lg.predict(X_test)
    l_lg_val = clf_lg.predict(X_val)
    l_lg_new = clf_lg.predict(X_new)

    f1_train = f1_score(y_res, l_lg_train, average='weighted')
    f1_test = f1_score(y_test, l_lg_test, average='weighted')
    f1_val = f1_score(y_val, l_lg_val, average='weighted')
    f1_new = f1_score(y_new, l_lg_new, average='weighted')
    f1_test_folds.append(f1_test)
    f1_test_CI_folds.append(bootstrap(y_test, l_lg_test, 3000, 0.95,f1_score, average='weighted'))

    true_folds.append(y_test)
    pred_folds.append(l_lg_test)

    lg_auc_train = roc_auc_score(y_res, p_lg_train, multi_class='ovr')
    lg_auc_test = roc_auc_score(y_test, p_lg_test, multi_class='ovr')
    lg_auc_val = roc_auc_score(y_val, p_lg_val, multi_class='ovr')
    lg_auc_new = roc_auc_score(y_new, p_lg_new, multi_class='ovr')
    auc_test_folds.append(lg_auc_test)
    auc_test_CI_folds.append(bootstrap(y_test, p_lg_test, 3000, 0.95,roc_auc_score, multi_class='ovr'))

    cm_test = confusion_matrix(y_test, l_lg_test)
    cm_folds.append(cm_test)

# %%
all_val_folds = np.stack(val_folds)
all_new_folds = np.stack(new_folds)

mean_folds = np.mean(all_val_folds, axis=0)
mean_new_folds = np.mean(all_new_folds, axis=0)

experiment_name = 'Age_Radio'

# %%
from datetime import datetime

# 获取当前时间
now = datetime.now()

# 格式化时间为 MMDDHHMM 格式
timestamp = now.strftime("%m%d%H%M")
csv_result = '/Users/huyanshen/Desktop/AI-Medicine/Research/PengCheng/Shap_Value_yanshen/ModelComparison/NN_result/results.csv'
original_stdout = sys.stdout

with open(csv_result.replace('results.csv', experiment_name + '_' + timestamp + '.txt'), 'w') as f:
    sys.stdout = f
    print('-------------Features---------------')
    print(sel_columns)

    print('-------------Testing----------------')
    all_test_folds = np.vstack(test_folds)
    gt_test = np.concatenate(test_gt_folds)
    print('All_test_folds: ', all_test_folds.shape)

    all_l_test_folds = np.concatenate(pred_folds)
    lg_accuracy_test = accuracy_score(gt_test, all_l_test_folds)
    lg_accuracy_CI_test = bootstrap(gt_test, all_l_test_folds, 3000, 0.95, accuracy_score)
    print(f'Test Accuracy: {np.round(lg_accuracy_test, decimals=4)} {tuple(np.round(lg_accuracy_CI_test, decimals=4))}')

    lg_auc_test = roc_auc_score(gt_test, all_test_folds, multi_class='ovr')
    lg_auc_CI_test = bootstrap(gt_test, all_test_folds, 3000, 0.95, roc_auc_score, multi_class='ovr')
    print('Test AUC : {} {}'.format(np.round(lg_auc_test, decimals=4), tuple(np.round(lg_auc_CI_test, decimals=4))))
    AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(auc_test_folds, decimals=4), np.round(auc_test_CI_folds, decimals=4))]
    print('Test AUC: ', AUC_format, '(per fold)')

    # Binarize the true labels to use with roc_auc_score
    y_test_binarized = label_binarize(gt_test, classes=[0, 1, 2])
    aucs_test = []
    aucs_CI_test = []
    for i in range(3):
        auc_test = roc_auc_score(y_test_binarized[:, i], np.array(all_test_folds)[:, i])
        auc_CI_test = bootstrap(y_test_binarized[:, i], np.array(all_test_folds)[:, i], 3000, 0.95, roc_auc_score, multi_class='ovr')
        aucs_test.append(auc_test)
        aucs_CI_test.append(auc_CI_test)
    AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(aucs_test, decimals=4), np.round(aucs_CI_test, decimals=4))]
    print('Test AUC : ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')

    f1_test = f1_score(gt_test, np.argmax(all_test_folds, axis=1), average='weighted')
    f1_CI_test = bootstrap(gt_test, np.argmax(all_test_folds, axis=1), 3000, 0.95, f1_score, average='weighted')
    print('Test F1 score: {} {}'.format(np.round(f1_test, decimals=4), tuple(np.round(f1_CI_test, decimals=4))))
    AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(f1_test_folds, decimals=4), np.round(f1_test_CI_folds, decimals=4))]
    print('Test F1 score: ', AUC_format, '(per fold)')
    test_f1_per_subtype = [np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=0), decimals=4),
                            np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=1), decimals=4),
                            np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=2), decimals=4)]
    test_f1_CI_per_subtype = [np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=0), decimals=4),
                            np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=1), decimals=4),
                            np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=2), decimals=4)]
    AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(test_f1_per_subtype, decimals=4), np.round(test_f1_CI_per_subtype, decimals=4))]
    print('Test F1 score: ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')

    cm_test = confusion_matrix(gt_test, np.argmax(all_test_folds, axis=1))
    print('Test Confusion Matrix: ')
    print(cm_test)
    #disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_val)
    #disp1.plot()

    print('-----------Validation--------------')
    all_val_folds = np.stack(val_folds)
    mean_folds = np.mean(all_val_folds, axis=0)
    print('All_val_folds: ', all_val_folds.shape)
    print('All_mean_val_folds:', mean_folds.shape)

    lg_auc_val = roc_auc_score(y_val, mean_folds, multi_class='ovr')
    print('Validation AUC : ', np.round(lg_auc_val, decimals=4))

    # Binarize the true labels to use with roc_auc_score
    y_val_binarized = label_binarize(y_val, classes=[0, 1, 2])
    aucs_val = []
    for i in range(3):
        auc_val = roc_auc_score(y_val_binarized[:, i], np.array(mean_folds)[:, i])
        aucs_val.append(auc_val)
    print('Validation AUC : ', np.round(aucs_val, decimals=4), '(per subtype, [WNT, G3/G4, SHH])')

    f1_mean_val = f1_score(y_val, np.argmax(mean_folds, axis=1), average='weighted')
    print('Validation f1 score: ', np.round(f1_mean_val, decimals=4))
    val_f1_per_subtype = [np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=0), decimals=4),
                            np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=1), decimals=4),
                            np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=2), decimals=4)]
    print('Validation f1 score: ', val_f1_per_subtype, '(per subtype, [WNT, G3/G4, SHH])')

    cm_val = confusion_matrix(y_val, np.argmax(mean_folds, axis=1))
    print('Validation Confusion Matrix: ')
    print(cm_val)
    #disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_val)
    #disp1.plot()
        
    print('-----------Golden--------------')
    all_new_folds = np.stack(new_folds)
    mean_new_folds = np.mean(all_new_folds, axis=0)
    print('All_new_folds: ', all_new_folds.shape)
    print('All_mean_new_folds:', mean_new_folds.shape)

    lg_auc_new = roc_auc_score(y_new, mean_new_folds, multi_class='ovr')
    print('Golden AUC : ', np.round(lg_auc_new, decimals=4))
    # Binarize the true labels to use with roc_auc_score
    y_new_binarized = label_binarize(y_new, classes=[0, 1, 2])
    aucs_new = []
    for i in range(3):
        auc_new = roc_auc_score(y_new_binarized[:, i], np.array(mean_new_folds)[:, i])
        aucs_new.append(auc_new)
    print('Golden AUC : ', np.round(aucs_new, decimals=4), '(per subtype, [WNT, G3/G4, SHH])')

    f1_mean_new = f1_score(y_new, np.argmax(mean_new_folds, axis=1), average='weighted')
    print('Golden f1 score: ', np.round(f1_mean_new, decimals=4))
    new_f1_per_subtype = [np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=0), decimals=4),
                            np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=1), decimals=4),
                            np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=2), decimals=4)]
    print('Golden f1 score: ', new_f1_per_subtype, '(per subtype, [WNT, G3/G4, SHH])')

    cm_new = confusion_matrix(y_new, np.argmax(mean_new_folds, axis=1))
    print('Golden Confusion Matrix: ')
    print(cm_new)

    print('-------------Params-----------------')
    for i in range(3):
        print(params_best[i])
        
    experiment_data = {
            'Experiment': experiment_name,
            'Test AUC Overall': np.round(lg_auc_test, decimals=4),
            'Test AUC Per Fold': np.round(auc_test_folds, decimals=4).tolist(),
            'Test AUC Per Subtype': np.round(aucs_test, decimals=4),
            'Test F1 Overall': np.round(f1_test, decimals=4),
            'Test F1 Per Fold': np.round(f1_test_folds, decimals=4).tolist(),
            'Test F1 Per Subtype': test_f1_per_subtype,
            'Validation AUC Overall': np.round(lg_auc_val, decimals=4),
            'Validation AUC Per Subtype': np.round(aucs_val, decimals=4).tolist(),
            'Validation F1 Overall': np.round(f1_mean_val, decimals=4),
            'Validation F1 Per Subtype': val_f1_per_subtype,
            'Golden AUC Overall': np.round(lg_auc_new, decimals=4),
            'Golden AUC Per Subtype': np.round(aucs_new, decimals=4).tolist(),
            'Golden F1 Overall': np.round(f1_mean_new, decimals=4),
            'Golden F1 Per Subtype': new_f1_per_subtype,
            'details file': experiment_name + '_' + timestamp + '.txt'
    }

    # 写入数据
    write_experiment_results_to_csv(csv_result, experiment_data)
    sys.stdout = original_stdout
# Out:
# invalid value encountered in scalar divide

# %%
from datetime import datetime

# 获取当前时间
now = datetime.now()

# 格式化时间为 MMDDHHMM 格式
timestamp = now.strftime("%m%d%H%M")
csv_result = '/Users/huyanshen/Desktop/AI-Medicine/Research/PengCheng/Shap_Value_yanshen/ModelComparison/SVM_result/results.csv'


print('-------------Features---------------')
print(sel_columns)

print('-------------Testing----------------')
all_test_folds = np.vstack(test_folds)
gt_test = np.concatenate(test_gt_folds)
print('All_test_folds: ', all_test_folds.shape)

all_l_test_folds = np.concatenate(pred_folds)
lg_accuracy_test = accuracy_score(gt_test, all_l_test_folds)
lg_accuracy_CI_test = bootstrap(gt_test, all_l_test_folds, 3000, 0.95, accuracy_score)
print(f'Test Accuracy: {np.round(lg_accuracy_test, decimals=4)} {tuple(np.round(lg_accuracy_CI_test, decimals=4))}')

lg_auc_test = roc_auc_score(gt_test, all_test_folds, multi_class='ovr')
lg_auc_CI_test = bootstrap(gt_test, all_test_folds, 3000, 0.95, roc_auc_score, multi_class='ovr')
print('Test AUC : {} {}'.format(np.round(lg_auc_test, decimals=4), tuple(np.round(lg_auc_CI_test, decimals=4))))
AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(auc_test_folds, decimals=4), np.round(auc_test_CI_folds, decimals=4))]
print('Test AUC: ', AUC_format, '(per fold)')

# Binarize the true labels to use with roc_auc_score
y_test_binarized = label_binarize(gt_test, classes=[0, 1, 2])
aucs_test = []
aucs_CI_test = []
for i in range(3):
    auc_test = roc_auc_score(y_test_binarized[:, i], np.array(all_test_folds)[:, i])
    auc_CI_test = bootstrap(y_test_binarized[:, i], np.array(all_test_folds)[:, i], 3000, 0.95, roc_auc_score, multi_class='ovr')
    aucs_test.append(auc_test)
    aucs_CI_test.append(auc_CI_test)
AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(aucs_test, decimals=4), np.round(aucs_CI_test, decimals=4))]
print('Test AUC : ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')

f1_test = f1_score(gt_test, np.argmax(all_test_folds, axis=1), average='weighted')
f1_CI_test = bootstrap(gt_test, np.argmax(all_test_folds, axis=1), 3000, 0.95, f1_score, average='weighted')
print('Test F1 score: {} {}'.format(np.round(f1_test, decimals=4), tuple(np.round(f1_CI_test, decimals=4))))
AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(f1_test_folds, decimals=4), np.round(f1_test_CI_folds, decimals=4))]
print('Test F1 score: ', AUC_format, '(per fold)')
test_f1_per_subtype = [np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=0), decimals=4),
                        np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=1), decimals=4),
                        np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=2), decimals=4)]
test_f1_CI_per_subtype = [np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=0), decimals=4),
                        np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=1), decimals=4),
                        np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_scores, pos_index=2), decimals=4)]
AUC_format = [str(i) + ' ' + str(tuple(j)) for i, j in zip(np.round(test_f1_per_subtype, decimals=4), np.round(test_f1_CI_per_subtype, decimals=4))]
print('Test F1 score: ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')

cm_test = confusion_matrix(gt_test, np.argmax(all_test_folds, axis=1))
print('Test Confusion Matrix: ')
print(cm_test)
#disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_val)
#disp1.plot()

print('-----------Validation--------------')
all_val_folds = np.stack(val_folds)
mean_folds = np.mean(all_val_folds, axis=0)
print('All_val_folds: ', all_val_folds.shape)
print('All_mean_val_folds:', mean_folds.shape)

lg_auc_val = roc_auc_score(y_val, mean_folds, multi_class='ovr')
print('Validation AUC : ', np.round(lg_auc_val, decimals=4))

# Binarize the true labels to use with roc_auc_score
y_val_binarized = label_binarize(y_val, classes=[0, 1, 2])
aucs_val = []
for i in range(3):
    auc_val = roc_auc_score(y_val_binarized[:, i], np.array(mean_folds)[:, i])
    aucs_val.append(auc_val)
print('Validation AUC : ', np.round(aucs_val, decimals=4), '(per subtype, [WNT, G3/G4, SHH])')

f1_mean_val = f1_score(y_val, np.argmax(mean_folds, axis=1), average='weighted')
print('Validation f1 score: ', np.round(f1_mean_val, decimals=4))
val_f1_per_subtype = [np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=0), decimals=4),
                        np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=1), decimals=4),
                        np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=2), decimals=4)]
print('Validation f1 score: ', val_f1_per_subtype, '(per subtype, [WNT, G3/G4, SHH])')

cm_val = confusion_matrix(y_val, np.argmax(mean_folds, axis=1))
print('Validation Confusion Matrix: ')
print(cm_val)
#disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_val)
#disp1.plot()
    
print('-----------Golden--------------')
all_new_folds = np.stack(new_folds)
mean_new_folds = np.mean(all_new_folds, axis=0)
print('All_new_folds: ', all_new_folds.shape)
print('All_mean_new_folds:', mean_new_folds.shape)

lg_auc_new = roc_auc_score(y_new, mean_new_folds, multi_class='ovr')
print('Golden AUC : ', np.round(lg_auc_new, decimals=4))
# Binarize the true labels to use with roc_auc_score
y_new_binarized = label_binarize(y_new, classes=[0, 1, 2])
aucs_new = []
for i in range(3):
    auc_new = roc_auc_score(y_new_binarized[:, i], np.array(mean_new_folds)[:, i])
    aucs_new.append(auc_new)
print('Golden AUC : ', np.round(aucs_new, decimals=4), '(per subtype, [WNT, G3/G4, SHH])')

f1_mean_new = f1_score(y_new, np.argmax(mean_new_folds, axis=1), average='weighted')
print('Golden f1 score: ', np.round(f1_mean_new, decimals=4))
new_f1_per_subtype = [np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=0), decimals=4),
                        np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=1), decimals=4),
                        np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=2), decimals=4)]
print('Golden f1 score: ', new_f1_per_subtype, '(per subtype, [WNT, G3/G4, SHH])')

cm_new = confusion_matrix(y_new, np.argmax(mean_new_folds, axis=1))
print('Golden Confusion Matrix: ')
print(cm_new)

print('-------------Params-----------------')
for i in range(3):
    print(params_best[i])
    
experiment_data = {
        'Experiment': experiment_name,
        'Test AUC Overall': np.round(lg_auc_test, decimals=4),
        'Test AUC Per Fold': np.round(auc_test_folds, decimals=4).tolist(),
        'Test AUC Per Subtype': np.round(aucs_test, decimals=4),
        'Test F1 Overall': np.round(f1_test, decimals=4),
        'Test F1 Per Fold': np.round(f1_test_folds, decimals=4).tolist(),
        'Test F1 Per Subtype': test_f1_per_subtype,
        'Validation AUC Overall': np.round(lg_auc_val, decimals=4),
        'Validation AUC Per Subtype': np.round(aucs_val, decimals=4).tolist(),
        'Validation F1 Overall': np.round(f1_mean_val, decimals=4),
        'Validation F1 Per Subtype': val_f1_per_subtype,
        'Golden AUC Overall': np.round(lg_auc_new, decimals=4),
        'Golden AUC Per Subtype': np.round(aucs_new, decimals=4).tolist(),
        'Golden F1 Overall': np.round(f1_mean_new, decimals=4),
        'Golden F1 Per Subtype': new_f1_per_subtype,
        'details file': experiment_name + '_' + timestamp + '.txt'
}

# 写入数据
write_experiment_results_to_csv(csv_result, experiment_data)
# Out:
# -------------Features---------------
# ['Cohort', 'Subtypes_three', 'fold', 'Age', 'T1E_log-sigma-3-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis_x', 'T1E_log-sigma-3-mm-3D_glcm_Autocorrelation_x', 'T1E_log-sigma-1-mm-3D_glcm_ClusterShade_x', 'T1E_wavelet-LHL_firstorder_Mean_x', 'T2_wavelet-LLH_glcm_ClusterShade_y', 'T1E_log-sigma-5-mm-3D_glrlm_LowGrayLevelRunEmphasis_x', 'T1E_wavelet-HLL_firstorder_Median_x', 'T1E_wavelet-LHL_firstorder_Median_x', 'T2_wavelet-HHL_firstorder_Skewness_x', 'T1E_log-sigma-3-mm-3D_glrlm_LongRunLowGrayLevelEmphasis_x', 'T1E_lbp-2D_glrlm_RunLengthNonUniformity_x', 'T2_log-sigma-1-mm-3D_gldm_LowGrayLevelEmphasis_x', 'T1E_log-sigma-5-mm-3D_firstorder_90Percentile_x', 'T1E_log-sigma-3-mm-3D_glszm_LowGrayLevelZoneEmphasis_x', 'T2_wavelet-HHL_glcm_SumSquares_x', 'T2_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized_x', 'T2_wavelet-LLH_gldm_DependenceNonUniformity_x', 'T2_original_shape_Maximum3DDiameter_y', 'T2_original_glszm_LargeAreaEmphasis_y']
# -------------Testing----------------
# All_test_folds:  (514, 3)
# Test Accuracy: 0.6926 (0.6537, 0.7315)
# Test AUC : 0.8112 (0.7741, 0.8451)
# Test AUC:  ['0.7998 (0.7335, 0.8601)', '0.8064 (0.7495, 0.8587)', '0.8559 (0.8041, 0.9025)'] (per fold)
# Test AUC :  ['0.8546 (0.793, 0.9099)', '0.7835 (0.7419, 0.822)', '0.7955 (0.7495, 0.838)'] (per subtype, [WNT, G3/G4, SHH])
# Test F1 score: 0.6941 (0.6548, 0.734)
# Test F1 score:  ['0.6982 (0.6332, 0.7675)', '0.6464 (0.5734, 0.7194)', '0.7368 (0.6667, 0.8016)'] (per fold)
# Test F1 score:  ['0.5882 (0.4828, 0.6838)', '0.7638 (0.7244, 0.7994)', '0.5966 (0.5286, 0.6599)'] (per subtype, [WNT, G3/G4, SHH])
# Test Confusion Matrix:
# [[ 40  16  11]
#  [ 23 228  52]
#  [  6  50  88]]
# -----------Validation--------------
# All_val_folds:  (3, 135, 3)
# All_mean_val_folds: (135, 3)
# Validation AUC :  0.7946
# Validation AUC :  [0.844  0.7732 0.7667] (per subtype, [WNT, G3/G4, SHH])
# Validation f1 score:  0.7033
# Validation f1 score:  [0.625, 0.7702, 0.5974] (per subtype, [WNT, G3/G4, SHH])
# Validation Confusion Matrix:
# [[10  5  2]
#  [ 4 62 14]
#  [ 1 14 23]]
# -----------Golden--------------
# All_new_folds:  (3, 44, 3)
# All_mean_new_folds: (44, 3)
# Golden AUC :  0.8062
# Golden AUC :  [0.7375 0.8375 0.8438] (per subtype, [WNT, G3/G4, SHH])
# Golden f1 score:  0.6734
# Golden f1 score:  [nan, 0.8525, 0.375] (per subtype, [WNT, G3/G4, SHH])
# Golden Confusion Matrix:
# [[ 0  2  5]
#  [ 3 26  4]
#  [ 1  0  3]]
# -------------Params-----------------
# {'alpha': 0.0005656938640490419, 'batch_size': 343, 'learning_rate_init': 0.0032034174061037046, 'power_t': 1.642605596631681, 'max_iter': 789, 'random_state': 4, 'tol': 0.00010244376257628324, 'momentum': 0.13775034461799884, 'validation_fraction': 0.9682502535343684, 'beta_1': 0.4446492621456912, 'beta_2': 0.46646448266480445, 'epsilon': 6.009229424373674e-08, 'n_iter_no_change': 77, 'max_fun': 44032}
# {'alpha': 0.0007411528600599452, 'batch_size': 117, 'learning_rate_init': 0.008558886603184736, 'power_t': 1.0213832851087523, 'max_iter': 171, 'random_state': 6, 'tol': 0.0009398506792928305, 'momentum': 0.6006517316825081, 'validation_fraction': 0.5267471482371865, 'beta_1': 0.6170980090372886, 'beta_2': 0.6046913334770397, 'epsilon': 2.2060407646961715e-08, 'n_iter_no_change': 7, 'max_fun': 19766}
# {'alpha': 0.00040567808637365516, 'batch_size': 709, 'learning_rate_init': 0.008257649950963602, 'power_t': 1.0678739136124835, 'max_iter': 480, 'random_state': 7, 'tol': 0.0008782841074207234, 'momentum': 0.7405206490569102, 'validation_fraction': 0.6803941134640467, 'beta_1': 0.03806126312245661, 'beta_2': 0.16810240982321356, 'epsilon': 6.924396286910769e-08, 'n_iter_no_change': 96, 'max_fun': 39728}
# invalid value encountered in scalar divide
