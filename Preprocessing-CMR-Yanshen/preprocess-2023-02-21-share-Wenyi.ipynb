# %%
import os
import shutil
import pandas as pd
import nibabel as nib
import SimpleITK as sitk
import pydicom
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tqdm import tqdm
import pickle as pkl
def dcm2nii(path_read, path_save):
    '''
    ## Convert Dicom Series Files to a Single NII File
    ### Args:
        path_read: The file folder containing dicom series files(No other files exits)
        path_save: The path you save the .nii/.nii.gz data file
    '''
    # GetGDCMSeriesIDs读取序列号相同的dcm文件
    series_id = sitk.ImageSeriesReader.GetGDCMSeriesIDs(path_read)
    # GetGDCMSeriesFileNames读取序列号相同dcm文件的路径，series[0]代表第一个序列号对应的文件
    series_file_names = sitk.ImageSeriesReader.GetGDCMSeriesFileNames(path_read, series_id[0])
    series_reader = sitk.ImageSeriesReader()
    series_reader.SetFileNames(series_file_names)
    image3d = series_reader.Execute()
    sitk.WriteImage(image3d, path_save)

def rename_dicom(dataroot='./DICOMs'):
    for root,dirs,files in os.walk(dataroot):
        # if len(dirs)==0:
        if True:
            for i in range(len(files)):
                if files[i]=='DICOMDIR.dcm':
                    os.remove(os.path.join(root,files[i]))
                    print(f'{os.path.join(root,files[i])} deleted')
                if not files[i].endswith('.dcm'):
                    os.rename(os.path.join(root,files[i]),os.path.join(root,f'{files[i]}.dcm'))
# Out:
# 0

# %%
def resample_volume(Origin='NII.nii.gz', volume=None, interpolator = sitk.sitkLinear, new_spacing = [1.7708333730698,1.7708333730698,1],output='Resampled.nii'):
    '''
    ## Resample MRI files to specified spacing, here we define spacing=[1.7708333730698,1.7708333730698,1]
    ### Args:
        Origin: The Original MRI file, MUST NOT BE DICOM!!!!!
        interpolater: The method of resampling
        new_spacing: The spacing we want to set
        output: The Output path of resampled MRI data
    ### Return:
        resample_image: The resampled MRI data
    '''
    if volume is None:
        volume = sitk.ReadImage(Origin)
    original_spacing = volume.GetSpacing()
    original_size = volume.GetSize()
    new_size = [int(round(osz*ospc/nspc)) for osz,ospc,nspc in zip(original_size, original_spacing, new_spacing)]
    resampled_image = sitk.Resample(volume,
                                    new_size,
                                    sitk.Transform(), 
                                    interpolator,
                                    volume.GetOrigin(), 
                                    new_spacing, volume.GetDirection(), 
                                    0,
                                    volume.GetPixelID())
    if output!='':
        sitk.WriteImage(resampled_image,output)
    return resampled_image

# %% [markdown]
# ## Map resolution from nifti to nifti

# %%
def resample_dataset2(spacing=[0.994,1.826],datapath='E:/VST_fusion/dataset'):
    error=[]
    for space in spacing:
        for roots,dirs,files in os.walk(datapath):
            if len(dirs)==0:
                files=exclude_seg_files(os.listdir(roots))
                for i in range(len(files)):
                    data_path=os.path.join(roots,files[i])
                    pre_data=sitk.ReadImage(data_path)
                    data_spacing=list(pre_data.GetSpacing())
                    data_spacing[0]=space
                    data_spacing[1]=space
                    new_data=resample_volume(Origin=data_path,new_spacing=data_spacing,output='')
                    if len(sitk.GetArrayFromImage(new_data))!=25 and 'LGE' not in data_path:
                        print(f'frame resample error: {data_path} {sitk.GetArrayFromImage(new_data).shape}')
                        error.append(data_path)
                    else:
                        save_path=roots.replace('nifti',f'nifti_spacing_{space}')
                        save_path=save_path.replace('dataset',f'dataset_spacing_{space}')
                        # save_path=save_path.replace('E:','F:')
                        if not os.path.exists(save_path):
                            os.makedirs(save_path)
                        save_path=os.path.join(save_path,files[i])
                        sitk.WriteImage(new_data,save_path)
                        print(f'{save_path} saved')
    return error
error=resample_dataset2(datapath='/Users/airskcer/Downloads/NP_nifti-20230109/',spacing=[0.994,1.826])
# error=resample_dataset2(datapath='/Users/airskcer/Downloads/RCM_nifti-20230107/',spacing=[0.994,1.826])
# Out:
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11183087_LI_CHANG_AN/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11183087_LI_CHANG_AN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11183087_LI_CHANG_AN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11183087_LI_CHANG_AN/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11183087_LI_CHANG_AN/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11183087_LI_CHANG_AN/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11183087_LI_CHANG_AN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11183087_LI_CHANG_AN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11028695_DAI_XIN_HUA/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11028695_DAI_XIN_HUA/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11028695_DAI_XIN_HUA/slice_29.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11028695_DAI_XIN_HUA/slice_21.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11028695_DAI_XIN_HUA/slice_24.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11028695_DAI_XIN_HUA/slice_28.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11028695_DAI_XIN_HUA/slice_26.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11028695_DAI_XIN_HUA/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11028695_DAI_XIN_HUA/slice_22.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11100109_LIN_JUN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11100109_LIN_JUN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11100109_LIN_JUN/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11100109_LIN_JUN/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11100109_LIN_JUN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11100109_LIN_JUN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11100109_LIN_JUN/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11100109_LIN_JUN/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11192562_LI_JIN_TIAN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11192562_LI_JIN_TIAN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11192562_LI_JIN_TIAN/slice_21.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11192562_LI_JIN_TIAN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11192562_LI_JIN_TIAN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11192562_LI_JIN_TIAN/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11192562_LI_JIN_TIAN/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11192562_LI_JIN_TIAN/slice_20.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11016675_LI_TIAN_LONG/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11016675_LI_TIAN_LONG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11016675_LI_TIAN_LONG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11016675_LI_TIAN_LONG/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11016675_LI_TIAN_LONG/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11016675_LI_TIAN_LONG/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11016675_LI_TIAN_LONG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11016675_LI_TIAN_LONG/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073922_ZHANG_TIAN_FANG/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073922_ZHANG_TIAN_FANG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073922_ZHANG_TIAN_FANG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073922_ZHANG_TIAN_FANG/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073922_ZHANG_TIAN_FANG/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073922_ZHANG_TIAN_FANG/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073922_ZHANG_TIAN_FANG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073922_ZHANG_TIAN_FANG/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11222486_LIU_SI_HUA/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11222486_LIU_SI_HUA/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11222486_LIU_SI_HUA/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11222486_LIU_SI_HUA/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11222486_LIU_SI_HUA/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11222486_LIU_SI_HUA/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11222486_LIU_SI_HUA/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11222486_LIU_SI_HUA/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11017222_WANG_BEN/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11017222_WANG_BEN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11017222_WANG_BEN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11017222_WANG_BEN/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11017222_WANG_BEN/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11017222_WANG_BEN/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11017222_WANG_BEN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11017222_WANG_BEN/slice_20.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11113105_WANG_ZHENG_ZHONG/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11113105_WANG_ZHENG_ZHONG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11113105_WANG_ZHENG_ZHONG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11113105_WANG_ZHENG_ZHONG/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11113105_WANG_ZHENG_ZHONG/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11113105_WANG_ZHENG_ZHONG/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11113105_WANG_ZHENG_ZHONG/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11113105_WANG_ZHENG_ZHONG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11022043_HUANG_ZONG_LUN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11022043_HUANG_ZONG_LUN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11022043_HUANG_ZONG_LUN/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11022043_HUANG_ZONG_LUN/slice_21.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11022043_HUANG_ZONG_LUN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11022043_HUANG_ZONG_LUN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11022043_HUANG_ZONG_LUN/slice_22.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11022043_HUANG_ZONG_LUN/slice_20.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11166624_WANG_GUI_MEI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11166624_WANG_GUI_MEI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11166624_WANG_GUI_MEI/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11166624_WANG_GUI_MEI/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11166624_WANG_GUI_MEI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11166624_WANG_GUI_MEI/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11166624_WANG_GUI_MEI/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11166624_WANG_GUI_MEI/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11174270_LIU_TONG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11174270_LIU_TONG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11174270_LIU_TONG/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11174270_LIU_TONG/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11174270_LIU_TONG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11174270_LIU_TONG/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11174270_LIU_TONG/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11174270_LIU_TONG/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11072007_WANG_QIAO_ZE/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11072007_WANG_QIAO_ZE/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11072007_WANG_QIAO_ZE/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11072007_WANG_QIAO_ZE/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11072007_WANG_QIAO_ZE/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11072007_WANG_QIAO_ZE/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11072007_WANG_QIAO_ZE/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11072007_WANG_QIAO_ZE/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11243041_HU_GAO_RUI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11243041_HU_GAO_RUI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11243041_HU_GAO_RUI/slice_37.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11243041_HU_GAO_RUI/slice_39.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11243041_HU_GAO_RUI/slice_44.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11243041_HU_GAO_RUI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11243041_HU_GAO_RUI/slice_41.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11243041_HU_GAO_RUI/slice_43.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118464_SUN_CHANG_LAI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118464_SUN_CHANG_LAI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118464_SUN_CHANG_LAI/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118464_SUN_CHANG_LAI/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118464_SUN_CHANG_LAI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118464_SUN_CHANG_LAI/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118464_SUN_CHANG_LAI/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118464_SUN_CHANG_LAI/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11189521_ZHU_KAI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11189521_ZHU_KAI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11189521_ZHU_KAI/slice_24.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11189521_ZHU_KAI/slice_28.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11189521_ZHU_KAI/slice_26.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11189521_ZHU_KAI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11189521_ZHU_KAI/slice_30.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11094651_HUANG_KE_PING/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11094651_HUANG_KE_PING/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11094651_HUANG_KE_PING/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11094651_HUANG_KE_PING/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11094651_HUANG_KE_PING/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11094651_HUANG_KE_PING/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11094651_HUANG_KE_PING/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11094651_HUANG_KE_PING/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11164558_HUANG_HAI_SEN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11164558_HUANG_HAI_SEN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11164558_HUANG_HAI_SEN/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11164558_HUANG_HAI_SEN/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11164558_HUANG_HAI_SEN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11164558_HUANG_HAI_SEN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11164558_HUANG_HAI_SEN/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11164558_HUANG_HAI_SEN/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118450_LI_GUI_HE/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118450_LI_GUI_HE/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118450_LI_GUI_HE/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118450_LI_GUI_HE/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118450_LI_GUI_HE/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118450_LI_GUI_HE/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118450_LI_GUI_HE/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11118450_LI_GUI_HE/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11076398_ZHOU_XIAO_JING/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11076398_ZHOU_XIAO_JING/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11076398_ZHOU_XIAO_JING/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11076398_ZHOU_XIAO_JING/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11076398_ZHOU_XIAO_JING/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11076398_ZHOU_XIAO_JING/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11076398_ZHOU_XIAO_JING/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11076398_ZHOU_XIAO_JING/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11146058_BAI_ZHI_HUI/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11146058_BAI_ZHI_HUI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11146058_BAI_ZHI_HUI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11146058_BAI_ZHI_HUI/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11146058_BAI_ZHI_HUI/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11146058_BAI_ZHI_HUI/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11146058_BAI_ZHI_HUI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11146058_BAI_ZHI_HUI/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11085352_LI_CHUAN_JIE/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11085352_LI_CHUAN_JIE/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11085352_LI_CHUAN_JIE/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11085352_LI_CHUAN_JIE/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11085352_LI_CHUAN_JIE/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11085352_LI_CHUAN_JIE/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11085352_LI_CHUAN_JIE/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11085352_LI_CHUAN_JIE/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11281530_YIN_TAO/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11281530_YIN_TAO/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11281530_YIN_TAO/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11281530_YIN_TAO/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11281530_YIN_TAO/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11281530_YIN_TAO/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11281530_YIN_TAO/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11281530_YIN_TAO/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11168743_TANG_ZHE_QI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11168743_TANG_ZHE_QI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11168743_TANG_ZHE_QI/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11168743_TANG_ZHE_QI/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11168743_TANG_ZHE_QI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11168743_TANG_ZHE_QI/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11168743_TANG_ZHE_QI/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11168743_TANG_ZHE_QI/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11156548_SUN_BING_FENG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11156548_SUN_BING_FENG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11156548_SUN_BING_FENG/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11156548_SUN_BING_FENG/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11156548_SUN_BING_FENG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11156548_SUN_BING_FENG/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11156548_SUN_BING_FENG/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11156548_SUN_BING_FENG/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11212917_FENG_MEI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11212917_FENG_MEI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11212917_FENG_MEI/slice_25.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11212917_FENG_MEI/slice_27.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11212917_FENG_MEI/slice_26.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11212917_FENG_MEI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11212917_FENG_MEI/slice_22.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11212917_FENG_MEI/slice_20.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160962_ZHANG_XUN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160962_ZHANG_XUN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160962_ZHANG_XUN/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160962_ZHANG_XUN/slice_24.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160962_ZHANG_XUN/slice_26.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160962_ZHANG_XUN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160962_ZHANG_XUN/slice_22.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160962_ZHANG_XUN/slice_20.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11111231_YU_LI_YING/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11111231_YU_LI_YING/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11111231_YU_LI_YING/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11111231_YU_LI_YING/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11111231_YU_LI_YING/slice_21.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11111231_YU_LI_YING/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11111231_YU_LI_YING/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11111231_YU_LI_YING/slice_22.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160508_NA_RI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160508_NA_RI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160508_NA_RI/slice_25.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160508_NA_RI/slice_27.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160508_NA_RI/slice_23.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160508_NA_RI/slice_21.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160508_NA_RI/slice_28.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11160508_NA_RI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11050994_ZHANG_YU_MIN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11050994_ZHANG_YU_MIN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11050994_ZHANG_YU_MIN/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11050994_ZHANG_YU_MIN/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11050994_ZHANG_YU_MIN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11050994_ZHANG_YU_MIN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11050994_ZHANG_YU_MIN/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11050994_ZHANG_YU_MIN/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11221786_YANG_JIN_PING/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11221786_YANG_JIN_PING/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11221786_YANG_JIN_PING/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11221786_YANG_JIN_PING/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11221786_YANG_JIN_PING/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11221786_YANG_JIN_PING/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11221786_YANG_JIN_PING/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11221786_YANG_JIN_PING/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11102082_XIA_YU_FENG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11102082_XIA_YU_FENG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11102082_XIA_YU_FENG/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11102082_XIA_YU_FENG/slice_24.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11102082_XIA_YU_FENG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11102082_XIA_YU_FENG/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11102082_XIA_YU_FENG/slice_22.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11102082_XIA_YU_FENG/slice_20.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11259805_LING_WEI_TONG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11259805_LING_WEI_TONG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11259805_LING_WEI_TONG/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11259805_LING_WEI_TONG/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11259805_LING_WEI_TONG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11259805_LING_WEI_TONG/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11259805_LING_WEI_TONG/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11259805_LING_WEI_TONG/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11025311_GAO_SHU_QI/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11025311_GAO_SHU_QI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11025311_GAO_SHU_QI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11025311_GAO_SHU_QI/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11025311_GAO_SHU_QI/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11025311_GAO_SHU_QI/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11025311_GAO_SHU_QI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11025311_GAO_SHU_QI/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073018_XIE_MI_HENG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073018_XIE_MI_HENG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073018_XIE_MI_HENG/slice_25.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073018_XIE_MI_HENG/slice_23.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073018_XIE_MI_HENG/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073018_XIE_MI_HENG/slice_21.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073018_XIE_MI_HENG/slice_26.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11073018_XIE_MI_HENG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11152289_QIN_PING/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11152289_QIN_PING/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11152289_QIN_PING/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11152289_QIN_PING/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11152289_QIN_PING/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11152289_QIN_PING/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11152289_QIN_PING/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11152289_QIN_PING/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11010268_YANG_SI_XI/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11010268_YANG_SI_XI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11010268_YANG_SI_XI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11010268_YANG_SI_XI/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11010268_YANG_SI_XI/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11010268_YANG_SI_XI/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11010268_YANG_SI_XI/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11010268_YANG_SI_XI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11068859_WANG_WEI_DONG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11068859_WANG_WEI_DONG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11068859_WANG_WEI_DONG/slice_25.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11068859_WANG_WEI_DONG/slice_29.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11068859_WANG_WEI_DONG/slice_27.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11068859_WANG_WEI_DONG/slice_23.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11068859_WANG_WEI_DONG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11068859_WANG_WEI_DONG/slice_30.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11117312_LI_CHUN_XIAO/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11117312_LI_CHUN_XIAO/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11117312_LI_CHUN_XIAO/slice_33.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11117312_LI_CHUN_XIAO/slice_28.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11117312_LI_CHUN_XIAO/slice_26.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11117312_LI_CHUN_XIAO/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11117312_LI_CHUN_XIAO/slice_30.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11117312_LI_CHUN_XIAO/slice_32.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11129945_ZHANG_FU_GANG/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11129945_ZHANG_FU_GANG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11129945_ZHANG_FU_GANG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11129945_ZHANG_FU_GANG/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11129945_ZHANG_FU_GANG/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11129945_ZHANG_FU_GANG/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11129945_ZHANG_FU_GANG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11129945_ZHANG_FU_GANG/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11204654_XU_HONG_HE/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11204654_XU_HONG_HE/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11204654_XU_HONG_HE/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11204654_XU_HONG_HE/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11204654_XU_HONG_HE/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11204654_XU_HONG_HE/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11204654_XU_HONG_HE/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11204654_XU_HONG_HE/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11096907_LIU_WEN_XIA/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11096907_LIU_WEN_XIA/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11096907_LIU_WEN_XIA/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11096907_LIU_WEN_XIA/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11096907_LIU_WEN_XIA/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11096907_LIU_WEN_XIA/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11096907_LIU_WEN_XIA/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11096907_LIU_WEN_XIA/slice_20.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11249394_LI_SHENG_CHEN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11249394_LI_SHENG_CHEN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11249394_LI_SHENG_CHEN/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11249394_LI_SHENG_CHEN/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11249394_LI_SHENG_CHEN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11249394_LI_SHENG_CHEN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11249394_LI_SHENG_CHEN/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11249394_LI_SHENG_CHEN/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11099946_XIE_SHU_YAN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11099946_XIE_SHU_YAN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11099946_XIE_SHU_YAN/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11099946_XIE_SHU_YAN/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11099946_XIE_SHU_YAN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11099946_XIE_SHU_YAN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11099946_XIE_SHU_YAN/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11099946_XIE_SHU_YAN/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11145966_ZHANG_LIN/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11145966_ZHANG_LIN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11145966_ZHANG_LIN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11145966_ZHANG_LIN/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11145966_ZHANG_LIN/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11145966_ZHANG_LIN/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11145966_ZHANG_LIN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11145966_ZHANG_LIN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11019940_CAO_YI_BING/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11019940_CAO_YI_BING/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11019940_CAO_YI_BING/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11019940_CAO_YI_BING/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11019940_CAO_YI_BING/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11019940_CAO_YI_BING/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11019940_CAO_YI_BING/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11019940_CAO_YI_BING/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11052795_LIANG_ZHAN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11052795_LIANG_ZHAN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11052795_LIANG_ZHAN/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11052795_LIANG_ZHAN/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11052795_LIANG_ZHAN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11052795_LIANG_ZHAN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11052795_LIANG_ZHAN/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11052795_LIANG_ZHAN/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11167374_CHEN_RI_KUN/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11167374_CHEN_RI_KUN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11167374_CHEN_RI_KUN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11167374_CHEN_RI_KUN/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11167374_CHEN_RI_KUN/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11167374_CHEN_RI_KUN/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11167374_CHEN_RI_KUN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11167374_CHEN_RI_KUN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11284926_LI_CHUN_SHENG/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11284926_LI_CHUN_SHENG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11284926_LI_CHUN_SHENG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11284926_LI_CHUN_SHENG/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11284926_LI_CHUN_SHENG/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11284926_LI_CHUN_SHENG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11282304_LU_FENG/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11282304_LU_FENG/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11282304_LU_FENG/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11282304_LU_FENG/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11282304_LU_FENG/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11282304_LU_FENG/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11282304_LU_FENG/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11282304_LU_FENG/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11202753_ZHAO_HONG_WEI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11202753_ZHAO_HONG_WEI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11202753_ZHAO_HONG_WEI/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11202753_ZHAO_HONG_WEI/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11202753_ZHAO_HONG_WEI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11202753_ZHAO_HONG_WEI/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11202753_ZHAO_HONG_WEI/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11202753_ZHAO_HONG_WEI/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11188808_ZHE_YI/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11188808_ZHE_YI/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11188808_ZHE_YI/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11188808_ZHE_YI/slice_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11188808_ZHE_YI/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11188808_ZHE_YI/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11188808_ZHE_YI/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11188808_ZHE_YI/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11131250_LI_BAO_YAN/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11131250_LI_BAO_YAN/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11131250_LI_BAO_YAN/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11131250_LI_BAO_YAN/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11131250_LI_BAO_YAN/slice_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11131250_LI_BAO_YAN/slice_14.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11131250_LI_BAO_YAN/slice_16.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11027726_ZHANG_SHI_KE/slice_13.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11027726_ZHANG_SHI_KE/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11027726_ZHANG_SHI_KE/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11027726_ZHANG_SHI_KE/slice_19.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11027726_ZHANG_SHI_KE/slice_15.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11027726_ZHANG_SHI_KE/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11027726_ZHANG_SHI_KE/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11027726_ZHANG_SHI_KE/slice_up.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11141561_LV_YU_ZHUO/slice_mid.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11141561_LV_YU_ZHUO/slice_down.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11141561_LV_YU_ZHUO/slice_17.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11141561_LV_YU_ZHUO/slice_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11141561_LV_YU_ZHUO/slice_10.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_0.994-20230109/SAX_data/11141561_LV_YU_ZHUO/slice_up.nii.gz saved
# ...
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11085352_LI_CHUAN_JIE/11085352_LI_CHUAN_JIE_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11281530_YIN_TAO/11281530_YIN_TAO_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11168743_TANG_ZHE_QI/11168743_TANG_ZHE_QI_10.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11156548_SUN_BING_FENG/11156548_SUN_BING_FENG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11212917_FENG_MEI/11212917_FENG_MEI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11160962_ZHANG_XUN/11160962_ZHANG_XUN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11111231_YU_LI_YING/11111231_YU_LI_YING_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11160508_NA_RI/11160508_NA_RI_10.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11050994_ZHANG_YU_MIN/11050994_ZHANG_YU_MIN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11221786_YANG_JIN_PING/11221786_YANG_JIN_PING_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11102082_XIA_YU_FENG/11102082_XIA_YU_FENG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11259805_LING_WEI_TONG/11259805_LING_WEI_TONG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11025311_GAO_SHU_QI/11025311_GAO_SHU_QI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11073018_XIE_MI_HENG/11073018_XIE_MI_HENG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11152289_QIN_PING/11152289_QIN_PING_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11010268_YANG_SI_XI/11010268_YANG_SI_XI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11068859_WANG_WEI_DONG/11068859_WANG_WEI_DONG_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11117312_LI_CHUN_XIAO/11117312_LI_CHUN_XIAO_23.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11129945_ZHANG_FU_GANG/11129945_ZHANG_FU_GANG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11204654_XU_HONG_HE/11204654_XU_HONG_HE_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11096907_LIU_WEN_XIA/11096907_LIU_WEN_XIA_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11249394_LI_SHENG_CHEN/11249394_LI_SHENG_CHEN_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11099946_XIE_SHU_YAN/11099946_XIE_SHU_YAN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11145966_ZHANG_LIN/11145966_ZHANG_LIN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11019940_CAO_YI_BING/11019940_CAO_YI_BING_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11052795_LIANG_ZHAN/11052795_LIANG_ZHAN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11167374_CHEN_RI_KUN/11167374_CHEN_RI_KUN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11284926_LI_CHUN_SHENG/11284926_LI_CHUN_SHENG_6.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11282304_LU_FENG/11282304_LU_FENG_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11202753_ZHAO_HONG_WEI/11202753_ZHAO_HONG_WEI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11188808_ZHE_YI/11188808_ZHE_YI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11131250_LI_BAO_YAN/11131250_LI_BAO_YAN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11027726_ZHANG_SHI_KE/11027726_ZHANG_SHI_KE_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11141561_LV_YU_ZHUO/11141561_LV_YU_ZHUO_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11027124_ZHAO_WEI_CHEN/11027124_ZHAO_WEI_CHEN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11148033_LU_YUAN_FEI/11148033_LU_YUAN_FEI_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11014788_XIE_YAN_LI/11014788_XIE_YAN_LI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11246261_MA_JING/11246261_MA_JING_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11192980_ZHU_SU_PING/11192980_ZHU_SU_PING_20.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11243069_DENG_XUE_LING/11243069_DENG_XUE_LING_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11210040_CHEN_XIAO_PING/11210040_CHEN_XIAO_PING_28.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11134949_ZHANG_QIU_JU/11134949_ZHANG_QIU_JU_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11037973_PEI_MENG_RAN/11037973_PEI_MENG_RAN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11021279_JIANG_HUI_MIAN/11021279_JIANG_HUI_MIAN_24.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11263836_LI_YU_HUI/11263836_LI_YU_HUI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11131291_FAN_TENG/11131291_FAN_TENG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11260908_SUN_XIU_MEI/11260908_SUN_XIU_MEI_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11014301_CAO_BIAN_HUI/11014301_CAO_BIAN_HUI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11220425_CHEN_SU_SHAO/11220425_CHEN_SU_SHAO_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11175099_SUN_XIU_ZHI/11175099_SUN_XIU_ZHI_20.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11028853_LI_BO/11028853_LI_BO_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11177575_SUN_FEI/11177575_SUN_FEI_21.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11206032_CHEN_YING/11206032_CHEN_YING_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11223710_HUO_SHI_CHEN/11223710_HUO_SHI_CHEN_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11225336_TAO_TAO/11225336_TAO_TAO_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11235452_LI_CHUN_SHENG/11235452_LI_CHUN_SHENG_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11160631_WU_YAN_QIU/11160631_WU_YAN_QIU_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11085795_JIANG_HONG_YING/11085795_JIANG_HONG_YING_10.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11209092_ZHENG_XIN_RAN/11209092_ZHENG_XIN_RAN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11206759_WU_HAI_YA/11206759_WU_HAI_YA_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11172697_ZHU_JIAN_JUN/11172697_ZHU_JIAN_JUN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11238949_WANG_HONG/11238949_WANG_HONG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11227269_MENG_XIANG_SHENG/11227269_MENG_XIANG_SHENG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11113376_LIU_GUI_XIA/11113376_LIU_GUI_XIA_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11157573_WANG_KAI/11157573_WANG_KAI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11112454_YUAN_BAO_KU/11112454_YUAN_BAO_KU_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11138395_LIU_BING/11138395_LIU_BING_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11092318_CHEN_HAI/11092318_CHEN_HAI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11277844_LI_ANG_HUA/11277844_LI_ANG_HUA_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11018757_LI_CHANG_DI/11018757_LI_CHANG_DI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11183126_OU_NA/11183126_OU_NA_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11094193_SUN_GUI_LAN/11094193_SUN_GUI_LAN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11048553_GU_WEN_HAO/11048553_GU_WEN_HAO_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11043193_ZHANG_YA_BI/11043193_ZHANG_YA_BI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11087256_LI_XIU_HUA/11087256_LI_XIU_HUA_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11105216_HAN_HONG/11105216_HAN_HONG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11113610_WANG_SHU_MIN/11113610_WANG_SHU_MIN_10.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11087255_XU_CHENG_SONG/11087255_XU_CHENG_SONG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11245804_CHEN_HANG_SHI/11245804_CHEN_HANG_SHI_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11133346_GUO_LI_LI/11133346_GUO_LI_LI_10.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11173375_ZHAO_YI_LIN/11173375_ZHAO_YI_LIN_22.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11249599_LI_WEI/11249599_LI_WEI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11267837_HE_YING_CHAN/11267837_HE_YING_CHAN_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11275163_JIANG_YI/11275163_JIANG_YI_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11138144_YIN_MAO_QIANG/11138144_YIN_MAO_QIANG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11171974_WU_ZHI_JIE/11171974_WU_ZHI_JIE_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11246614_WANG_ZE_LIN/11246614_WANG_ZE_LIN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11044344_WANG_XIANG/11044344_WANG_XIANG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11075738_SUN_FANG_CHEN/11075738_SUN_FANG_CHEN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11018749_FANG_SHUANG_DE/11018749_FANG_SHUANG_DE_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11020422_SUN_LI_CHUN/11020422_SUN_LI_CHUN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11241593_HUANG_YUN_SHENG/11241593_HUANG_YUN_SHENG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11098687_WANG_LIAN_SHENG/11098687_WANG_LIAN_SHENG_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11226470_ZHANG_JIAN_QIAO/11226470_ZHANG_JIAN_QIAO_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11238948_WU_NING/11238948_WU_NING_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11092973_SUN_YONG/11092973_SUN_YONG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11244768_LI_LI_YUN/11244768_LI_LI_YUN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11020793_LIU_GUI_XIANG/11020793_LIU_GUI_XIANG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11265807_CHEN_DONG_LIN/11265807_CHEN_DONG_LIN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11083236_WANG_XIU_CHUN/11083236_WANG_XIU_CHUN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11065601_ZHANG_BO_SHEN/11065601_ZHANG_BO_SHEN_10.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11043409_YAN_HAI_YAN/11043409_YAN_HAI_YAN_12.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11218072_GU_MING_GAO/11218072_GU_MING_GAO_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11081626_ZHAO_HONG_SHUAI/11081626_ZHAO_HONG_SHUAI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11010131_ZHANG_HAO_TONG/11010131_ZHANG_HAO_TONG_11.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11021910_ZHANG_JIN_KUI/11021910_ZHANG_JIN_KUI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11026321_TANG_CUI_ZHEN/11026321_TANG_CUI_ZHEN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11185655_CUI_LI_BIN/11185655_CUI_LI_BIN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11053932_CHEN_LI_PING/11053932_CHEN_LI_PING_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11136947_GUAN_XIU_YING/11136947_GUAN_XIU_YING_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11027178_ZHANG_JIA_YOU/11027178_ZHANG_JIA_YOU_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11216241_PEI_SHENG/11216241_PEI_SHENG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11143742_CAO_XIAO_YANG/11143742_CAO_XIAO_YANG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11223841_FENG_JUN_HUA/11223841_FENG_JUN_HUA_9.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11175410_SONG_KE_HAO/11175410_SONG_KE_HAO_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11212928_QI_BAO_SEN/11212928_QI_BAO_SEN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11099488_TAN_SHAO_JUN/11099488_TAN_SHAO_JUN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11117162_ZHOU_QUAN_FENG/11117162_ZHOU_QUAN_FENG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11103264_LI_SHU_JUN/11103264_LI_SHU_JUN_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11189790_XU_FENG_YONG/11189790_XU_FENG_YONG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11069928_LIU_FENG_JIE/11069928_LIU_FENG_JIE_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11131397_ZHOU_ZHI_HUI/11131397_ZHOU_ZHI_HUI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11117317_XIA_LI_GENG/11117317_XIA_LI_GENG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11019224_LI_JI_YONG/11019224_LI_JI_YONG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11254185_XU_HAI_QIN/11254185_XU_HAI_QIN_18.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11205387_YAN_JUN_ZHI/11205387_YAN_JUN_ZHI_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11004739_ZHANG_ZHAO_FENG/11004739_ZHANG_ZHAO_FENG_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11039151_ZHU_HE/11039151_ZHU_HE_8.nii.gz saved
# /Users/airskcer/Downloads/NP_nifti_spacing_1.826-20230109/4CH_data/11257864_LIU_YUN_HAI/11257864_LIU_YUN_HAI_7.nii.gz saved

# %%
def check_spacings(root='/data/Airscker/VST_fusion_dataset_M1/Dataset/Abnormal_nifti_spacing_1.826'):
    pats = []
    for roots, dirs, files in os.walk(root):
        if len(dirs) == 0:
            pats.append(roots)
    bar = tqdm(range(len(pats)))
    error = []
    for i in bar:
        target = pats[i].replace('1.826', '0.994')
        if not os.path.exists(target):
            error.append(pats[i])
        else:
            pat_num = len(os.listdir(pats[i]))
            target_num = len(os.listdir(target))
            if pat_num != target_num:
                error.append(f'{pats[i]} {pat_num} {target_num}')
    print(len(error))
    for i in range(len(error)):
        print(error[i])
check_spacings(root='/Users/airskcer/Downloads/HCM_nifti_spacing_1.826-10s/')
# Out:
# 100%|██████████| 40/40 [00:00<00:00, 17527.39it/s]
# 0

# %% [markdown]
# ## check slices' data size, if every patient's slices' size isn't uniformed, error occurs

# %%
def check_size(dataroot='/Users/airskcer/Downloads/DCM_nifti-20230107/'):
    error={}
    folders=[]
    for roots,dirs,files in os.walk(dataroot):
        if len(dirs)==0:
            folders.append(roots)
    bar=tqdm(range(len(folders)))
    for i in bar:
        files=exclude_seg_files(os.listdir(folders[i]))
        if len(files)==1:
            continue
        sizes=[]
        for j in range(len(files)):
            data=sitk.ReadImage(os.path.join(folders[i],files[j]))
            sizes.append(sitk.GetArrayFromImage(data).shape)
        sizes=np.array(sizes)
        if np.sum(np.std(sizes,axis=0))!=0:
            error[folders[i]]=sizes
    for key in error:
        print(key,error[key])
    return error
error=check_size(dataroot='/Users/airskcer/Downloads/LVNC_nifti-20221224/')
# Out:
# 100%|██████████| 1316/1316 [02:04<00:00, 10.57it/s]

# %%
def error_process(error_map: dict):
    """
    The error_process function is used to find the files that have different shapes and move them into a new folder.
    
    
    :param error_map: dict: Store the error information
    :return: The file names and the shape of the files that have an error
    :doc-author: Trelent
    """
    for path in error_map.keys():
        map={}
        files=exclude_seg_files(os.listdir(path))
        for i in range(len(files)):
            map[files[i]]=np.array(list(sitk.GetArrayFromImage(sitk.ReadImage(os.path.join(path,files[i]))).shape))
        shapes=np.array(list(map.values()))
        new_shape=np.unique(shapes,axis=0)
        error_shape=None
        if len(files)>2:
            for i in range(len(new_shape)):
                count=0
                for j in range(len(shapes)):
                    if np.all(shapes[j]==new_shape[i]):
                        count+=1
                if count==1:
                    error_shape=new_shape[i]
        else:
            continue
        if error_shape is not None:
            for key in map:
                if np.all(error_shape==map[key]):
                    print(path,key,error_shape)
                    # if 'SAX_LGE_data' in path:
                    #     target = path.replace('SAX_LGE_data', '4CH_LGE_data')
                        # try:
                        #     os.makedirs(target)
                        # except:
                        #     pass
                        # try:
                        #     shutil.move(os.path.join(path,key),target)
                        # except:
                        #     print(f'{target} already exists')
                    # os.remove(os.path.join(path,key))
error_process(error_map=error)
# Out:
# /Users/airskcer/Downloads/LVNC_nifti-20221224/SAX_data/11143330_XU_DONG_XI slice_8.nii.gz [ 25 162 192]
# /Users/airskcer/Downloads/LVNC_nifti-20221224/SAX_data/11470714_LIU_LI slice_8.nii.gz [  5 192 192]
# /Users/airskcer/Downloads/LVNC_nifti-20221224/SAX_data/11555140_LIU_FANG_FANG slice_8.nii.gz [ 25 162 192]
# /Users/airskcer/Downloads/LVNC_nifti-20221224/SAX_data/11850433_ZHANG_XIN slice_1.nii.gz [ 25 352 352]
# /Users/airskcer/Downloads/LVNC_nifti-20221224/SAX_data/11313413_QIAN_XIAO_LIN slice_12.nii.gz [ 25 168 192]
# /Users/airskcer/Downloads/LVNC_nifti-20221224/4CH_data/12108320_CHEN_HAO 12108320_CHEN_HAO_4.nii.gz [ 35 164 208]
# /Users/airskcer/Downloads/LVNC_nifti-20221224/4CH_data/11133538_QIAN_XIAO_LIN 11133538_QIAN_XIAO_LIN_8.nii.gz [ 25 162 192]
# /Users/airskcer/Downloads/LVNC_nifti-20221224/SAX_LGE_data/12108320_CHEN_HAO 12108320_CHEN_HAO_2.nii.gz [  5 256 256]
# /Users/airskcer/Downloads/LVNC_nifti-20221224/4CH_LGE_data/12108320_CHEN_HAO 12108320_CHEN_HAO_3.nii.gz [  1 256 256]
# /Users/airskcer/Downloads/LVNC_nifti-20221224/4CH_LGE_data/11579441_YAO_BAO_QIANG 11579441_YAO_BAO_QIANG_16.nii.gz [ 17 162 192]

# %% [markdown]
# ## Resample Every Patient's Data

# %%
import os
import pydicom
import shutil
import numpy as np
def resample_dataset(dataroot='./DICOMs',output='./New_dicom/'):
    """Resample the dataset to a new directory .

    Args:
        dataroot (str, optional):The root path of all patients' dicom files. Defaults to './DICOMs'.
        output (str, optional):The output path of resampled dicom dataset. Defaults to './New_dicom/'.
    """
    error=[]
    count=0
    for paths,dirs,files in os.walk(dataroot):
        # if len(dirs)==0:
        if True:
            for i in range(len(files)):
                try:
                    info=pydicom.dcmread(os.path.join(paths,files[i]))
                    id=info['0010','0020'].value
                    name=str(info['0010','0010'].value).replace(' ','_')
                    mod=str(info['0008','103e'].value).replace(':','_')
                    date=str(info['0008','0020'].value)
                    ui=str(info['0008','0018'].value)
                except:
                    print(f'Basic info missed: {os.path.join(paths,files[i])}')
                    continue
                if name!='':
                    savepath=os.path.join(output,f'{id}_{name}',date,mod).replace('*','_').replace('?','_').replace('>','_').replace('<','_')
                    if not os.path.exists(savepath):
                        os.makedirs(savepath)
                    count+=1
                    try:
                        shutil.copyfile(os.path.join(paths,files[i]),os.path.join(savepath,f'{ui}.dcm'))
                    except:
                        print(f"Error occured when copying {os.path.join(paths,files[i])} to {os.path.join(savepath,f'{ui}.dcm')}")
                    # os.remove(os.path.join(paths,files[i]))
                else:
                    error.append(os.path.join(paths,files[i]))
        # for i in range(len(error)):
        #     print(error[i])
    return error
resample_dataset(dataroot='/Users/airskcer/Downloads/HCM_20230112/',output='/Users/airskcer/Downloads/HCM_Resampled_dicom-20230112')
# resample_dataset(dataroot='/Users/airskcer/Downloads/RCM_20230107/',output='/Users/airskcer/Downloads/RCM_Resampled_dicom-20230107')
# resample_dataset(dataroot='E:/BaiduNetdiskDownload/HHD/',output='F:/resampled_dicom/HHD_Resampled_dicom-20221217')
# Out:
# Basic info missed: /Users/airskcer/Downloads/HCM_20230112/.DS_Store
# Basic info missed: /Users/airskcer/Downloads/HCM_20230112/.DS_Store.dcm
# Basic info missed: /Users/airskcer/Downloads/HCM_20230112/20230108-HCM(425例图+425例信息) 王家鑫/.DS_Store.dcm
# Basic info missed: /Users/airskcer/Downloads/HCM_20230112/20230108-HCM(425例图+425例信息) 王家鑫/2018.4th n=146/FU_ZHI_QIANG_046Y/Win10 (C) - ¿ì½Ý·½Ê½.lnk.dcm
# Basic info missed: /Users/airskcer/Downloads/HCM_20230112/HCM yk2/.DS_Store.dcm
# Basic info missed: /Users/airskcer/Downloads/HCM_20230112/HCM yk1/.DS_Store.dcm
# []

# %% [markdown]
# ## Save dicom data as nifti data, must be done AFTER dataset resample
# For SAX data, bigger slice number means lower position(at the most time)

# %%
def save_nifti(dataroot='./New_dicom/',output='./',fps=25,thres=4):
    """Convert dicom data files into nifti format, and resample its resolution
    Args:
        dataroot (str, optional): The root path of resampled data. Defaults to './New_dicom/'.
        output (str, optional): The output path of generated nfiti data. Defaults to './'.
        fps (int, optional): The fps of a single slice(SAX/LAX4CH). Defaults to 25.
    """
    for roots,dirs,files in os.walk(dataroot):
        if len(dirs)==0:
            slice_map={}
            file_info={}
            for i in range(len(files)):
                info=pydicom.dcmread(os.path.join(roots,files[i]))
                file_info[files[i]]=info
                sn=info.SeriesNumber
                if sn not in list(slice_map.keys()):
                    slice_map[sn]=[files[i]]
                else:
                    slice_map[sn].append(files[i])
            slices=list(slice_map.keys())
            for i in range(len(slices)):
                dcms=slice_map[slices[i]]
                pats_name=str(file_info[dcms[0]]['0010','0010'].value).replace(' ','_')
                pats_id=file_info[dcms[0]]['0010','0020'].value
                filetag=str(file_info[dcms[0]]['0008','103e'].value)
                print(f'filetag:{filetag}')
                if ('BH' in filetag or '4CH' in filetag or '4ch' in filetag or '4 CH' in filetag or 'TFE' in filetag or 'SecondaryCapture' in filetag or '1'==filetag) and ('SA' not in filetag and 'sa' not in filetag and 'shot' not in filetag and '8slices' not in filetag and 'LVOT' not in filetag):
                    if len(dcms)%fps==0:
                        temp_folder=os.path.join(output,'4ch_temp')
                        savepath=os.path.join(output,'4CH_data',f'{pats_id}_{pats_name}')
                        filename=f'{pats_id}_{pats_name}_{slices[i]}.nii.gz'
                    else:
                        temp_folder=os.path.join(output,'4ch_lge_temp')
                        savepath=os.path.join(output,'4CH_LGE_data',f'{pats_id}_{pats_name}')
                        filename=f'{pats_id}_{pats_name}_{slices[i]}.nii.gz'
                    for j in range(len(dcms)):
                        if not os.path.exists(temp_folder):
                            os.makedirs(temp_folder)
                        shutil.copyfile(os.path.join(roots,dcms[j]),os.path.join(temp_folder,dcms[j]))
                    if not os.path.exists(savepath):
                        os.makedirs(savepath)
                    # else:
                    #     os.remove(os.path.join(savepath,os.listdir(savepath)[0]))
                    try:
                        dcm2nii(temp_folder,os.path.join(savepath,filename))
                    except:
                        pass
                    # resample_volume(Origin=os.path.join(savepath,filename),output=os.path.join(savepath,filename))
                    print(f'{filename} saved into {savepath}')
                    shutil.rmtree(temp_folder)
                elif 'SA' in filetag or 'sa' in filetag or '2'==filetag or 'shot' in filetag or 'PSIR_TFE 8slices'==filetag:
                    """
                    Bigger slice ID, lower z-axis position
                    """
                    if len(dcms)%fps==0:
                        temp_folder=os.path.join(output,'sax_temp')
                        savepath=os.path.join(output,'SAX_data',f'{pats_id}_{pats_name}')
                        filename=f'slice_{slices[i]}.nii.gz'
                    else:
                        temp_folder=os.path.join(output,'sax_lge_temp')
                        savepath=os.path.join(output,'SAX_LGE_data',f'{pats_id}_{pats_name}')
                        filename=f'{pats_id}_{pats_name}_{slices[i]}.nii.gz'
                    for j in range(len(dcms)):
                        if not os.path.exists(temp_folder):
                            os.makedirs(temp_folder)
                        shutil.copyfile(os.path.join(roots,dcms[j]),os.path.join(temp_folder,dcms[j]))
                    if not os.path.exists(savepath):
                        os.makedirs(savepath)
                    try:
                        dcm2nii(temp_folder,os.path.join(savepath,filename))
                    except:
                        pass
                    # resample_volume(Origin=os.path.join(savepath,filename),output=os.path.join(savepath,filename))
                    print(f'{filename} saved into {savepath}')
                    shutil.rmtree(temp_folder)
    temps=['4ch_temp','4ch_lge_temp','sax_temp','sax_lge_temp']
    for i in range(len(temps)):
        try:
            shutil.rmtree(os.path.join(output,temps[i]))
        except: 
            pass

# save_nifti(dataroot='./test2/HCM_new/12162262_WANG_JIAN_LIANG/',output='./test2/HCM_nfiti')
# save_nifti(dataroot='F:/resampled_dicom/DCM_Resampled_dcm-20221129/12093484_MA_QUAN_BAO/20220105/PS_PSMDE SPGR SA/',output='E:/nifti_original_space/DCM_nifti-20221129/SAX_LGE_data/',fps=25,thres=4)
# save_nifti(dataroot='E:/BaiduNetdiskDownload/NP_Resampled_dicom-20221212/12083851_WANG_WEN_HOU/20211210/Cine FIESTA SA/',output='E:/BaiduNetdiskDownload/NP_nifti-20221212/',fps=25,thres=4)
# fix_seriesnum(root=r'E:\BaiduNetdiskDownload\CAD_Resampled_dicom\12027538_LI_BAO_MING\20210309\Cine FIESTA SA',threshold=30)
# save_nifti2(dataroot='E:/BaiduNetdiskDownload/ARVC_2_Resampled_dicom/11589224_ZHANG_MING_HAO/20160126/B-TFE_BH/',output='E:/VST_fusion/ARVC_2_nifti/',fps=30,thres=50)
# save_nifti2(dataroot='E:/BaiduNetdiskDownload/RCM_Resampled_dicom-20221216/11894742_SUN_JIAN_LIN/20210705/4CH_LGE/',output='E:/BaiduNetdiskDownload/RCM_nifti-20221216',fps=25,thres=4)
# save_nifti2(dataroot='E:/BaiduNetdiskDownload/HCM_Resampled_dicom/12066703_CHEN_BAI_GANG/20210810/PSIR_TFE 8slices_LGE/',output='E:/BaiduNetdiskDownload/HCM_nifti',fps=25,thres=4)
# save_nifti2(dataroot='E:/BaiduNetdiskDownload/HCM_Resampled_dcm/12145504_SUN_QING_HE/20220808/cine_trufi_retro_4ch/',output='E:/BaiduNetdiskDownload/HCM_nifti',fps=25)

# %% [markdown]
# ## Save CINE

# %%
def save_cine(dataroot='./New_dicom/',output='./',fps=25,thres=60):
    """Convert dicom data files into nifti format, and resample its resolution
    Args:
        dataroot (str, optional): The root path of resampled data. Defaults to './New_dicom/'.
        output (str, optional): The output path of generated nfiti data. Defaults to './'.
        fps (int, optional): The fps of a single slice(SAX/LAX4CH). Defaults to 25.
    """
    error=[]
    for roots,dirs,files in os.walk(dataroot):
        if len(dirs)==0:
            try:
                slice_map={}
                file_info={}
                files=exclude_seg_files(files)
                for i in range(len(files)):
                    info=pydicom.dcmread(os.path.join(roots,files[i]))
                    file_info[files[i]]=info
                    sn=info.SeriesNumber
                    if sn not in list(slice_map.keys()):
                        slice_map[sn]=[files[i]]
                    else:
                        slice_map[sn].append(files[i])
                slices=list(slice_map.keys())
                for i in range(len(slices)):
                    dcms=slice_map[slices[i]]
                    pats_name=str(file_info[dcms[0]]['0010','0010'].value).replace(' ','_')
                    pats_id=file_info[dcms[0]]['0010','0020'].value
                    filetag=str(file_info[dcms[0]]['0008','103e'].value)
                    print(filetag)
                    # if ('BH' in filetag or '4CH' in filetag or '4 CH' in filetag or 'TFE' in filetag or 'SecondaryCapture' in filetag or '1'==filetag) and ('SA' not in filetag and 'sa' not in filetag and 'shot' not in filetag and '8slices' not in filetag and 'LVOT' not in filetag):
                    if len(files)<thres and 'LVOT' not in filetag:
                        print(f'fps: {len(dcms)}')
                        # if len(dcms)%fps==0:
                        if len(dcms)>=10:
                            temp_folder=os.path.join(output,'4ch_temp')
                            savepath=os.path.join(output,'4CH_data',f'{pats_id}_{pats_name}')
                            filename=f'{pats_id}_{pats_name}_{slices[i]}.nii.gz'
                            # continue
                        else:
                            # temp_folder=os.path.join(output,'4ch_lge_temp')
                            # savepath=os.path.join(output,'4CH_LGE_data',f'{pats_id}_{pats_name}')
                            # filename=f'{pats_id}_{pats_name}_{slices[i]}.nii.gz'
                            continue
                        for j in range(len(dcms)):
                            if not os.path.exists(temp_folder):
                                os.makedirs(temp_folder)
                            shutil.copyfile(os.path.join(roots,dcms[j]),os.path.join(temp_folder,dcms[j]))
                        if not os.path.exists(savepath):
                            os.makedirs(savepath)
                        try:
                        # if True:
                            dcm2nii(temp_folder,os.path.join(savepath,filename))
                            # resample_volume(Origin=os.path.join(savepath,filename),output=os.path.join(savepath,filename))
                            print(f'{filename} saved into {savepath}')
                        except:
                            pass
                        shutil.rmtree(temp_folder)
                    # elif 'SA' in filetag or 'sa' in filetag or '2'==filetag or 'shot' in filetag or 'PSIR_TFE 8slices'==filetag:
                    elif len(files)>=thres:
                        print(f'fps: {len(dcms)}')
                        """
                        Bigger slice ID, lower z-axis position
                        """
                        # if len(dcms)%fps==0:
                        # if len(dcms)>=25:
                        if True:
                            temp_folder=os.path.join(output,'sax_temp')
                            savepath=os.path.join(output,'SAX_data',f'{pats_id}_{pats_name}')
                            filename=f'slice_{slices[i]}.nii.gz'
                            # continue
                        else:
                            # temp_folder=os.path.join(output,'sax_lge_temp')
                            # savepath=os.path.join(output,'SAX_LGE_data',f'{pats_id}_{pats_name}')
                            # filename=f'{pats_id}_{pats_name}_{slices[i]}.nii.gz'
                            continue
                        for j in range(len(dcms)):
                            if not os.path.exists(temp_folder):
                                os.makedirs(temp_folder)
                            shutil.copyfile(os.path.join(roots,dcms[j]),os.path.join(temp_folder,dcms[j]))
                        if not os.path.exists(savepath):
                            os.makedirs(savepath)
                        try:
                            dcm2nii(temp_folder,os.path.join(savepath,filename))
                            # resample_volume(Origin=os.path.join(savepath,filename),output=os.path.join(savepath,filename))
                            print(f'{filename} saved into {savepath}')
                        except:
                            pass 
                        shutil.rmtree(temp_folder)
            except:
                print(f'unknow error occured with {roots}')
                error.append(roots)
    temps=['4ch_temp','4ch_lge_temp','sax_temp','sax_lge_temp']
    for i in range(len(temps)):
        try:
            shutil.rmtree(os.path.join(output,temps[i]))
        except:
            pass
    return error
cine_error=save_cine(dataroot='/Users/airskcer/Downloads/HCM_Resampled_dicom-20230112/',output='/Users/airskcer/Downloads/HCM_nifti-20230112/',fps=25,thres=80)
# save_cine(dataroot='/Users/airskcer/Downloads/RCM_Resampled_dicom-20230107/11124028_SHI_KE_GANG/',output='/Users/airskcer/Downloads/RCM_nifti-20230107/',fps=25,thres=60)

# %%
# path='/Users/airskcer/Downloads/check/'
# pats=os.listdir(path)
# pats=exclude_seg_files(pats)
# for i in range(len(pats)):
#     id=int(pats[i].split('.jpg')[0].split('_')[-1])
#     pat_name=pats[i].split('.jpg')[0].replace(f'_{id}','')
#     save_cine(dataroot=f'/Users/airskcer/Downloads/HCM_Resampled_dicom-20230102/{pat_name}',output='/Users/airskcer/Downloads/HCM_nifti-20230102/',thres=60)
# for roots,dirs,files in os.walk('/Users/airskcer/Downloads/HCM_nifti-20230102/4CH_data/'):
#     if len(dirs)==0:
#         files=exclude_seg_files(files)
#         for i in range(len(files)):
#             if files[i].replace('.nii.gz','.jpg') in pats:
#                 print(files[i])
#                 os.remove(os.path.join(roots,files[i]))

# %% [markdown]
# ## Check data lost

# %%
nifti_path='/Users/airskcer/Downloads/HCM_nifti-20230112/4CH_data/'
dcm_path='/Users/airskcer/Downloads/HCM_Resampled_dicom-20230112/'
dcms=os.listdir(dcm_path)
niftis=os.listdir(nifti_path)
error=[]
for i in range(len(niftis)):
    if niftis[i].startswith('._'):
        os.remove(os.path.join(nifti_path,niftis[i]))
print(len(niftis),len(dcms))
for i in range(len(dcms)):
    if dcms[i] not in niftis:
        print(dcms[i])
        error.append(os.path.join(dcm_path,dcms[i]))
# print(error)11
# Out:
# 672 679
# 11935261_PEI_YUN_PENG
# 11868487_LIU_FENG_LAN
# 12104331_ZHONG_HUI
# 12096792_HOU_XIAO_LI
# 12103375_MA_YI_FEN
# 11865661_WU_CUI_LAN
# 11266381_LUO_CHANG_SHENG

# %%
ds_store(root='/Users/airskcer/Downloads/')
del_empty(root='/Users/airskcer/Downloads/')

# %% [markdown]
# ## Divide 4CH_LGE and SAX_LGE into different folders

# %%
def fix_4ch_lge(path=r'E:\BaiduNetdiskDownload\ARVC_1\11235202_HE_HUI',fps=25,thres=4):
    for roots,dirs,files in os.walk(path):
        if len(dirs)==0:
            size={}
            if len(files)%fps!=0 and len(files)<50:
                for i in range(len(files)):
                    sd=pydicom.dcmread(os.path.join(roots,files[i])).pixel_array.shape
                    if sd in size.keys():
                        size[sd].append(os.path.join(roots,files[i]))
                    else:
                        size[sd]=[os.path.join(roots,files[i])]
                # print(size)
                # if len(size.keys())>1:
                #     print(roots)
                if len(size.keys())==2:
                    savepath=roots.replace(roots.split('/')[-1],'4CH_LGE')
                    # print(savepath)
                    try:
                        os.makedirs(savepath)
                    except:
                        pass
                    f_key=None
                    num=len(files)
                    for key in size.keys():
                        if len(size[key])<num:
                            f_key=key
                            num=len(size[key])
                    for i in range(len(size[f_key])): 
                        shutil.move(size[key][i],savepath)
                        print(f'{size[key][i]} moved to {savepath}')
# for i in range(len(error)):
#     save_nifti2(dataroot=error[i],output='E:/BaiduNetdiskDownload/ARVC_1_nifti',fps=25,thres=4)
# fix_4ch_lge(path='E:/BaiduNetdiskDownload/CHD_Resampled_dicom-20221210/')
fix_4ch_lge(path='/Users/airskcer/Downloads/HCM_Resampled_dicom-20230112/')
# fix_4ch_lge(path='/Users/airskcer/Downloads/RCM_Resampled_dicom-20230107/')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [8], line 34
#      30                         print(f'{size[key][i]} moved to {savepath}')
#      31 # for i in range(len(error)):
#      32 #     save_nifti2(dataroot=error[i],output='E:/BaiduNetdiskDownload/ARVC_1_nifti',fps=25,thres=4)
#      33 # fix_4ch_lge(path='E:/BaiduNetdiskDownload/CHD_Resampled_dicom-20221210/')
# ---> 34 fix_4ch_lge(path='/Users/airskcer/Downloads/HCM_Resampled_dicom-20230112/')
#      35 # fix_4ch_lge(path='/Users/airskcer/Downloads/RCM_Resampled_dicom-20230107/')
#
# Cell In [8], line 7, in fix_4ch_lge(path, fps, thres)
#       5 if len(files)%fps!=0 and len(files)<50:
#       6     for i in range(len(files)):
# ----> 7         sd=pydicom.dcmread(os.path.join(roots,files[i])).pixel_array.shape
#       8         if sd in size.keys():
#       9             size[sd].append(os.path.join(roots,files[i]))
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pydicom/dataset.py:834, in Dataset.__getattr__(self, name)
#     832     return {}
#     833 # Try the base class attribute getter (fix for issue 332)
# --> 834 return object.__getattribute__(self, name)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pydicom/dataset.py:1887, in Dataset.pixel_array(self)
#    1872 @property
#    1873 def pixel_array(self) -> "numpy.ndarray":
#    1874     """Return the pixel data as a :class:`numpy.ndarray`.
#    1875
#    1876     .. versionchanged:: 1.4
#    (...)
#    1885         :class:`numpy.ndarray`.
#    1886     """
# -> 1887     self.convert_pixel_data()
#    1888     return cast("numpy.ndarray", self._pixel_array)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pydicom/dataset.py:1444, in Dataset.convert_pixel_data(self, handler_name)
#    1442     self._convert_pixel_data_using_handler(handler_name)
#    1443 else:
# -> 1444     self._convert_pixel_data_without_handler()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pydicom/dataset.py:1556, in Dataset._convert_pixel_data_without_handler(self)
#    1547 self._pixel_id = {}
#    1549 logger.info(
#    1550     "Unable to decode the pixel data using the following handlers: {}."
#    1551     "Please see the list of supported Transfer Syntaxes in the "
#    (...)
#    1554     .format(", ".join([str(hh) for hh in available_handlers]))
#    1555 )
# -> 1556 raise last_exception
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pydicom/dataset.py:1536, in Dataset._convert_pixel_data_without_handler(self)
#    1534 for handler in available_handlers:
#    1535     try:
# -> 1536         self._do_pixel_data_conversion(handler)
#    1537         return
#    1538     except Exception as exc:
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pydicom/dataset.py:1563, in Dataset._do_pixel_data_conversion(self, handler)
#    1559 """Do the actual data conversion using the given handler."""
#    1561 # Use the handler to get a 1D numpy array of the pixel data
#    1562 # Will raise an exception if no pixel data element
# -> 1563 arr = handler.get_pixeldata(self)
#    1564 self._pixel_array = reshape_pixel_array(self, arr)
#    1566 # Some handler/transfer syntax combinations may need to
#    1567 #   convert the color space from YCbCr to RGB
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pydicom/pixel_data_handlers/numpy_handler.py:174, in get_pixeldata(ds, read_only)
#     172 px_keyword = [kw for kw in keywords if kw in ds]
#     173 if len(px_keyword) != 1:
# --> 174     raise AttributeError(
#     175         "Unable to convert the pixel data: one of Pixel Data, Float "
#     176         "Pixel Data or Double Float Pixel Data must be present in "
#     177         "the dataset"
#     178     )
#     180 # Attributes required by both Floating Point Image Pixel Module Attributes
#     181 # and Image Pixel Description Macro Attributes
#     182 required_elements = [
#     183     'BitsAllocated', 'Rows', 'Columns',
#     184     'SamplesPerPixel', 'PhotometricInterpretation'
#     185 ]
#
# AttributeError: Unable to convert the pixel data: one of Pixel Data, Float Pixel Data or Double Float Pixel Data must be present in the dataset

# %% [markdown]
# ## Get spacing info

# %%
import pandas as pd
from tqdm import tqdm

def get_data(path='./test2/HCM_new/'):
    """
    The get_data function returns a list of dictionaries, where each dictionary contains the patient's name, 
    patient ID number, and vendor. The function takes one argument: path to the directory containing all patients' 
    data folders. It will return a list of dictionaries with each dictionary containing information about one patient.
    
    :param path='./test2/HCM_new/': Specify the path to the directory containing all of your patients' dicom files
    :return: A list of dictionaries
    """
    pats=os.listdir(path)
    all_data=[]
    for i in range(len(pats)):
        pat_path=os.path.join(path,pats[i])
        pat_data={}
        for roots,dirs,files in os.walk(pat_path):
            if len(dirs)==0:
                for i in range(len(files)):
                    info=pydicom.dcmread(os.path.join(roots,files[i]))
                    pat_data['Name']=str(info['0010','0010'].value)
                    pat_data['ID']=info['0010','0020'].value
                    if len(files)%25==0:
                        pat_data['Vendor_cine']=str(info['0008','0070'].value)
                        if len(files)>100:
                            try:
                                pat_data['SAX_cine_z_spacing']=float(info['0018','0088'].value)
                            except:
                                pass
                            try:
                                pat_data['SAX_cine_xy_spacing']=list(info['0028','0030'].value)
                            except:
                                pass
                        else:
                            try:
                                pat_data['4CH_cine_z_spacing']=float(info['0018','0088'].value)
                            except:
                                pass
                            try:
                                pat_data['4CH_cine_xy_spacing']=list(info['0028','0030'].value)
                            except:
                                pass
                    # elif len(files):
                    else:
                        pat_data['Vendor_LGE']=info['0008','0070'].value
                        if len(files)>5:
                            try:
                                pat_data['SAX_LGE_z_spacing']=float(info['0018','0088'].value)
                            except:
                                pass
                            try:
                                pat_data['SAX_LGE_xy_spacing']=list(info['0028','0030'].value)
                            except:
                                pass
                        else:
                            try:
                                pat_data['4CH_LGE_z_spacing']=float(info['0018','0088'].value)
                            except:
                                pass
                            try:
                                pat_data['4CH_LGE_xy_spacing']=list(info['0028','0030'].value)
                            except:
                                pass
        print(pat_data)
        all_data.append(pat_data)
    return all_data
def get_info_from_nifti(nifti_path='E:/BaiduNetdiskDownload/DCM_nifti/',check_mode=True):
    niftis=['4CH_data','4CH_LGE_data','SAX_data','SAX_LGE_data']
    avail_pats=[]
    for i in range(len(niftis)):
        try:
            pats=os.listdir(os.path.join(nifti_path,niftis[i]))
            if len(pats)>len(avail_pats):
                avail_pats=pats
        except:
            pass
    print(f'{len(avail_pats)} patients available')
    all_info=[]
    
    bar=tqdm(range(len(avail_pats)),mininterval=1)
    for i in bar:
        pat_info=dict(name=avail_pats[i])
        for j in range(len(niftis)):
            sizes = []
            try:
                pat_folder=os.path.join(nifti_path,niftis[j],avail_pats[i])
                pat_files=exclude_seg_files(os.listdir(pat_folder))
                if check_mode:
                    for k in range(len(pat_files)):
                        data=sitk.ReadImage(os.path.join(pat_folder,pat_files[k]))
                        sizes.append(list(data.GetSpacing()))
                else:
                    data = sitk.ReadImage(os.path.join(pat_folder, pat_files[0]))
                spacing=data.GetSpacing()
                pat_info[f'{niftis[j]}_xyz']=spacing
            except:
                pass
            if check_mode:
                sizes=np.array(sizes)
                if np.all(np.std(sizes,axis=0))!=0:
                    print(pat_folder,sizes)
        all_info.append(pat_info)
        # break
    return all_info
# all_info=[]
# mods=os.listdir('E:/nifti_original_space/')
# for i in range(len(mods)):
#     folder=os.path.join('E:/nifti_original_space/',mods[i])
#     if os.path.isdir(folder):
#         print(folder)
#         niftis=['4CH_data','4CH_LGE_data','SAX_data','SAX_LGE_data']
#         avail_pats=[]
#         for j in range(len(niftis)):
#             try:
#                 pats=os.listdir(os.path.join(folder,niftis[j]))
#                 if len(pats)>len(avail_pats):
#                     avail_pats=pats
#             except:
#                 pass
        # all_info+=get_info_from_nifti(nifti_path=folder)
        # all_info+=find_error(nifti_path=folder,niftis=avail_pats)
# all_info=get_info_from_nifti(nifti_path='/Volumes/SSD/HHD_nifti-20221217/')
all_info=get_info_from_nifti(nifti_path='/Users/airskcer/Downloads/NP_nifti-20230109/',check_mode=False)
# all_info=find_error(nifti_path='E:/BaiduNetdiskDownload/RCM_nifti-20221216/',niftis=os.listdir('E:/BaiduNetdiskDownload/RCM_Resampled_dicom-20221216'))
# hcm_data1=get_data(path='E:/BaiduNetdiskDownload/HCM_Resampled_dcm/')
# cad_data=get_data(path='./test2/CAD_new/')
# all_data=pd.DataFrame(hcm_data+cad_data)
# all_data.to_excel('spacing_info.xlsx',index=False)
# data=pd.DataFrame(get_data(path='./test4/DCM_new/'))
# data.to_excel('./test4/spacing_info.xlsx',index=False)
# Out:
# 151 patients available
# 100%|██████████| 151/151 [00:04<00:00, 33.13it/s]

# %%
pd.DataFrame(all_info).to_csv('./fuwai_dataset/NP_20230109/spacing_info.csv',index=False)

# %% [markdown]
# ## Print all meteadata of a single dicom file or all dicom files in a folder

# %%
def dicom_metadata(path):
    if os.path.isdir(path):
        for roots,dirs,files in os.walk(path):
            if len(dirs)==0:
                for i in range(len(files)):
                    if files[i].endswith('.dcm'):
                        info=pydicom.dcmread(os.path.join(roots,files[i]))
                        print(info)
    elif path.endswith('.dcm'):
        info=pydicom.dcmread(path)
        print(info)
    return info
# dicom_metadata('./New_dicom/11892346_ZHANG_YING/20190528/Cine FIESTA SA/')

# %%
dicom_metadata('F:/resampled_dicom/ARVC_1_Resampled_dicom/11097334_FENG_ZHEN/20110117/4CH_LGE/')
