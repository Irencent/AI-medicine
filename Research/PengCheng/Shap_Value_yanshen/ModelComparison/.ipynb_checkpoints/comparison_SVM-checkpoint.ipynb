# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from tqdm import tqdm

from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import StandardScaler
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline
from lifelines import CoxPHFitter
import shap
import xgboost
import matplotlib.pyplot as plt
import statistics as st
from bayes_opt import BayesianOptimization
from bayes_opt.util import UtilityFunction
from pyirr import intraclass_correlation
from lightgbm import LGBMClassifier
from sklearn.svm import SVC
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
from feature_utils.feature_classfication import data_normalization, data_normalization_apply_cohort1_to_all, lgb_evaluate_lgbm, lgb_evaluate_svm

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from functools import partial
from sklearn.preprocessing import label_binarize

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score, roc_auc_score, roc_curve, auc
import sys
import argparse

import csv
import os
# Out:
# /var/folders/nj/6hcc0q8x30x74w9dhvw1xz2r0000gn/T/ipykernel_3091/1228147542.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def write_experiment_results_to_csv(file_path, data_dict):
    file_exists = os.path.isfile(file_path)

    with open(file_path, 'a', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=data_dict.keys())

        if not file_exists:
            writer.writeheader()

        writer.writerow(data_dict)

def f1_scores(label_f1, pred_f1, pos_index):
    """
    Calculate f1 score（for bootstrap）
    :param data: data[:, 0] = pred, data[:, 1] = label, data[:, 2] = index
    :return: f1 score
    """
    conf_mat = confusion_matrix(y_true=label_f1, y_pred=pred_f1)

    tp = conf_mat[pos_index][pos_index]
    fp = np.sum(conf_mat[:, pos_index]) - tp
    fn = np.sum(conf_mat[pos_index]) - tp
    precision = tp / (tp + fp)
    recall = tp / (tp + fn)
    f1_cls = 2 * precision * recall / (precision + recall)
    return f1_cls

def update_value_ep(x):
    if x < 0.1:
        return 0
    elif 0.1 <= x <= 0.5:
        return 0.5
    else:
        return 1
    
def update_value_age(x):
    """
    年龄的encoding：0-3，3-6，6-9，9-12，12-15，15-18，18+, [0, 0.15, 0.3, 0.45, 0.6, 0.75, 1]
    """
    if x < 3:
        return 0
    elif 3 <= x < 6:
        return 0.15
    elif 6 <= x < 9:
        return 0.3
    elif 9 <= x < 12:
        return 0.45
    elif 12 <= x < 15:
        return 0.6
    elif 15 <= x < 18:
        return 0.75
    else:
        return 1
    
def update_value_dsmn(x):
    """
    转移pattern：C-D-（0）；C-D+（0.25）；C+D-（0.5）；C+NA（0.75）；C+D+（1）
    """
    if x ==0:
        return 0
    elif x==0.25:
        return 1.0
    elif x==0.375:
        return 0.75
    elif x==0.5:
        return 0.5
    elif x==0.75:
        return 0.25
    else:
        return 0
    
class DummyFile(object):
    def write(self, x): pass

# %%
three_cls_path =  '/Users/huyanshen/Desktop/AI-Medicine/Research/PengCheng/Shap_Value_yanshen/ModelComparison/new_3cls_radiomics_new.txt'#args.radiomics_file
three_cls_path_c4 = '/Users/huyanshen/Desktop/AI-Medicine/Research/PengCheng/Shap_Value_yanshen/ModelComparison/new_3cls_radiomics_cohort4_new.txt'#args.radiomics_file_c4
data = pd.read_csv(three_cls_path, sep='\t')
data_c4 = pd.read_csv(three_cls_path_c4, sep='\t')

# %%
wnt_shh_g34_feature_names = ['T1E_log-sigma-3-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis_x',
     'T1E_log-sigma-3-mm-3D_glcm_Autocorrelation_x',
     'T1E_log-sigma-1-mm-3D_glcm_ClusterShade_x',
     'T1E_wavelet-LHL_firstorder_Mean_x',
     'T2_wavelet-LLH_glcm_ClusterShade_y',
     'T1E_log-sigma-5-mm-3D_glrlm_LowGrayLevelRunEmphasis_x',
     'T1E_wavelet-HLL_firstorder_Median_x',
     'T1E_wavelet-LHL_firstorder_Median_x',
     'T2_wavelet-HHL_firstorder_Skewness_x',
     'T1E_log-sigma-3-mm-3D_glrlm_LongRunLowGrayLevelEmphasis_x',
     'T1E_lbp-2D_glrlm_RunLengthNonUniformity_x',
     'T2_log-sigma-1-mm-3D_gldm_LowGrayLevelEmphasis_x',
     'T1E_log-sigma-5-mm-3D_firstorder_90Percentile_x',
     'T1E_log-sigma-3-mm-3D_glszm_LowGrayLevelZoneEmphasis_x',
     'T2_wavelet-HHL_glcm_SumSquares_x',
     'T2_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized_x',
     'T2_wavelet-LLH_gldm_DependenceNonUniformity_x',
     'T2_original_shape_Maximum3DDiameter_y',
     'T2_original_glszm_LargeAreaEmphasis_y']

clinical_feature_names = ''
    
id_val = data[data['Cohort']!=1]['id'].tolist()
id_new = data_c4['id'].tolist()
print('Val id: ', len(id_val))
print('New id: ', len(id_new))
    #['Location','FourthIn','Enhance','Enhance_Percent','Margin','Water','Cyst','Hydro','EpendymalDissemination','3rdVIRDissemination','SuperLMD','InfraLMD','LMDPattern','Ependymal3Dissemination','LMDDissemination','AllDissemination']
clnc_all =['Location','FourthIn','Enhance','Enhance_Percent','Margin','Water','Cyst','Hydro','EpendymalDissemination','3rdVIRDissemination','SuperLMD','InfraLMD','LMDPattern','Ependymal3Dissemination','LMDDissemination','AllDissemination']
# Out:
# Val id:  135
# New id:  44

# %%
sel_columns_basic = ['Cohort','Subtypes_three','fold','Age']
sel_columns = sel_columns_basic + wnt_shh_g34_feature_names

x = data[sel_columns]
x.iloc[:, 4:] = x.iloc[:, 4:].astype(float)
print('total features and labels shape: ', x.shape)
x_new = data_c4[sel_columns]
print(sel_columns, x_new.shape)
x_new.iloc[:, 3:] = x_new.iloc[:, 3:].astype(float)
print('total features and labels shape: ', x.shape)
# Out:
# total features and labels shape:  (649, 23)
# ['Cohort', 'Subtypes_three', 'fold', 'Age', 'T1E_log-sigma-3-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis_x', 'T1E_log-sigma-3-mm-3D_glcm_Autocorrelation_x', 'T1E_log-sigma-1-mm-3D_glcm_ClusterShade_x', 'T1E_wavelet-LHL_firstorder_Mean_x', 'T2_wavelet-LLH_glcm_ClusterShade_y', 'T1E_log-sigma-5-mm-3D_glrlm_LowGrayLevelRunEmphasis_x', 'T1E_wavelet-HLL_firstorder_Median_x', 'T1E_wavelet-LHL_firstorder_Median_x', 'T2_wavelet-HHL_firstorder_Skewness_x', 'T1E_log-sigma-3-mm-3D_glrlm_LongRunLowGrayLevelEmphasis_x', 'T1E_lbp-2D_glrlm_RunLengthNonUniformity_x', 'T2_log-sigma-1-mm-3D_gldm_LowGrayLevelEmphasis_x', 'T1E_log-sigma-5-mm-3D_firstorder_90Percentile_x', 'T1E_log-sigma-3-mm-3D_glszm_LowGrayLevelZoneEmphasis_x', 'T2_wavelet-HHL_glcm_SumSquares_x', 'T2_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized_x', 'T2_wavelet-LLH_gldm_DependenceNonUniformity_x', 'T2_original_shape_Maximum3DDiameter_y', 'T2_original_glszm_LargeAreaEmphasis_y'] (44, 23)
# total features and labels shape:  (649, 23)

# %%
# split base dataset and external validation dataset
df_val = x[(x['Cohort'] == 2) | (x['Cohort'] == 3)]
df_val.reset_index(inplace=True)
X_val = df_val.iloc[:, 4:]

feature_names = X_val.columns.tolist()
X_val = np.array(X_val)
y_val = df_val['Subtypes_three']
y_val = np.array(y_val)
    
df_new = x_new
X_new = df_new.iloc[:, 3:]

feature_names = X_new.columns.tolist()
print(feature_names)
X_new = np.array(X_new)
y_new = df_new['Subtypes_three']
y_new = np.array(y_new)

print('X-val: ', X_val.shape)
print('X-new: ', X_new.shape)

df_X = x[x['Cohort'] == 1]
df_X.reset_index(inplace=True)
folds_indices = {}
# Out:
# ['Age', 'T1E_log-sigma-3-mm-3D_gldm_LargeDependenceHighGrayLevelEmphasis_x', 'T1E_log-sigma-3-mm-3D_glcm_Autocorrelation_x', 'T1E_log-sigma-1-mm-3D_glcm_ClusterShade_x', 'T1E_wavelet-LHL_firstorder_Mean_x', 'T2_wavelet-LLH_glcm_ClusterShade_y', 'T1E_log-sigma-5-mm-3D_glrlm_LowGrayLevelRunEmphasis_x', 'T1E_wavelet-HLL_firstorder_Median_x', 'T1E_wavelet-LHL_firstorder_Median_x', 'T2_wavelet-HHL_firstorder_Skewness_x', 'T1E_log-sigma-3-mm-3D_glrlm_LongRunLowGrayLevelEmphasis_x', 'T1E_lbp-2D_glrlm_RunLengthNonUniformity_x', 'T2_log-sigma-1-mm-3D_gldm_LowGrayLevelEmphasis_x', 'T1E_log-sigma-5-mm-3D_firstorder_90Percentile_x', 'T1E_log-sigma-3-mm-3D_glszm_LowGrayLevelZoneEmphasis_x', 'T2_wavelet-HHL_glcm_SumSquares_x', 'T2_wavelet-HHL_glrlm_GrayLevelNonUniformityNormalized_x', 'T2_wavelet-LLH_gldm_DependenceNonUniformity_x', 'T2_original_shape_Maximum3DDiameter_y', 'T2_original_glszm_LargeAreaEmphasis_y']
# X-val:  (135, 20)
# X-new:  (44, 20)

# %%
for fold in df_X['fold'].unique():
    test_index = df_X[df_X['fold'] == fold].index
    train_index = df_X[df_X['fold'] != fold].index
    print(len(test_index), len(train_index))
    folds_indices[fold] = {'train_index': train_index, 'test_index': test_index}

X = df_X.iloc[:, 4:]
y = df_X['Subtypes_three']
print('X: ', X.shape)
print('Fold index has been determined!')
    
params_best = []
for i, values in enumerate(folds_indices.values()):
    train_index, test_index = values['train_index'], values['test_index']
    X_test, y_test = X.iloc[test_index], y.iloc[test_index]
    X_train, y_train = X.iloc[train_index], y.iloc[train_index]

    X_train = np.array(X_train)
    X_test = np.array(X_test)

    y_train = np.array(y_train).astype(int)
    y_test = np.array(y_test).astype(int)

    nm = SMOTE(random_state=42)
    X_res, y_res = nm.fit_resample(X_train, y_train)

    print('size of data partitions')
    print('...............INPUT..............OUTPUT..........')
    print('Train      : ', X_train.shape, '         ', y_train.shape, np.sum(y_train))
    print('Test       : ', X_test.shape, '         ', y_test.shape, np.sum(y_test))
    print('Validation : ', X_val.shape, '         ', y_val.shape, np.sum(y_val))
    # bayesian optimization of hyperparameters for lg_boost
    seed = 1
    # use partial to pass train, val and test data
    partial_lgb_evaluate_svm = partial(lgb_evaluate_svm, X_train=X_res, y_train=y_res, X_val=X_val, y_val=y_val,
                                                X_test=X_test, y_test=y_test, multi_cls=True)
    lgb_bo = BayesianOptimization(partial_lgb_evaluate_svm, pbounds={'C' : (0.01, 100)})

    # Optimally needs quite a few more initiation points and number of iterations
    gp_params = {'alpha': 1e-4}
    lgb_bo.set_gp_params(**gp_params)
    acq_f = UtilityFunction(kind="ei", kappa=2.576, xi=0.0)
    lgb_bo.maximize(init_points=200, n_iter=50, acquisition_function=acq_f)

    fold_max = lgb_bo.max['params']
    params_best.append(fold_max)
# Out:
# 172 342
# 170 344
# 172 342
# X:  (514, 20)
# Fold index has been determined!
# size of data partitions
# ...............INPUT..............OUTPUT..........
# Train      :  (342, 20)           (342,) 391
# Test       :  (172, 20)           (172,) 200
# Validation :  (135, 20)           (135,) 156
# |   iter    |  target   |     C     |
# -------------------------------------
# ************************************
# Train AUC       :  0.9665
# Test AUC       :  0.7618
# Validation AUC :  0.7862
# {'C': 10.968614388970535, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 1         | 0.7618    | 10.97     |
# ************************************
# Train AUC       :  0.9949
# Test AUC       :  0.7513
# Validation AUC :  0.7395
# {'C': 99.73280384226751, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 2         | 0.7513    | 99.73     |
# ************************************
# Train AUC       :  0.9908
# Test AUC       :  0.7524
# Validation AUC :  0.753
# {'C': 58.53279679487917, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 3         | 0.7524    | 58.53     |
# ************************************
# Train AUC       :  0.9936
# Test AUC       :  0.7538
# Validation AUC :  0.7412
# {'C': 80.34656207947286, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 4         | 0.7538    | 80.35     |
# ************************************
# Train AUC       :  0.9948
# Test AUC       :  0.7524
# Validation AUC :  0.7358
# {'C': 95.8859111959148, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 5         | 0.7524    | 95.89     |
# ************************************
# Train AUC       :  0.9792
# Test AUC       :  0.7551
# Validation AUC :  0.7667
# {'C': 22.727785430273993, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 6         | 0.7551    | 22.73     |
# ************************************
# Train AUC       :  0.9267
# Test AUC       :  0.7799
# Validation AUC :  0.7758
# {'C': 1.323675909014466, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 7         | 0.7799    | 1.324     |
# ************************************
# Train AUC       :  0.9914
# Test AUC       :  0.7532
# Validation AUC :  0.7504
# {'C': 60.79193649961243, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 8         | 0.7532    | 60.79     |
# ************************************
# Train AUC       :  0.993
# Test AUC       :  0.7544
# Validation AUC :  0.7447
# {'C': 74.33828309974707, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 9         | 0.7544    | 74.34     |
# ************************************
# Train AUC       :  0.99
# Test AUC       :  0.7554
# Validation AUC :  0.7606
# {'C': 50.738876722653124, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 10        | 0.7554    | 50.74     |
# ************************************
# Train AUC       :  0.9924
# Test AUC       :  0.7536
# Validation AUC :  0.7432
# {'C': 69.12981497458073, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 11        | 0.7536    | 69.13     |
# ************************************
# Train AUC       :  0.9906
# Test AUC       :  0.753
# Validation AUC :  0.7522
# {'C': 55.78412236202841, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 12        | 0.753     | 55.78     |
# ************************************
# Train AUC       :  0.9839
# Test AUC       :  0.7582
# Validation AUC :  0.7618
# {'C': 31.967215603422503, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 13        | 0.7582    | 31.97     |
# ************************************
# Train AUC       :  0.9692
# Test AUC       :  0.7606
# Validation AUC :  0.7818
# {'C': 12.505666254640996, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 14        | 0.7606    | 12.51     |
# ************************************
# Train AUC       :  0.9844
# Test AUC       :  0.7568
# Validation AUC :  0.7607
# {'C': 33.89576720657583, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 15        | 0.7568    | 33.9      |
# ************************************
# Train AUC       :  0.9902
# Test AUC       :  0.7547
# Validation AUC :  0.7585
# {'C': 51.679772380711455, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 16        | 0.7547    | 51.68     |
# ************************************
# Train AUC       :  0.9949
# Test AUC       :  0.7496
# Validation AUC :  0.7365
# {'C': 99.7731388721422, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 17        | 0.7496    | 99.77     |
# ************************************
# Train AUC       :  0.9823
# Test AUC       :  0.7553
# Validation AUC :  0.7614
# {'C': 28.196777893935796, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 18        | 0.7553    | 28.2      |
# ************************************
# Train AUC       :  0.963
# Test AUC       :  0.7644
# Validation AUC :  0.7893
# {'C': 9.335806517564397, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 19        | 0.7644    | 9.336     |
# ************************************
# Train AUC       :  0.9891
# Test AUC       :  0.756
# Validation AUC :  0.7588
# {'C': 47.580617059823304, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 20        | 0.756     | 47.58     |
# ************************************
# Train AUC       :  0.9794
# Test AUC       :  0.7559
# Validation AUC :  0.766
# {'C': 22.28476636910392, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 21        | 0.7559    | 22.28     |
# ************************************
# Train AUC       :  0.995
# Test AUC       :  0.7532
# Validation AUC :  0.7361
# {'C': 99.92320154471737, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 22        | 0.7532    | 99.92     |
# ************************************
# Train AUC       :  0.9931
# Test AUC       :  0.7521
# Validation AUC :  0.7406
# {'C': 76.20144345724071, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 23        | 0.7521    | 76.2      |
# ************************************
# Train AUC       :  0.9936
# Test AUC       :  0.7554
# Validation AUC :  0.7404
# {'C': 80.60258183680551, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 24        | 0.7554    | 80.6      |
# ************************************
# Train AUC       :  0.9408
# Test AUC       :  0.782
# Validation AUC :  0.7772
# {'C': 2.97395417264596, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 25        | 0.782     | 2.974     |
# ************************************
# Train AUC       :  0.9933
# Test AUC       :  0.7525
# Validation AUC :  0.7393
# {'C': 77.51331588941959, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 26        | 0.7525    | 77.51     |
# ************************************
# Train AUC       :  0.9825
# Test AUC       :  0.7552
# Validation AUC :  0.7604
# {'C': 28.99909624735409, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 27        | 0.7552    | 29.0      |
# ************************************
# Train AUC       :  0.9888
# Test AUC       :  0.756
# Validation AUC :  0.7627
# {'C': 45.82941685591769, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 28        | 0.756     | 45.83     |
# ************************************
# Train AUC       :  0.9463
# Test AUC       :  0.7762
# Validation AUC :  0.7774
# {'C': 3.9568219299016856, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 29        | 0.7762    | 3.957     |
# ************************************
# Train AUC       :  0.9893
# Test AUC       :  0.7548
# Validation AUC :  0.7565
# {'C': 48.45813331923281, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 30        | 0.7548    | 48.46     |
# ************************************
# Train AUC       :  0.9942
# Test AUC       :  0.7531
# Validation AUC :  0.7369
# {'C': 87.7248550361373, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 31        | 0.7531    | 87.72     |
# ************************************
# Train AUC       :  0.9945
# Test AUC       :  0.7514
# Validation AUC :  0.7364
# {'C': 91.3272118876623, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 32        | 0.7514    | 91.33     |
# ************************************
# Train AUC       :  0.9892
# Test AUC       :  0.7559
# Validation AUC :  0.7582
# {'C': 48.36348767708719, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 33        | 0.7559    | 48.36     |
# ************************************
# Train AUC       :  0.9944
# Test AUC       :  0.7504
# Validation AUC :  0.7363
# {'C': 91.09710170673019, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 34        | 0.7504    | 91.1      |
# ************************************
# Train AUC       :  0.9932
# Test AUC       :  0.7537
# Validation AUC :  0.7414
# {'C': 76.11778439086129, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 35        | 0.7537    | 76.12     |
# ************************************
# Train AUC       :  0.9794
# Test AUC       :  0.7559
# Validation AUC :  0.7663
# {'C': 22.194479633606704, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 36        | 0.7559    | 22.19     |
# ************************************
# Train AUC       :  0.9888
# Test AUC       :  0.7564
# Validation AUC :  0.7575
# {'C': 47.506231324629155, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 37        | 0.7564    | 47.51     |
# ************************************
# Train AUC       :  0.9948
# Test AUC       :  0.7515
# Validation AUC :  0.7381
# {'C': 97.31953749833258, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 38        | 0.7515    | 97.32     |
# ************************************
# Train AUC       :  0.9914
# Test AUC       :  0.754
# Validation AUC :  0.7558
# {'C': 60.005882116684006, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 39        | 0.754     | 60.01     |
# ************************************
# Train AUC       :  0.9908
# Test AUC       :  0.7537
# Validation AUC :  0.7537
# {'C': 55.24590738632857, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 40        | 0.7537    | 55.25     |
# ************************************
# Train AUC       :  0.9933
# Test AUC       :  0.7513
# Validation AUC :  0.7421
# {'C': 79.69373085072036, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 41        | 0.7513    | 79.69     |
# ************************************
# Train AUC       :  0.9086
# Test AUC       :  0.7659
# Validation AUC :  0.7711
# {'C': 0.6228455648465827, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 42        | 0.7659    | 0.6228    |
# ************************************
# Train AUC       :  0.9904
# Test AUC       :  0.7554
# Validation AUC :  0.76
# {'C': 52.27945364927398, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 43        | 0.7554    | 52.28     |
# ************************************
# Train AUC       :  0.9518
# Test AUC       :  0.7716
# Validation AUC :  0.7806
# {'C': 5.1655767581993715, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 44        | 0.7716    | 5.166     |
# ************************************
# Train AUC       :  0.9824
# Test AUC       :  0.7564
# Validation AUC :  0.7623
# {'C': 28.335018833910144, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 45        | 0.7564    | 28.34     |
# ************************************
# Train AUC       :  0.9937
# Test AUC       :  0.7543
# Validation AUC :  0.7394
# {'C': 82.20042961175614, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 46        | 0.7543    | 82.2      |
# ************************************
# Train AUC       :  0.9462
# Test AUC       :  0.7749
# Validation AUC :  0.7761
# {'C': 4.019899862247392, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 47        | 0.7749    | 4.02      |
# ************************************
# Train AUC       :  0.9925
# Test AUC       :  0.7529
# Validation AUC :  0.7464
# {'C': 70.36932972360346, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 48        | 0.7529    | 70.37     |
# ************************************
# Train AUC       :  0.9916
# Test AUC       :  0.7526
# Validation AUC :  0.7492
# {'C': 63.32357328713081, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 49        | 0.7526    | 63.32     |
# ************************************
# Train AUC       :  0.9904
# Test AUC       :  0.7545
# Validation AUC :  0.7552
# {'C': 53.32860775348877, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 50        | 0.7545    | 53.33     |
# ************************************
# Train AUC       :  0.9835
# Test AUC       :  0.7579
# Validation AUC :  0.7603
# {'C': 30.498366842491876, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 51        | 0.7579    | 30.5      |
# ************************************
# Train AUC       :  0.9888
# Test AUC       :  0.7555
# Validation AUC :  0.7552
# {'C': 45.81211619926894, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 52        | 0.7555    | 45.81     |
# ************************************
# Train AUC       :  0.9583
# Test AUC       :  0.7646
# Validation AUC :  0.7889
# {'C': 7.428315973872962, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 53        | 0.7646    | 7.428     |
# ************************************
# Train AUC       :  0.9311
# Test AUC       :  0.7805
# Validation AUC :  0.7761
# {'C': 1.679517565219965, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 54        | 0.7805    | 1.68      |
# ************************************
# Train AUC       :  0.9846
# Test AUC       :  0.7577
# Validation AUC :  0.7607
# {'C': 33.822443345385665, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 55        | 0.7577    | 33.82     |
# ************************************
# Train AUC       :  0.9948
# Test AUC       :  0.7526
# Validation AUC :  0.7353
# {'C': 97.64426266819648, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 56        | 0.7526    | 97.64     |
# ************************************
# Train AUC       :  0.9893
# Test AUC       :  0.7565
# Validation AUC :  0.7623
# {'C': 47.72125650543566, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 57        | 0.7565    | 47.72     |
# ************************************
# Train AUC       :  0.9871
# Test AUC       :  0.7562
# Validation AUC :  0.7613
# {'C': 41.732073209240156, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 58        | 0.7562    | 41.73     |
# ************************************
# Train AUC       :  0.9883
# Test AUC       :  0.7556
# Validation AUC :  0.7648
# {'C': 44.66148161171473, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 59        | 0.7556    | 44.66     |
# ************************************
# Train AUC       :  0.9877
# Test AUC       :  0.7562
# Validation AUC :  0.7594
# {'C': 42.42556756543412, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 60        | 0.7562    | 42.43     |
# ************************************
# Train AUC       :  0.9916
# Test AUC       :  0.7542
# Validation AUC :  0.7491
# {'C': 61.08028830355135, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 61        | 0.7542    | 61.08     |
# ************************************
# Train AUC       :  0.9715
# Test AUC       :  0.7609
# Validation AUC :  0.7817
# {'C': 14.147063770243117, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 62        | 0.7609    | 14.15     |
# ************************************
# Train AUC       :  0.9923
# Test AUC       :  0.7541
# Validation AUC :  0.7464
# {'C': 69.35453843930993, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 63        | 0.7541    | 69.35     |
# ************************************
# Train AUC       :  0.9784
# Test AUC       :  0.7571
# Validation AUC :  0.7705
# {'C': 20.641480534232937, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 64        | 0.7571    | 20.64     |
# ************************************
# Train AUC       :  0.934
# Test AUC       :  0.7784
# Validation AUC :  0.7777
# {'C': 2.0066203393899813, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 65        | 0.7784    | 2.007     |
# ************************************
# Train AUC       :  0.9808
# Test AUC       :  0.754
# Validation AUC :  0.7617
# {'C': 25.029371139524205, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 66        | 0.754     | 25.03     |
# ************************************
# Train AUC       :  0.9482
# Test AUC       :  0.775
# Validation AUC :  0.7776
# {'C': 4.317510888155913, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 67        | 0.775     | 4.318     |
# ************************************
# Train AUC       :  0.987
# Test AUC       :  0.7567
# Validation AUC :  0.7605
# {'C': 40.5493338534463, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 68        | 0.7567    | 40.55     |
# ************************************
# Train AUC       :  0.9825
# Test AUC       :  0.7564
# Validation AUC :  0.7624
# {'C': 28.81347740885763, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 69        | 0.7564    | 28.81     |
# ************************************
# Train AUC       :  0.992
# Test AUC       :  0.7537
# Validation AUC :  0.7493
# {'C': 66.8901806539081, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 70        | 0.7537    | 66.89     |
# ************************************
# Train AUC       :  0.9922
# Test AUC       :  0.755
# Validation AUC :  0.7464
# {'C': 67.18779493489406, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 71        | 0.755     | 67.19     |
# ************************************
# Train AUC       :  0.9945
# Test AUC       :  0.7514
# Validation AUC :  0.739
# {'C': 92.3696946905686, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 72        | 0.7514    | 92.37     |
# ************************************
# Train AUC       :  0.9878
# Test AUC       :  0.756
# Validation AUC :  0.7643
# {'C': 42.43898482671413, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 73        | 0.756     | 42.44     |
# ************************************
# Train AUC       :  0.9896
# Test AUC       :  0.7558
# Validation AUC :  0.7576
# {'C': 49.452014984599344, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 74        | 0.7558    | 49.45     |
# ************************************
# Train AUC       :  0.9844
# Test AUC       :  0.7578
# Validation AUC :  0.7619
# {'C': 34.05343546889214, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 75        | 0.7578    | 34.05     |
# ************************************
# Train AUC       :  0.9846
# Test AUC       :  0.7587
# Validation AUC :  0.7631
# {'C': 34.13472438311178, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 76        | 0.7587    | 34.13     |
# ************************************
# Train AUC       :  0.9834
# Test AUC       :  0.7564
# Validation AUC :  0.7615
# {'C': 31.024655311078046, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 77        | 0.7564    | 31.02     |
# ************************************
# Train AUC       :  0.9934
# Test AUC       :  0.755
# Validation AUC :  0.7414
# {'C': 77.89234538443152, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 78        | 0.755     | 77.89     |
# ************************************
# Train AUC       :  0.9898
# Test AUC       :  0.7557
# Validation AUC :  0.7555
# {'C': 49.15098605717341, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 79        | 0.7557    | 49.15     |
# ************************************
# Train AUC       :  0.988
# Test AUC       :  0.756
# Validation AUC :  0.7643
# {'C': 43.18914024377629, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 80        | 0.756     | 43.19     |
# ************************************
# Train AUC       :  0.994
# Test AUC       :  0.7531
# Validation AUC :  0.7389
# {'C': 85.27324295617392, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 81        | 0.7531    | 85.27     |
# ************************************
# Train AUC       :  0.9819
# Test AUC       :  0.7546
# Validation AUC :  0.7599
# {'C': 27.831429247928646, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 82        | 0.7546    | 27.83     |
# ************************************
# Train AUC       :  0.993
# Test AUC       :  0.7542
# Validation AUC :  0.7449
# {'C': 74.88894911133843, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 83        | 0.7542    | 74.89     |
# ************************************
# Train AUC       :  0.9945
# Test AUC       :  0.7538
# Validation AUC :  0.735
# {'C': 92.59747374285597, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 84        | 0.7538    | 92.6      |
# ************************************
# Train AUC       :  0.984
# Test AUC       :  0.7577
# Validation AUC :  0.7623
# {'C': 32.969600222676, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 85        | 0.7577    | 32.97     |
# ************************************
# Train AUC       :  0.9843
# Test AUC       :  0.758
# Validation AUC :  0.7622
# {'C': 33.33958057821449, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 86        | 0.758     | 33.34     |
# ************************************
# Train AUC       :  0.9939
# Test AUC       :  0.7541
# Validation AUC :  0.7361
# {'C': 84.94978172875994, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 87        | 0.7541    | 84.95     |
# ************************************
# Train AUC       :  0.9944
# Test AUC       :  0.7521
# Validation AUC :  0.7378
# {'C': 90.26811688051971, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 88        | 0.7521    | 90.27     |
# ************************************
# Train AUC       :  0.966
# Test AUC       :  0.7626
# Validation AUC :  0.788
# {'C': 10.62671061285293, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 89        | 0.7626    | 10.63     |
# ************************************
# Train AUC       :  0.9931
# Test AUC       :  0.7533
# Validation AUC :  0.7412
# {'C': 76.06737406550106, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 90        | 0.7533    | 76.07     |
# ************************************
# Train AUC       :  0.9857
# Test AUC       :  0.7576
# Validation AUC :  0.7601
# {'C': 37.869711239561205, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 91        | 0.7576    | 37.87     |
# ************************************
# Train AUC       :  0.9807
# Test AUC       :  0.755
# Validation AUC :  0.7636
# {'C': 24.635472364095154, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 92        | 0.755     | 24.64     |
# ************************************
# Train AUC       :  0.9759
# Test AUC       :  0.7586
# Validation AUC :  0.7716
# {'C': 18.521996221140746, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 93        | 0.7586    | 18.52     |
# ************************************
# Train AUC       :  0.9928
# Test AUC       :  0.7527
# Validation AUC :  0.7436
# {'C': 73.20690604424092, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 94        | 0.7527    | 73.21     |
# ************************************
# Train AUC       :  0.9948
# Test AUC       :  0.7528
# Validation AUC :  0.734
# {'C': 97.89574686456639, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 95        | 0.7528    | 97.9      |
# ************************************
# Train AUC       :  0.9942
# Test AUC       :  0.7503
# Validation AUC :  0.7411
# {'C': 90.32042533130972, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 96        | 0.7503    | 90.32     |
# ************************************
# Train AUC       :  0.9669
# Test AUC       :  0.7623
# Validation AUC :  0.7865
# {'C': 10.802594908633642, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 97        | 0.7623    | 10.8      |
# ************************************
# Train AUC       :  0.9762
# Test AUC       :  0.7592
# Validation AUC :  0.7722
# {'C': 18.42014144215175, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 98        | 0.7592    | 18.42     |
# ************************************
# Train AUC       :  0.987
# Test AUC       :  0.758
# Validation AUC :  0.7665
# {'C': 40.05017459811214, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 99        | 0.758     | 40.05     |
# ************************************
# Train AUC       :  0.9808
# Test AUC       :  0.7551
# Validation AUC :  0.762
# {'C': 24.91670782066724, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 100       | 0.7551    | 24.92     |
# ************************************
# Train AUC       :  0.9873
# Test AUC       :  0.7571
# Validation AUC :  0.7676
# {'C': 40.42926297779546, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 101       | 0.7571    | 40.43     |
# ************************************
# Train AUC       :  0.9908
# Test AUC       :  0.7548
# Validation AUC :  0.7531
# {'C': 55.012100228827755, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 102       | 0.7548    | 55.01     |
# ************************************
# Train AUC       :  0.9776
# Test AUC       :  0.7573
# Validation AUC :  0.768
# {'C': 20.113293381829287, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 103       | 0.7573    | 20.11     |
# ************************************
# Train AUC       :  0.9696
# Test AUC       :  0.7614
# Validation AUC :  0.7829
# {'C': 12.517578323557807, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 104       | 0.7614    | 12.52     |
# ************************************
# Train AUC       :  0.9844
# Test AUC       :  0.7573
# Validation AUC :  0.7623
# {'C': 34.475430017330424, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 105       | 0.7573    | 34.48     |
# ************************************
# Train AUC       :  0.9905
# Test AUC       :  0.7552
# Validation AUC :  0.7549
# ...
# | 215       | 0.8554    | 1.491     |
# ************************************
# Train AUC       :  0.8174
# Test AUC       :  0.8527
# Validation AUC :  0.7601
# {'C': 0.08209346709155432, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 216       | 0.8527    | 0.08209   |
# ************************************
# Train AUC       :  0.8699
# Test AUC       :  0.8515
# Validation AUC :  0.7789
# {'C': 0.2522498969714039, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 217       | 0.8515    | 0.2522    |
# ************************************
# Train AUC       :  0.9931
# Test AUC       :  0.7709
# Validation AUC :  0.7112
# {'C': 69.0611996954859, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 218       | 0.7709    | 69.06     |
# ************************************
# Train AUC       :  0.9437
# Test AUC       :  0.8308
# Validation AUC :  0.7639
# {'C': 5.045902170768418, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 219       | 0.8308    | 5.046     |
# ************************************
# Train AUC       :  0.9467
# Test AUC       :  0.8279
# Validation AUC :  0.7635
# {'C': 5.656422719682333, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 220       | 0.8279    | 5.656     |
# ************************************
# Train AUC       :  0.9096
# Test AUC       :  0.8566
# Validation AUC :  0.7785
# {'C': 1.156636561728232, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 221       | 0.8566    | 1.157     |
# ************************************
# Train AUC       :  0.9127
# Test AUC       :  0.8559
# Validation AUC :  0.7748
# {'C': 1.350400040702456, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 222       | 0.8559    | 1.35      |
# ************************************
# Train AUC       :  0.9245
# Test AUC       :  0.8466
# Validation AUC :  0.7701
# {'C': 2.3581246543845067, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 223       | 0.8466    | 2.358     |
# ************************************
# Train AUC       :  0.8978
# Test AUC       :  0.8546
# Validation AUC :  0.7785
# {'C': 0.6225703315357426, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 224       | 0.8546    | 0.6226    |
# ************************************
# Train AUC       :  0.9701
# Test AUC       :  0.8045
# Validation AUC :  0.7501
# {'C': 14.945138245648518, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 225       | 0.8045    | 14.95     |
# ************************************
# Train AUC       :  0.9097
# Test AUC       :  0.8562
# Validation AUC :  0.778
# {'C': 1.1562410599677284, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 226       | 0.8562    | 1.156     |
# ************************************
# Train AUC       :  0.9875
# Test AUC       :  0.7839
# Validation AUC :  0.7211
# {'C': 38.95605978267232, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 227       | 0.7839    | 38.96     |
# ************************************
# Train AUC       :  0.9912
# Test AUC       :  0.7766
# Validation AUC :  0.711
# {'C': 56.6036595983831, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 228       | 0.7766    | 56.6      |
# ************************************
# Train AUC       :  0.9793
# Test AUC       :  0.7938
# Validation AUC :  0.7343
# {'C': 22.84127079169042, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 229       | 0.7938    | 22.84     |
# ************************************
# Train AUC       :  0.9413
# Test AUC       :  0.8339
# Validation AUC :  0.7638
# {'C': 4.635834078874352, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 230       | 0.8339    | 4.636     |
# ************************************
# Train AUC       :  0.99
# Test AUC       :  0.7777
# Validation AUC :  0.7138
# {'C': 51.07917942705729, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 231       | 0.7777    | 51.08     |
# ************************************
# Train AUC       :  0.993
# Test AUC       :  0.7719
# Validation AUC :  0.7108
# {'C': 67.8493676344781, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 232       | 0.7719    | 67.85     |
# ************************************
# Train AUC       :  0.9742
# Test AUC       :  0.7995
# Validation AUC :  0.7458
# {'C': 18.13897453071538, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 233       | 0.7995    | 18.14     |
# ************************************
# Train AUC       :  0.9105
# Test AUC       :  0.8566
# Validation AUC :  0.7784
# {'C': 1.2035329569716327, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 234       | 0.8566    | 1.204     |
# ************************************
# Train AUC       :  0.9094
# Test AUC       :  0.8563
# Validation AUC :  0.7781
# {'C': 1.1392339020560123, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 235       | 0.8563    | 1.139     |
# ************************************
# Train AUC       :  0.9107
# Test AUC       :  0.8562
# Validation AUC :  0.777
# {'C': 1.223081505101125, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 236       | 0.8562    | 1.223     |
# ************************************
# Train AUC       :  0.9591
# Test AUC       :  0.8166
# Validation AUC :  0.7648
# {'C': 9.626671768514576, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 237       | 0.8166    | 9.627     |
# ************************************
# Train AUC       :  0.9865
# Test AUC       :  0.7828
# Validation AUC :  0.7243
# {'C': 35.3534137499457, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 238       | 0.7828    | 35.35     |
# ************************************
# Train AUC       :  0.7163
# Test AUC       :  0.731
# Validation AUC :  0.65
# {'C': 0.015601051973573348, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 239       | 0.731     | 0.0156    |
# ************************************
# Train AUC       :  0.8447
# Test AUC       :  0.8508
# Validation AUC :  0.7712
# {'C': 0.14300179841148195, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 240       | 0.8508    | 0.143     |
# ************************************
# Train AUC       :  0.8283
# Test AUC       :  0.8548
# Validation AUC :  0.7683
# {'C': 0.10016040130478596, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 241       | 0.8548    | 0.1002    |
# ************************************
# Train AUC       :  0.8947
# Test AUC       :  0.8547
# Validation AUC :  0.78
# {'C': 0.5442985265218996, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 242       | 0.8547    | 0.5443    |
# ************************************
# Train AUC       :  0.9137
# Test AUC       :  0.8556
# Validation AUC :  0.774
# {'C': 1.4247891098098144, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 243       | 0.8556    | 1.425     |
# ************************************
# Train AUC       :  0.9168
# Test AUC       :  0.8541
# Validation AUC :  0.7735
# {'C': 1.6444512008619048, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 244       | 0.8541    | 1.644     |
# ************************************
# Train AUC       :  0.9006
# Test AUC       :  0.8534
# Validation AUC :  0.7776
# {'C': 0.7013410994456784, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 245       | 0.8534    | 0.7013    |
# ************************************
# Train AUC       :  0.9159
# Test AUC       :  0.8548
# Validation AUC :  0.774
# {'C': 1.5683769779354735, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 246       | 0.8548    | 1.568     |
# ************************************
# Train AUC       :  0.9119
# Test AUC       :  0.8565
# Validation AUC :  0.7761
# {'C': 1.2971858008049733, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 247       | 0.8565    | 1.297     |
# ************************************
# Train AUC       :  0.9229
# Test AUC       :  0.8487
# Validation AUC :  0.7718
# {'C': 2.186845979555981, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 248       | 0.8487    | 2.187     |
# ************************************
# Train AUC       :  0.8843
# Test AUC       :  0.8523
# Validation AUC :  0.7819
# {'C': 0.36205910277053593, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 249       | 0.8523    | 0.3621    |
# ************************************
# Train AUC       :  0.9239
# Test AUC       :  0.8473
# Validation AUC :  0.7708
# {'C': 2.287900927383275, 'break_ties': False, 'cache_size': 200, 'class_weight': 'balanced', 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf', 'max_iter': -1, 'probability': True, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
# | 250       | 0.8473    | 2.288     |
# =====================================

# %%
test_folds = []
test_gt_folds = []
val_folds = []
true_folds = []
pred_folds = []
cm_folds = []
f1_test_folds = []
auc_test_folds = []
new_folds = []
f1_test_CI_folds = []
auc_test_CI_folds = []

for i, values in enumerate(folds_indices.values()):
    train_index, test_index = values['train_index'], values['test_index']
    X_train, y_train = X.iloc[train_index], y.iloc[train_index]
    X_test, y_test = X.iloc[test_index], y.iloc[test_index]

    X_train = np.array(X_train)
    X_test = np.array(X_test)

    y_train = np.array(y_train).astype(int)
    y_test = np.array(y_test).astype(int)

    X_train, y_train = X.iloc[train_index], y.iloc[train_index]
    X_test, y_test = X.iloc[test_index], y.iloc[test_index]

    X_train = np.array(X_train)
    X_test = np.array(X_test)

    y_train = np.array(y_train).astype(int)
    y_test = np.array(y_test).astype(int)

    nm = SMOTE(random_state=42)
    X_res, y_res = nm.fit_resample(X_train, y_train)

    params_cur = params_best[i]
    modelsvc = SVC(probability=True)
    modelsvc.set_params(**params_cur)
    clf_lg = modelsvc.fit(X_res, y_res)
    p_lg_train = clf_lg.predict_proba(X_res)  # [:,1]
    p_lg_test = clf_lg.predict_proba(X_test)  # [:,1]
    p_lg_val = clf_lg.predict_proba(X_val)  # [:,1]
    p_lg_new = clf_lg.predict_proba(X_new)  # [:,1]

    val_folds.append(p_lg_val)
    test_folds.append(p_lg_test)
    test_gt_folds.append(y_test)
    new_folds.append(p_lg_new)

    l_lg_train = clf_lg.predict(X_res)
    l_lg_test = clf_lg.predict(X_test)
    l_lg_val = clf_lg.predict(X_val)
    l_lg_new = clf_lg.predict(X_new)

    f1_train = f1_score(y_res, l_lg_train, average='weighted')
    f1_test = f1_score(y_test, l_lg_test, average='weighted')
    f1_val = f1_score(y_val, l_lg_val, average='weighted')
    f1_new = f1_score(y_new, l_lg_new, average='weighted')
    f1_test_folds.append(f1_test)
    f1_test_CI_folds.append(bootstrap(y_test, l_lg_test, 3000, 0.95,f1_score, average='weighted'))

    true_folds.append(y_test)
    pred_folds.append(l_lg_test)

    lg_auc_train = roc_auc_score(y_res, p_lg_train, multi_class='ovr')
    lg_auc_test = roc_auc_score(y_test, p_lg_test, multi_class='ovr')
    lg_auc_val = roc_auc_score(y_val, p_lg_val, multi_class='ovr')
    lg_auc_new = roc_auc_score(y_new, p_lg_new, multi_class='ovr')
    auc_test_folds.append(lg_auc_test)
    auc_test_CI_folds.append(bootstrap(y_test, p_lg_test, 3000, 0.95,roc_auc_score, multi_class='ovr'))

    cm_test = confusion_matrix(y_test, l_lg_test)
    cm_folds.append(cm_test)

# %%
def bootstrap(true, pred, B, c, func, **args):
    """
    计算 bootstrap 置信区间
    :param data: array 保存样本数据
    :param B: 抽样次数 通常 B>=1000
    :param c: 置信水平
    :param func: 样本估计量
    :return: bootstrap置信区间上下限
    """
    array = np.array(true)
    n = len(array)
    sample_result_arr = []
    for i in range(B):
        index_arr = np.random.randint(0, n, size=n)
        data_sample_real = true[index_arr]
        data_sample_pred = pred[index_arr]
        sample_result = func(data_sample_real, data_sample_pred, **args)
        sample_result_arr.append(sample_result)
    a = 1 - c
    k1 = int(B * a / 2)
    k2 = int(B * (1 - a / 2))
    auc_sample_arr_sorted = sorted(sample_result_arr)
    lower = auc_sample_arr_sorted[k1]
    higher = auc_sample_arr_sorted[k2]
    return (lower, higher)

#print("f1 score(95%CI):{}{}".format(f1_score(y_test, l_lg_test, average='weighted'),np.round(bootstrap(y_test, l_lg_test, 1000, 0.95, f1_score, average='weighted'), decimals=4)))
#print("AUC CI(95%CI):{}{}".format(roc_auc_score(y_test, p_lg_test, multi_class='ovr'), bootstrap(y_test, p_lg_test, 1000, 0.95, roc_auc_score, multi_class='ovr')))

# %%
all_val_folds = np.stack(val_folds)
all_new_folds = np.stack(new_folds)

mean_folds = np.mean(all_val_folds, axis=0)
mean_new_folds = np.mean(all_new_folds, axis=0)

experiment_name = 'Age_Radio'

# %%
from datetime import datetime

# 获取当前时间
now = datetime.now()

# 格式化时间为 MMDDHHMM 格式
timestamp = now.strftime("%m%d%H%M")
csv_result = '/Users/huyanshen/Desktop/AI-Medicine/Research/PengCheng/Shap_Value_yanshen/ModelComparison/SVM_result/results.csv'

with open(csv_result.replace('results.csv', experiment_name + '_' + timestamp + '.txt'), 'w') as f:
    sys.stdout = f
    print('-------------Features---------------')
    print(sel_columns)

    print('-------------Testing----------------')
    all_test_folds = np.vstack(test_folds)
    gt_test = np.concatenate(test_gt_folds)
    print('All_test_folds: ', all_test_folds.shape)

    lg_auc_test = roc_auc_score(gt_test, all_test_folds, multi_class='ovr')
    lg_auc_CI_test = bootstrap(gt_test, all_test_folds, 3000, 0.95, roc_auc_score, multi_class='ovr')
    print('Test AUC : {} {}'.format(np.round(lg_auc_test, decimals=4), np.round(lg_auc_CI_test), decimals=4))
    AUC_format = [str(i) + ' ' + str(j) for i, j in zip(np.round(auc_test_folds, decimals=4), np.round(auc_test_CI_folds, decimals=4))]
    print('Test AUC: ', AUC_format, '(per fold)')

    # Binarize the true labels to use with roc_auc_score
    y_test_binarized = label_binarize(gt_test, classes=[0, 1, 2])
    aucs_test = []
    aucs_CI_test = []
    for i in range(3):
        auc_test = roc_auc_score(y_test_binarized[:, i], np.array(all_test_folds)[:, i])
        auc_CI_test = bootstrap(y_test_binarized[:, i], np.array(all_test_folds)[:, i], 3000, 0.95, roc_auc_score, multi_class='ovr')
        aucs_test.append(auc_test)
        aucs_CI_test.append(auc_CI_test)
    AUC_format = [str(i) + ' ' + str(j) for i, j in zip(np.round(aucs_test, decimals=4), np.round(aucs_CI_test, decimals=4))]
    print('Test AUC : ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')

    f1_test = f1_score(gt_test, np.argmax(all_test_folds, axis=1), average='weighted')
    f1_CI_test = bootstrap(gt_test, np.argmax(all_test_folds, axis=1), 3000, 0.95, f1_score, average='weighted')
    print('Test F1 score: {} {}'.format(np.round(f1_test, decimals=4), np.round(f1_CI_test, decimals=4)))
    AUC_format = [str(i) + ' ' + str(j) for i, j in zip(np.round(f1_test_folds, decimals=4), np.round(f1_test_CI_folds, decimals=4))]
    print('Test F1 score: ', AUC_format, '(per fold)')
    test_f1_per_subtype = [np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=0), decimals=4),
                            np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=1), decimals=4),
                            np.round(f1_scores(gt_test, np.argmax(all_test_folds, axis=1), pos_index=2), decimals=4)]
    test_f1_CI_per_subtype = [np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_score, pos_index=0), decimals=4),
                            np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_score, pos_index=1), decimals=4),
                            np.round(bootstrap(gt_test, np.argmax(all_test_folds, axis=1),3000, 0.95, f1_score, pos_index=2), decimals=4)]
    AUC_format = [str(i) + ' ' + str(j) for i, j in zip(np.round(test_f1_per_subtype, decimals=4), np.round(test_f1_CI_per_subtype, decimals=4))]
    print('Test F1 score: ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')

    cm_test = confusion_matrix(gt_test, np.argmax(all_test_folds, axis=1))
    print('Test Confusion Matrix: ')
    print(cm_test)
    #disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_val)
    #disp1.plot()

    print('-----------Validation--------------')
    all_val_folds = np.stack(val_folds)
    mean_folds = np.mean(all_val_folds, axis=0)
    print('All_val_folds: ', all_val_folds.shape)
    print('All_mean_val_folds:', mean_folds.shape)

    lg_auc_val = roc_auc_score(y_val, mean_folds, multi_class='ovr')
    lg_auc_CI_val = bootstrap(y_val, mean_folds, 3000, 0.95, roc_auc_score, multi_class='ovr')
    print('Validation AUC : {} {}'.format(np.round(lg_auc_val, decimals=4), np.round(lg_auc_CI_val, decimals=4)))
    #print('Validation AUC : ', np.round(lg_auc_val, decimals=4))

    # Binarize the true labels to use with roc_auc_score
    y_val_binarized = label_binarize(y_val, classes=[0, 1, 2])
    aucs_val = []
    aucs_CI_val = []
    for i in range(3):
        auc_val = roc_auc_score(y_val_binarized[:, i], np.array(mean_folds)[:, i])
        auc_CI_val = bootstrap(y_val_binarized[:, i], np.array(mean_folds)[:, i], 3000, 0.95, roc_auc_score, multi_class='ovr')
        aucs_val.append(auc_test)
        aucs_CI_val.append(auc_CI_test)
    AUC_format = [str(i) + ' ' + str(j) for i, j in zip(np.round(aucs_val, decimals=4), np.round(aucs_CI_val, decimals=4))]
    print('Validation AUC : ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')
    #print('Validation AUC : ', np.round(aucs_val, decimals=4), '(per subtype, [WNT, G3/G4, SHH])')

    f1_mean_val = f1_score(y_val, np.argmax(mean_folds, axis=1), average='weighted')
    f1_mean_CI_val = bootstrap(y_val, np.argmax(mean_folds, axis=1), 3000, 0.95, f1_score, average='weighted')
    print('Validation F1 score: {} {}'.format(np.round(f1_mean_val, decimals=4), np.round(f1_mean_CI_val, decimals=4)))
    #print('Validation f1 score: ', np.round(f1_mean_val, decimals=4))
    val_f1_per_subtype = [np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=0), decimals=4),
                            np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=1), decimals=4),
                            np.round(f1_scores(y_val, np.argmax(mean_folds, axis=1), pos_index=2), decimals=4)]
    val_f1_CI_per_subtype = [np.round(bootstrap(gt_test, np.argmax(mean_folds, axis=1),3000, 0.95, f1_score, pos_index=0), decimals=4),
                            np.round(bootstrap(gt_test, np.argmax(mean_folds, axis=1),3000, 0.95, f1_score, pos_index=1), decimals=4),
                            np.round(bootstrap(gt_test, np.argmax(mean_folds, axis=1),3000, 0.95, f1_score, pos_index=2), decimals=4)]
    AUC_format = [str(i) + ' ' + str(j) for i, j in zip(np.round(val_f1_per_subtype, decimals=4), np.round(val_f1_CI_per_subtype, decimals=4))]
    print('Validation F1 score: ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')

    #print('Validation f1 score: ', val_f1_per_subtype, '(per subtype, [WNT, G3/G4, SHH])')

    cm_val = confusion_matrix(y_val, np.argmax(mean_folds, axis=1))
    print('Validation Confusion Matrix: ')
    print(cm_val)
    #disp1 = ConfusionMatrixDisplay(confusion_matrix=cm_val)
    #disp1.plot()
        
    print('-----------Golden--------------')
    all_new_folds = np.stack(new_folds)
    mean_new_folds = np.mean(all_new_folds, axis=0)
    print('All_new_folds: ', all_new_folds.shape)
    print('All_mean_new_folds:', mean_new_folds.shape)

    lg_auc_new = roc_auc_score(y_new, mean_new_folds, multi_class='ovr')
    lg_auc_CI_new = bootstrap(y_new, mean_new_folds, 3000, 0.95, roc_auc_score, multi_class='ovr')
    print('Golden AUC : {} {}'.format(np.round(lg_auc_new, decimals=4), np.round(lg_auc_CI_new, decimals=4)))
    #print('Golden AUC : ', np.round(lg_auc_new, decimals=4))
    # Binarize the true labels to use with roc_auc_score
    y_new_binarized = label_binarize(y_new, classes=[0, 1, 2])
    aucs_new = []
    aucs_CI_new = []
    for i in range(3):
        auc_new = roc_auc_score(y_new_binarized[:, i], np.array(mean_new_folds)[:, i])
        auc_CI_new = bootstrap(y_new_binarized[:, i], np.array(mean_new_folds)[:, i], 3000, 0.95, roc_auc_score, multi_class='ovr')
        aucs_CI_new.append(auc_CI_new)
        aucs_new.append(auc_new)
    AUC_format = [str(i) + ' ' + str(j) for i, j in zip(np.round(aucs_new, decimals=4), np.round(aucs_CI_new, decimals=4))]
    print('Golden AUC : ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')
    #print('Golden AUC : ', np.round(aucs_new, decimals=4), '(per subtype, [WNT, G3/G4, SHH])')

    f1_mean_new = f1_score(y_new, np.argmax(mean_new_folds, axis=1), average='weighted')
    f1_mean_CI_new = bootstrap(y_new, np.argmax(mean_folds, axis=1), 3000, 0.95, f1_score, average='weighted')
    print('Golden F1 score: {} {}'.format(np.round(f1_mean_new, decimals=4), np.round(f1_mean_CI_new, decimals=4)))
    #print('Golden f1 score: ', np.round(f1_mean_new, decimals=4))
    new_f1_per_subtype = [np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=0), decimals=4),
                            np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=1), decimals=4),
                            np.round(f1_scores(y_new, np.argmax(mean_new_folds, axis=1), pos_index=2), decimals=4)]
    new_f1_CI_per_subtype = [np.round(bootstrap(y_new, np.argmax(mean_new_folds, axis=1),3000, 0.95, f1_score, pos_index=0), decimals=4),
                            np.round(bootstrap(y_new, np.argmax(mean_new_folds, axis=1),3000, 0.95, f1_score, pos_index=1), decimals=4),
                            np.round(bootstrap(y_new, np.argmax(mean_new_folds, axis=1),3000, 0.95, f1_score, pos_index=2), decimals=4)]
    AUC_format = [str(i) + ' ' + str(j) for i, j in zip(np.round(new_f1_per_subtype, decimals=4), np.round(new_f1_CI_per_subtype, decimals=4))]
    print('Golden F1 score: ', AUC_format, '(per subtype, [WNT, G3/G4, SHH])')
    #print('Golden f1 score: ', new_f1_per_subtype, '(per subtype, [WNT, G3/G4, SHH])')

    cm_new = confusion_matrix(y_new, np.argmax(mean_new_folds, axis=1))
    print('Golden Confusion Matrix: ')
    print(cm_new)

    print('-------------Params-----------------')
    for i in range(3):
        print(params_best[i])
        
    experiment_data = {
            'Experiment': experiment_name,
            'Test AUC Overall': np.round(lg_auc_test, decimals=4),
            'Test AUC Per Fold': np.round(auc_test_folds, decimals=4).tolist(),
            'Test AUC Per Subtype': np.round(aucs_test, decimals=4),
            'Test F1 Overall': np.round(f1_test, decimals=4),
            'Test F1 Per Fold': np.round(f1_test_folds, decimals=4).tolist(),
            'Test F1 Per Subtype': test_f1_per_subtype,
            'Validation AUC Overall': np.round(lg_auc_val, decimals=4),
            'Validation AUC Per Subtype': np.round(aucs_val, decimals=4).tolist(),
            'Validation F1 Overall': np.round(f1_mean_val, decimals=4),
            'Validation F1 Per Subtype': val_f1_per_subtype,
            'Golden AUC Overall': np.round(lg_auc_new, decimals=4),
            'Golden AUC Per Subtype': np.round(aucs_new, decimals=4).tolist(),
            'Golden F1 Overall': np.round(f1_mean_new, decimals=4),
            'Golden F1 Per Subtype': new_f1_per_subtype,
            'details file': experiment_name + '_' + timestamp + '.txt'
    }

    # 写入数据
    write_experiment_results_to_csv(csv_result, experiment_data)
