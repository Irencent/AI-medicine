# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import shapely
from shapely.geometry import Polygon, MultiPolygon

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Load the built-in GeoPandas world dataset 
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Set up the map projection and figure
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.Orthographic(260, 40)}, figsize=(8, 8))

# Plot the world map 
world_color = 'lightgrey'
#world_color = [220/255, 225/255, 240/255] # 淡紫色
#world_color = [151/255, 190/255, 190/225] # 蓝色
#world_color = [155/255, 200/255, 180/225] # 青绿色
#world_color = [185/255, 205/255, 207/255] # 灰绿色
world.plot(ax=ax, color=world_color, transform=ccrs.PlateCarree(), edgecolor=world_color)


locations = [
    (37.433017, -122.175175), # ('Stanford Hospital, USA', 
    (39.9496, -75.1932), # 'Children’s Hospital of Philadelphia, USA', 
]

# 创建一个 RGB 颜色 
rgb_color = [220/255, 225/255, 240/255]
purple=[132/255,154/255,160/255]

# 标记地点
#scatter = gdf.plot(ax=ax, markersize=100, color=purple)

#for lat, lon in locations:
#   ax.scatter(lon, lat, s=200, color=purple, edgecolor=None, transform=ccrs.Geodetic())
#   ax.scatter(lon, lat, s=20, color='white', edgecolor=None, transform=ccrs.Geodetic())




# Optionally, you can remove the axis for a cleaner look
ax.set_global()
#ax.outline_patch.set_visible(False)

ax.gridlines()

border = world[world['name'] == 'United States of America']['geometry']
ax.add_geometries(border, crs=ccrs.PlateCarree(), facecolor='none', edgecolor='black',linestyle=':')
#ax.add_feature(cfeature.BORDERS, edgecolor='black', linewidth=1, linestyle=':')
ax.coastlines(color='white')
# Display the plot
plt.show()
#fig.savefig("America-light-grey.png", dpi=800)
# Out:
# /var/folders/nj/6hcc0q8x30x74w9dhvw1xz2r0000gn/T/ipykernel_44703/3489773842.py:7: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import pandas as pd
import cartopy.feature as cfeature

# Load the built-in natural earth data from GeoPandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Create a plot with an Orthographic projection with Asia at the center
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.Orthographic(100, 40)}, figsize=(8, 8))

# Add the GeoPandas data to the plot with Cartopy's interface 152, 191, 190
world_color = 'lightgrey'
#world_color = [220/255, 225/255, 240/255] # 淡紫色
#world_color = [151/255, 190/255, 190/225] # 蓝色
#world_color = [155/255, 200/255, 180/225] # 青绿色
#world_color = [185/255, 205/255, 207/255] # 灰绿色
#world_color = [182/255, 225/255, 210/225]

world.plot(ax=ax, transform=ccrs.PlateCarree(), color=world_color, edgecolor=world_color)

locations = [
    (31.2057496,121.4580583),  # '华山医院, 上海, 中国'
    (32.6512, 113.1201),  # '济南, 中国'
    (36.682784, 117.024967),      # '齐鲁医院, 中国'
    (39.9813, 116.3626),      # '北京三博脑科医院, 中国'
    (31.842598, 117.227219), # '安徽省立医院, 中国'
    (34.241842, 108.943481), # '西京医院, 中国'
    (28.193106, 112.98127), # ''湘雅医院, 中国', 
    (29.56301, 106.551556), # '重庆, 中国', 
    (37.88, 113.40),    # '天坛, 北京', 
    # Add more locations as needed
]

# 创建一个 RGB 颜色
rgb_color = [220/255, 225/255, 240/255]
purple=[132/255,154/255,160/255]

# 标记地点
#scatter = gdf.plot(ax=ax, markersize=100, color=purple)

#for lat, lon in locations:
#  ax.scatter(lon, lat, s=200, color=purple, edgecolor=None, transform=ccrs.Geodetic())
#  ax.scatter(lon, lat, s=20, color='white', edgecolor=None, transform=ccrs.Geodetic())


# Set the extent (view) of the map to global
ax.set_global()

# Add gridlines, coastlines, and the outline of the map
ax.gridlines()
#ax.coastlines()

# Add national boundaries with a specific style
border = world[world['name'] == 'China']['geometry']
ax.add_geometries(border, crs=ccrs.PlateCarree(), facecolor='none', edgecolor='black', linestyle=':')
border = world[world['name'] == 'Taiwan']['geometry']
ax.add_geometries(border, crs=ccrs.PlateCarree(), facecolor='none', edgecolor='black', linestyle=':')
#ax.add_feature(cfeature.BORDERS, edgecolor='black', linewidth=1, linestyle=':')



ax.coastlines(color='white')

plt.show()
#fig.savefig('China-lightgrey.png', dpi=800)
# Out:
# /var/folders/nj/6hcc0q8x30x74w9dhvw1xz2r0000gn/T/ipykernel_44703/1764948358.py:8: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import pandas as pd
import cartopy.feature as cfeature

# Load the built-in natural earth data from GeoPandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Create a plot with an Orthographic projection with Asia at the center
fig, ax = plt.subplots(subplot_kw={'projection': ccrs.Orthographic(100, 40)}, figsize=(8, 8))

# Add the GeoPandas data to the plot with Cartopy's interface
world.plot(ax=ax, transform=ccrs.PlateCarree(), color='lightgrey')

# Set the extent (view) of the map to global
ax.set_global()

# Add gridlines, coastlines, and the outline of the map
ax.gridlines()
ax.coastlines()

# Add national boundaries with a specific style
ax.add_feature(cfeature.BORDERS, edgecolor='black', linewidth=1, linestyle=':')

# 地点和病人数量
locations = [('华山医院, 上海, 中国', (31.2057496,121.4580583)), 
             ('济南, 中国', (32.6512, 113.1201)), 
             ('齐鲁医院, 中国', (36.682784, 117.024967)), 
             ('北京三博脑科医院, 中国', (39.9813, 116.3626)), 
             ('安徽省立医院, 中国', (31.842598, 117.227219)), 
             ('西京医院, 中国', (34.241842, 108.943481)), 
             ('湘雅医院, 中国', (28.193106, 112.98127)), 
             ('重庆, 中国', (29.56301, 106.551556)), 
             ('Stanford Hospital, USA', (37.433017, -122.175175)), 
             ('Children’s Hospital of Philadelphia, USA', (39.9496, -75.1932)),
             ('天坛, 北京', (37.88, 113.40))]
patients = [18, 12, 12, 29, 30, 7, 6, 3, 40,91,577]  # 示例病人数量

# 获取每个地点的经纬度和名称
names = [loc[0] for loc in locations]
latitudes = [loc[1][0] for loc in locations]
longitudes = [loc[1][1] for loc in locations]

# 创建一个 GeoDataFrame
df = pd.DataFrame(
    {'Name': names, 'Latitude': latitudes, 'Longitude': longitudes, 'Patients': patients})
gdf = gpd.GeoDataFrame(
    df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))

# 加载全球地图
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# 创建一个 RGB 颜色
rgb_color = [220/255, 225/255, 240/255]
purple=[132/255,154/255,160/255]

scatter = gdf.plot(ax=ax, markersize=100, color=purple)


# Remove the default frame of the plot (if desired)
# ax.spines['geo'].set_visible(False)

plt.show()
# Out:
# /var/folders/nj/6hcc0q8x30x74w9dhvw1xz2r0000gn/T/ipykernel_1566/353731825.py:8: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# /var/folders/nj/6hcc0q8x30x74w9dhvw1xz2r0000gn/T/ipykernel_1566/353731825.py:52: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# Load the built-in natural earth data from GeoPandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Define the center of the projection to be in the middle of Asia
central_longitude = 100
central_latitude = 40

# Create a plot with an Orthographic projection with Asia at the center
fig, ax = plt.subplots(subplot_kw={
    'projection': ccrs.Orthographic(central_longitude, central_latitude)},
    figsize=(8, 8))

# Add the GeoPandas data to the plot with Cartopy's interface
world.plot(ax=ax, transform=ccrs.PlateCarree(), color='lightgrey')

# Set the extent (view) of the map to global
ax.set_global()

# Add gridlines and coastlines
ax.gridlines()
ax.coastlines()

# Add national boundaries with a specific style
ax.add_feature(cfeature.BORDERS, edgecolor='black', linewidth=1, linestyle=':')

plt
# Out:
# /var/folders/nj/6hcc0q8x30x74w9dhvw1xz2r0000gn/T/ipykernel_1566/2059852701.py:7: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# <module 'matplotlib.pyplot' from '/Users/huyanshen/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py'>
